# %% [markdown]
# <a href="https://colab.research.google.com/github/BenRoche18/Im2Calories/blob/master/food_classification_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Set up environment

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torchsummary import summary

import os
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import copy
import shutil
from PIL import Image
from tqdm.autonotebook import tqdm
import sys

# %% [markdown]
# **Import utility functions from Pytorch**

# %%
ROOT_DIR = os.path.dirname(os.getcwd())

sys.path.append(os.path.join(ROOT_DIR, "utilities"))

from engine import train_one_epoch, evaluate
import utils

# %% [markdown]
# **Enable GPU**

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Running on", device)
# Out:
# Running on cuda:0

# %% [markdown]
# **Declare parameters**

# %%
IMAGE_SIZE = 512
BATCH_SIZE = 1

# %% [markdown]
# # Input data

# %% [markdown]
# **Download Food256 dataset**
#
# To extend the food classification into food detection I will need a dataset that includes bounding boxes, thus I have used food-256 including 256 different classes that contain atleast 100 images each. If the given directory not found then dataset is downloaded and extracted.

# %%
FOOD256_DIR = os.path.join(os.path.abspath(os.sep), "Datasets", "food256")

if not os.path.exists(FOOD256_DIR):
  print("Downloading Food-256 dataset... ", end="")
  # !wget http://foodcam.mobi/dataset256.zip
  print("Done")


  print("Extracting data... ", end="")
  # !unzip dataset256.zip
  print("Done")

# %% [markdown]
# **Format dataset for extraction**
#
# Extract images into one directory called 'images' and create a corresponding label file containing 'class x y width height' in seperate 'labels' directory. Then create train.txt and val.txt files containing image paths.

# %%
IMAGES_DIR = os.path.join(FOOD256_DIR, "images")
LABELS_DIR = os.path.join(FOOD256_DIR, "labels")

if not os.path.exists(IMAGES_DIR):
    os.makedirs(IMAGES_DIR)
    os.makedirs(LABELS_DIR)

    classes = [str(i) for i in range(1, 257)]

    for class_id in classes:
        class_path = os.path.join(FOOD256_DIR, class_id, "bb_info.txt")
        with open(class_path, 'r') as file:
            # ignore headers
            file.readline()
            for line in file.readlines():
                line = line.strip().split()
                img_path = os.path.join(FOOD256_DIR, class_id, line[0]+".jpg")

                # copy img to images directory
                dest = os.path.join(IMAGES_DIR, line[0]+".jpg")
                shutil.copy(img_path, dest)

                # copy bounding box annotation into txt file in labels directory
                with open(os.path.join(LABELS_DIR, line[0]+".txt"), 'w') as box_file:
                    box = class_id + " " + " ".join(line[1:])
                    box_file.write(box)

# %% [markdown]
# **Define FoodDataset class as subclass of Dataset**

# %%
class FoodDataset(torch.utils.data.Dataset):
    def __init__(self, root, transform=None):
        self.root = root
        self.transform = transform
        self.images = list(sorted(os.listdir(os.path.join(root, "images"))))
        self.classes = []
        with open(os.path.join(root, "category.txt"), 'r') as file:
            file.readline()
            for line in file.readlines():
                self.classes.append(line.strip().split("\t")[1])
        
    def __getitem__(self, index):
        # image
        img_path = os.path.join(self.root, "images", self.images[index])
        img = Image.open(img_path).convert("RGB")
        
        #label
        lbl_path = img_path.replace("images", "labels").replace(".jpg", ".txt")
        with open(lbl_path, 'r') as file:
            line = file.read().split()
            
        lbl = int(line[0]) - 1
            
        x1 = float(line[1])
        y1 = float(line[2])
        x2 = float(line[3])
        y2 = float(line[4])

        target = {
            "image_id": torch.as_tensor([index]),
            "labels": torch.as_tensor([lbl], dtype=torch.int64),
            "boxes": torch.as_tensor([[x1, y1, x2, y2]], dtype=torch.float32),
            "area": torch.as_tensor([(x2-x1)*(y2-y1)]),
            "iscrowd": torch.as_tensor([0], dtype=torch.int64)
        }
        
        if self.transform is not None:
            img, target = self.transform(img, target)
            
        return img, target
        
    
    def __len__(self):
        return len(self.images)

# %% [markdown]
# **Format images**

# %%
# custom transform for R-CNN input
class CustomTransform:
    def __init__(self, image_size):
        self.image_size = image_size
        
    def __call__(self, img, target):
        # resize to a max of IMAGE_SIZE
        w, h = img.size
        scale = min(IMAGE_SIZE/w, IMAGE_SIZE/h)
        img = transforms.functional.resize(img, (int(h*scale), int(w*scale)))
        
        # update bounding boxes
        target["boxes"] *= scale
        
        # add padding to a size of IMAGE_SIZE
        img = transforms.functional.pad(img, (0, 0, IMAGE_SIZE-int(w*scale), IMAGE_SIZE-int(h*scale)))
        
        # convert to tensor
        img = transforms.functional.to_tensor(img)

        # normalize
        img = img / 255
        return img, target

transform = CustomTransform(image_size=IMAGE_SIZE)

food_raw = FoodDataset(FOOD256_DIR, transform=transform)
food_size = len(food_raw)

class_names = food_raw.classes

# %% [markdown]
# **Split dataset into train and val sets**

# %%
indices = torch.randperm(food_size).tolist()

# define how to batch data (i.e not combine target dicitonaries)
def collate_fn(batch):
    return tuple(zip(*batch))

# take 80% as training
train_raw = torch.utils.data.Subset(food_raw, indices[:int(0.8*food_size)])
train_size = len(train_raw)
train_loader = torch.utils.data.DataLoader(train_raw, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fn)

# take 20% as validation
val_raw = torch.utils.data.Subset(food_raw, indices[int(0.8*food_size):])
val_size = len(val_raw)
val_loader = torch.utils.data.DataLoader(val_raw, batch_size=max(1, BATCH_SIZE//2), shuffle=True, collate_fn=collate_fn)

# %% [markdown]
# **Show example image with bounding boxes**

# %%
fig, axis= plt.subplots(1)

#randomly select image from dataset
i = np.random.randint(train_size)
img = train_raw[i][0].numpy()
img = np.transpose(img, (1,2,0))
img = img * 255
img = np.clip(img, 0, 1)
plt.imshow(img)

# draw bounding box
x1, y1, x2, y2 = train_raw[i][1]["boxes"][0]
box = patches.Rectangle((x1, y1), x2-x1, y2-y1, linewidth=2, edgecolor='r', facecolor='none')
axis.add_patch(box)

plt.title(class_names[train_raw[i][1]["labels"][0]])

fig

# %% [markdown]
# # Model

# %% [markdown]
# **Fetch pretrained wide resnet on food101 dataset as backbone**

# %%
BACKBONE_PATH = os.path.join(ROOT_DIR, "models", "food_classification", "fine_tuning_wideres.pt")

print("Fetching pretrained backbone... ", end="")
backbone = torchvision.models.wide_resnet101_2(pretrained=False)

# replace classification head
num_features = backbone.fc.in_features
backbone.fc = torch.nn.Linear(num_features, 101)

# load trained weights
backbone.load_state_dict(torch.load(BACKBONE_PATH))

# remove classification head
backbone = torch.nn.Sequential(*list(backbone.children())[:-2])
backbone.out_channels = 2048

print("done")
# Out:
# Fetching pretrained backbone... done

# %% [markdown]
# **Create Faster R-CNN from wide resnet backbone**

# %%
print("Creating R-CNN... ", end="")
model = torchvision.models.detection.FasterRCNN(backbone, num_classes=len(class_names))

model = model.to(device)
print("done")
# Out:
# Creating R-CNN... done

# %% [markdown]
# # Train

# %% [markdown]
# **Declare optimizer**

# %%
learning_rate = 0.01

# fetch trainable parameters for transfer learning(where requires_grad = true)
params = [p for p in model.parameters() if p.requires_grad]

optimizer = torch.optim.SGD(params, lr=learning_rate)

# %% [markdown]
# **Train model**

# %%
num_epochs = 5

for epoch in range(num_epochs):
    train_one_epoch(model, optimizer, train_loader, device, epoch, print_freq=10)
    evaluate(model, val_loader, device)
# Out:
# Epoch: [5]  [    0/23117]  eta: 12:18:45  lr: 0.010000  loss: 15.1717 (15.1717)  loss_classifier: 5.5978 (5.5978)  loss_box_reg: 0.0000 (0.0000)  loss_objectness: 0.6115 (0.6115)  loss_rpn_box_reg: 8.9624 (8.9624)  time: 1.9175  data: 0.0905  max mem: 4262
# Epoch: [5]  [   10/23117]  eta: 4:32:26  lr: 0.010000  loss: 5.9187 (7.7618)  loss_classifier: 0.5604 (1.4514)  loss_box_reg: 0.0061 (0.0173)  loss_objectness: 0.3257 (0.3544)  loss_rpn_box_reg: 5.4309 (5.9387)  time: 0.7074  data: 0.0923  max mem: 4926
# Epoch: [5]  [   20/23117]  eta: 4:11:08  lr: 0.010000  loss: 5.8056 (6.5430)  loss_classifier: 0.2556 (0.8481)  loss_box_reg: 0.0153 (0.0250)  loss_objectness: 0.2839 (0.3128)  loss_rpn_box_reg: 5.2674 (5.3571)  time: 0.5892  data: 0.0944  max mem: 4926
# Epoch: [5]  [   30/23117]  eta: 4:04:30  lr: 0.010000  loss: 4.8225 (5.7609)  loss_classifier: 0.1384 (0.6371)  loss_box_reg: 0.0284 (0.0286)  loss_objectness: 0.2164 (0.2783)  loss_rpn_box_reg: 4.2083 (4.8169)  time: 0.5958  data: 0.1006  max mem: 4926
# Epoch: [5]  [   40/23117]  eta: 3:59:46  lr: 0.010000  loss: 3.5504 (5.2215)  loss_classifier: 0.1640 (0.5217)  loss_box_reg: 0.0296 (0.0296)  loss_objectness: 0.2015 (0.2594)  loss_rpn_box_reg: 3.1947 (4.4108)  time: 0.5930  data: 0.0971  max mem: 4926
# Epoch: [5]  [   50/23117]  eta: 3:57:11  lr: 0.010000  loss: 3.3348 (4.8121)  loss_classifier: 0.1626 (0.4483)  loss_box_reg: 0.0359 (0.0303)  loss_objectness: 0.1829 (0.2480)  loss_rpn_box_reg: 3.0064 (4.0854)  time: 0.5883  data: 0.0908  max mem: 4926
# Epoch: [5]  [   60/23117]  eta: 3:54:41  lr: 0.010000  loss: 3.0116 (4.5128)  loss_classifier: 0.1295 (0.3943)  loss_box_reg: 0.0279 (0.0305)  loss_objectness: 0.1698 (0.2378)  loss_rpn_box_reg: 2.6770 (3.8502)  time: 0.5847  data: 0.0850  max mem: 4926
# Epoch: [5]  [   70/23117]  eta: 3:53:14  lr: 0.010000  loss: 3.0661 (4.3392)  loss_classifier: 0.1057 (0.3560)  loss_box_reg: 0.0279 (0.0309)  loss_objectness: 0.1698 (0.2321)  loss_rpn_box_reg: 2.8600 (3.7202)  time: 0.5825  data: 0.0810  max mem: 4926
# Epoch: [5]  [   80/23117]  eta: 3:52:34  lr: 0.010000  loss: 3.1042 (4.1635)  loss_classifier: 0.1326 (0.3291)  loss_box_reg: 0.0427 (0.0324)  loss_objectness: 0.1361 (0.2229)  loss_rpn_box_reg: 2.8536 (3.5791)  time: 0.5907  data: 0.0883  max mem: 4926
# Epoch: [5]  [   90/23117]  eta: 3:51:45  lr: 0.010000  loss: 2.9187 (4.0570)  loss_classifier: 0.1326 (0.3049)  loss_box_reg: 0.0427 (0.0324)  loss_objectness: 0.1415 (0.2189)  loss_rpn_box_reg: 2.7044 (3.5008)  time: 0.5920  data: 0.0881  max mem: 4926
# Epoch: [5]  [  100/23117]  eta: 3:51:30  lr: 0.010000  loss: 2.8741 (3.9010)  loss_classifier: 0.1146 (0.2848)  loss_box_reg: 0.0333 (0.0320)  loss_objectness: 0.1426 (0.2157)  loss_rpn_box_reg: 2.4904 (3.3684)  time: 0.5943  data: 0.0890  max mem: 4926
# Epoch: [5]  [  110/23117]  eta: 3:50:43  lr: 0.010000  loss: 2.3378 (3.7568)  loss_classifier: 0.0928 (0.2676)  loss_box_reg: 0.0284 (0.0317)  loss_objectness: 0.1371 (0.2089)  loss_rpn_box_reg: 2.0452 (3.2486)  time: 0.5919  data: 0.0856  max mem: 4926
# Epoch: [5]  [  120/23117]  eta: 3:50:22  lr: 0.010000  loss: 2.1429 (3.6495)  loss_classifier: 0.1030 (0.2557)  loss_box_reg: 0.0333 (0.0325)  loss_objectness: 0.1364 (0.2033)  loss_rpn_box_reg: 1.8387 (3.1580)  time: 0.5887  data: 0.0811  max mem: 4926
# Epoch: [5]  [  130/23117]  eta: 3:50:14  lr: 0.010000  loss: 2.2721 (3.5489)  loss_classifier: 0.1097 (0.2449)  loss_box_reg: 0.0417 (0.0332)  loss_objectness: 0.1472 (0.1991)  loss_rpn_box_reg: 2.0224 (3.0717)  time: 0.5968  data: 0.0882  max mem: 4926
# Epoch: [5]  [  140/23117]  eta: 3:50:14  lr: 0.010000  loss: 2.2468 (3.4467)  loss_classifier: 0.1093 (0.2358)  loss_box_reg: 0.0436 (0.0334)  loss_objectness: 0.1197 (0.1925)  loss_rpn_box_reg: 1.9573 (2.9850)  time: 0.6023  data: 0.0909  max mem: 4926
# Epoch: [5]  [  150/23117]  eta: 3:50:19  lr: 0.010000  loss: 2.1649 (3.3701)  loss_classifier: 0.1069 (0.2274)  loss_box_reg: 0.0363 (0.0338)  loss_objectness: 0.1219 (0.1893)  loss_rpn_box_reg: 1.9081 (2.9197)  time: 0.6064  data: 0.0898  max mem: 4926
# Epoch: [5]  [  160/23117]  eta: 3:50:33  lr: 0.010000  loss: 2.1274 (3.2948)  loss_classifier: 0.1102 (0.2200)  loss_box_reg: 0.0347 (0.0337)  loss_objectness: 0.1322 (0.1880)  loss_rpn_box_reg: 1.8474 (2.8532)  time: 0.6121  data: 0.0927  max mem: 4926
# Epoch: [5]  [  170/23117]  eta: 3:50:46  lr: 0.010000  loss: 2.0499 (3.2293)  loss_classifier: 0.0952 (0.2120)  loss_box_reg: 0.0297 (0.0332)  loss_objectness: 0.1478 (0.1883)  loss_rpn_box_reg: 1.7626 (2.7957)  time: 0.6162  data: 0.0927  max mem: 4926
# Epoch: [5]  [  180/23117]  eta: 3:50:53  lr: 0.010000  loss: 1.9002 (3.1693)  loss_classifier: 0.0879 (0.2048)  loss_box_reg: 0.0244 (0.0326)  loss_objectness: 0.1249 (0.1852)  loss_rpn_box_reg: 1.6824 (2.7468)  time: 0.6152  data: 0.0900  max mem: 4926
# Epoch: [5]  [  190/23117]  eta: 3:50:51  lr: 0.010000  loss: 1.9770 (3.1150)  loss_classifier: 0.0916 (0.1994)  loss_box_reg: 0.0267 (0.0324)  loss_objectness: 0.1013 (0.1836)  loss_rpn_box_reg: 1.7340 (2.6996)  time: 0.6108  data: 0.0863  max mem: 4926
# Epoch: [5]  [  200/23117]  eta: 3:50:45  lr: 0.010000  loss: 1.9770 (3.0607)  loss_classifier: 0.0965 (0.1945)  loss_box_reg: 0.0307 (0.0325)  loss_objectness: 0.1010 (0.1806)  loss_rpn_box_reg: 1.7340 (2.6531)  time: 0.6057  data: 0.0785  max mem: 4926
# Epoch: [5]  [  210/23117]  eta: 3:50:49  lr: 0.010000  loss: 1.9425 (3.0069)  loss_classifier: 0.0965 (0.1899)  loss_box_reg: 0.0254 (0.0324)  loss_objectness: 0.1268 (0.1827)  loss_rpn_box_reg: 1.6009 (2.6019)  time: 0.6088  data: 0.0823  max mem: 4926
# Epoch: [5]  [  220/23117]  eta: 3:50:47  lr: 0.010000  loss: 1.9926 (2.9759)  loss_classifier: 0.0910 (0.1859)  loss_box_reg: 0.0286 (0.0323)  loss_objectness: 0.1153 (0.1800)  loss_rpn_box_reg: 1.6882 (2.5777)  time: 0.6109  data: 0.0822  max mem: 4926
# Epoch: [5]  [  230/23117]  eta: 3:50:39  lr: 0.010000  loss: 2.1206 (2.9397)  loss_classifier: 0.1067 (0.1826)  loss_box_reg: 0.0339 (0.0325)  loss_objectness: 0.1036 (0.1795)  loss_rpn_box_reg: 1.8570 (2.5451)  time: 0.6057  data: 0.0747  max mem: 4926
# Epoch: [5]  [  240/23117]  eta: 3:50:33  lr: 0.010000  loss: 2.2054 (2.9148)  loss_classifier: 0.1067 (0.1789)  loss_box_reg: 0.0343 (0.0323)  loss_objectness: 0.1113 (0.1775)  loss_rpn_box_reg: 1.9674 (2.5261)  time: 0.6038  data: 0.0742  max mem: 4926
# Epoch: [5]  [  250/23117]  eta: 3:50:36  lr: 0.010000  loss: 1.8190 (2.8664)  loss_classifier: 0.1085 (0.1764)  loss_box_reg: 0.0343 (0.0325)  loss_objectness: 0.1169 (0.1767)  loss_rpn_box_reg: 1.6023 (2.4808)  time: 0.6095  data: 0.0805  max mem: 4926
# Epoch: [5]  [  260/23117]  eta: 3:50:36  lr: 0.010000  loss: 1.8006 (2.8364)  loss_classifier: 0.1112 (0.1736)  loss_box_reg: 0.0368 (0.0325)  loss_objectness: 0.1155 (0.1751)  loss_rpn_box_reg: 1.4691 (2.4553)  time: 0.6134  data: 0.0851  max mem: 4926
# Epoch: [5]  [  270/23117]  eta: 3:50:26  lr: 0.010000  loss: 2.0074 (2.8079)  loss_classifier: 0.1112 (0.1712)  loss_box_reg: 0.0374 (0.0326)  loss_objectness: 0.1260 (0.1756)  loss_rpn_box_reg: 1.7210 (2.4285)  time: 0.6062  data: 0.0773  max mem: 4926
# Epoch: [5]  [  280/23117]  eta: 3:50:25  lr: 0.010000  loss: 2.0610 (2.7775)  loss_classifier: 0.0833 (0.1680)  loss_box_reg: 0.0230 (0.0323)  loss_objectness: 0.1413 (0.1751)  loss_rpn_box_reg: 1.6792 (2.4021)  time: 0.6058  data: 0.0770  max mem: 4926
# Epoch: [5]  [  290/23117]  eta: 3:50:18  lr: 0.010000  loss: 1.8801 (2.7471)  loss_classifier: 0.0982 (0.1662)  loss_box_reg: 0.0296 (0.0325)  loss_objectness: 0.1097 (0.1733)  loss_rpn_box_reg: 1.6093 (2.3751)  time: 0.6077  data: 0.0789  max mem: 4926
# Epoch: [5]  [  300/23117]  eta: 3:50:17  lr: 0.010000  loss: 1.6749 (2.7166)  loss_classifier: 0.0982 (0.1637)  loss_box_reg: 0.0292 (0.0323)  loss_objectness: 0.1040 (0.1733)  loss_rpn_box_reg: 1.4410 (2.3473)  time: 0.6084  data: 0.0781  max mem: 4926
# Epoch: [5]  [  310/23117]  eta: 3:50:21  lr: 0.010000  loss: 1.5292 (2.6867)  loss_classifier: 0.0910 (0.1616)  loss_box_reg: 0.0269 (0.0322)  loss_objectness: 0.1022 (0.1714)  loss_rpn_box_reg: 1.3630 (2.3214)  time: 0.6159  data: 0.0841  max mem: 4926
# Epoch: [5]  [  320/23117]  eta: 3:50:19  lr: 0.010000  loss: 1.5401 (2.6584)  loss_classifier: 0.0924 (0.1601)  loss_box_reg: 0.0279 (0.0324)  loss_objectness: 0.1082 (0.1710)  loss_rpn_box_reg: 1.3221 (2.2949)  time: 0.6156  data: 0.0845  max mem: 4926
# Epoch: [5]  [  330/23117]  eta: 3:50:22  lr: 0.010000  loss: 1.6281 (2.6285)  loss_classifier: 0.0964 (0.1584)  loss_box_reg: 0.0317 (0.0324)  loss_objectness: 0.0973 (0.1688)  loss_rpn_box_reg: 1.3221 (2.2689)  time: 0.6157  data: 0.0860  max mem: 4926
# Epoch: [5]  [  340/23117]  eta: 3:50:15  lr: 0.010000  loss: 1.8278 (2.6124)  loss_classifier: 0.1001 (0.1569)  loss_box_reg: 0.0343 (0.0324)  loss_objectness: 0.0973 (0.1681)  loss_rpn_box_reg: 1.5896 (2.2550)  time: 0.6120  data: 0.0821  max mem: 4926
# Epoch: [5]  [  350/23117]  eta: 3:50:22  lr: 0.010000  loss: 1.8201 (2.5839)  loss_classifier: 0.0975 (0.1554)  loss_box_reg: 0.0366 (0.0325)  loss_objectness: 0.0978 (0.1664)  loss_rpn_box_reg: 1.5581 (2.2295)  time: 0.6159  data: 0.0856  max mem: 4926
# Epoch: [5]  [  360/23117]  eta: 3:50:13  lr: 0.010000  loss: 1.7719 (2.5636)  loss_classifier: 0.0977 (0.1541)  loss_box_reg: 0.0389 (0.0327)  loss_objectness: 0.0860 (0.1648)  loss_rpn_box_reg: 1.5055 (2.2120)  time: 0.6149  data: 0.0848  max mem: 4926
# Epoch: [5]  [  370/23117]  eta: 3:50:02  lr: 0.010000  loss: 1.8457 (2.5528)  loss_classifier: 0.0977 (0.1527)  loss_box_reg: 0.0382 (0.0326)  loss_objectness: 0.0991 (0.1654)  loss_rpn_box_reg: 1.5701 (2.2021)  time: 0.6006  data: 0.0708  max mem: 4926
# Epoch: [5]  [  380/23117]  eta: 3:49:55  lr: 0.010000  loss: 1.9762 (2.5467)  loss_classifier: 0.0954 (0.1511)  loss_box_reg: 0.0297 (0.0326)  loss_objectness: 0.1065 (0.1648)  loss_rpn_box_reg: 1.7152 (2.1982)  time: 0.6021  data: 0.0723  max mem: 4926
# Epoch: [5]  [  390/23117]  eta: 3:49:50  lr: 0.010000  loss: 1.9615 (2.5301)  loss_classifier: 0.0959 (0.1500)  loss_box_reg: 0.0297 (0.0325)  loss_objectness: 0.1065 (0.1635)  loss_rpn_box_reg: 1.7152 (2.1841)  time: 0.6073  data: 0.0779  max mem: 4926
# Epoch: [5]  [  400/23117]  eta: 3:49:44  lr: 0.010000  loss: 1.9372 (2.5175)  loss_classifier: 0.0959 (0.1486)  loss_box_reg: 0.0295 (0.0324)  loss_objectness: 0.1349 (0.1629)  loss_rpn_box_reg: 1.6959 (2.1736)  time: 0.6076  data: 0.0791  max mem: 4926
# Epoch: [5]  [  410/23117]  eta: 3:49:44  lr: 0.010000  loss: 1.9775 (2.5045)  loss_classifier: 0.0832 (0.1472)  loss_box_reg: 0.0275 (0.0323)  loss_objectness: 0.1393 (0.1625)  loss_rpn_box_reg: 1.7209 (2.1625)  time: 0.6119  data: 0.0822  max mem: 4926
# Epoch: [5]  [  420/23117]  eta: 3:49:38  lr: 0.010000  loss: 1.6525 (2.4843)  loss_classifier: 0.0928 (0.1460)  loss_box_reg: 0.0287 (0.0322)  loss_objectness: 0.1016 (0.1619)  loss_rpn_box_reg: 1.5199 (2.1442)  time: 0.6126  data: 0.0824  max mem: 4926
# Epoch: [5]  [  430/23117]  eta: 3:49:34  lr: 0.010000  loss: 1.5690 (2.4655)  loss_classifier: 0.1078 (0.1455)  loss_box_reg: 0.0347 (0.0324)  loss_objectness: 0.0977 (0.1611)  loss_rpn_box_reg: 1.3122 (2.1264)  time: 0.6089  data: 0.0789  max mem: 4926
# Epoch: [5]  [  440/23117]  eta: 3:49:26  lr: 0.010000  loss: 1.6049 (2.4463)  loss_classifier: 0.1017 (0.1444)  loss_box_reg: 0.0341 (0.0323)  loss_objectness: 0.0859 (0.1604)  loss_rpn_box_reg: 1.3122 (2.1093)  time: 0.6073  data: 0.0779  max mem: 4926
# Epoch: [5]  [  450/23117]  eta: 3:49:19  lr: 0.010000  loss: 1.5550 (2.4292)  loss_classifier: 0.0935 (0.1434)  loss_box_reg: 0.0263 (0.0323)  loss_objectness: 0.0905 (0.1593)  loss_rpn_box_reg: 1.2662 (2.0941)  time: 0.6045  data: 0.0750  max mem: 4926
# Epoch: [5]  [  460/23117]  eta: 3:49:19  lr: 0.010000  loss: 1.6347 (2.4253)  loss_classifier: 0.0945 (0.1423)  loss_box_reg: 0.0289 (0.0323)  loss_objectness: 0.1285 (0.1597)  loss_rpn_box_reg: 1.4752 (2.0910)  time: 0.6121  data: 0.0821  max mem: 4926
# Epoch: [5]  [  470/23117]  eta: 3:49:14  lr: 0.010000  loss: 1.9023 (2.4129)  loss_classifier: 0.1057 (0.1416)  loss_box_reg: 0.0307 (0.0324)  loss_objectness: 0.1306 (0.1593)  loss_rpn_box_reg: 1.6674 (2.0796)  time: 0.6144  data: 0.0848  max mem: 4926
# Epoch: [5]  [  480/23117]  eta: 3:49:09  lr: 0.010000  loss: 1.8021 (2.4019)  loss_classifier: 0.1057 (0.1408)  loss_box_reg: 0.0307 (0.0324)  loss_objectness: 0.1338 (0.1590)  loss_rpn_box_reg: 1.5567 (2.0698)  time: 0.6095  data: 0.0800  max mem: 4926
# Epoch: [5]  [  490/23117]  eta: 3:49:04  lr: 0.010000  loss: 1.5778 (2.3885)  loss_classifier: 0.0886 (0.1395)  loss_box_reg: 0.0250 (0.0321)  loss_objectness: 0.1448 (0.1595)  loss_rpn_box_reg: 1.3051 (2.0574)  time: 0.6102  data: 0.0814  max mem: 4926
# Epoch: [5]  [  500/23117]  eta: 3:48:54  lr: 0.010000  loss: 1.5474 (2.3784)  loss_classifier: 0.0886 (0.1389)  loss_box_reg: 0.0250 (0.0322)  loss_objectness: 0.1239 (0.1593)  loss_rpn_box_reg: 1.2830 (2.0480)  time: 0.6045  data: 0.0759  max mem: 4926
# Epoch: [5]  [  510/23117]  eta: 3:48:48  lr: 0.010000  loss: 1.6874 (2.3634)  loss_classifier: 0.1090 (0.1382)  loss_box_reg: 0.0333 (0.0322)  loss_objectness: 0.1098 (0.1591)  loss_rpn_box_reg: 1.4266 (2.0340)  time: 0.6023  data: 0.0729  max mem: 4926
# Epoch: [5]  [  520/23117]  eta: 3:48:41  lr: 0.010000  loss: 1.5957 (2.3479)  loss_classifier: 0.1037 (0.1373)  loss_box_reg: 0.0317 (0.0321)  loss_objectness: 0.0950 (0.1582)  loss_rpn_box_reg: 1.2874 (2.0203)  time: 0.6063  data: 0.0766  max mem: 4926
# Epoch: [5]  [  530/23117]  eta: 3:48:38  lr: 0.010000  loss: 1.4650 (2.3358)  loss_classifier: 0.0930 (0.1364)  loss_box_reg: 0.0248 (0.0319)  loss_objectness: 0.0928 (0.1584)  loss_rpn_box_reg: 1.2513 (2.0090)  time: 0.6096  data: 0.0808  max mem: 4926
# Epoch: [5]  [  540/23117]  eta: 3:48:33  lr: 0.010000  loss: 1.5024 (2.3228)  loss_classifier: 0.0906 (0.1354)  loss_box_reg: 0.0226 (0.0318)  loss_objectness: 0.1209 (0.1583)  loss_rpn_box_reg: 1.2348 (1.9973)  time: 0.6125  data: 0.0837  max mem: 4926
# Epoch: [5]  [  550/23117]  eta: 3:48:24  lr: 0.010000  loss: 1.4379 (2.3106)  loss_classifier: 0.0914 (0.1347)  loss_box_reg: 0.0288 (0.0317)  loss_objectness: 0.1057 (0.1585)  loss_rpn_box_reg: 1.2223 (1.9857)  time: 0.6059  data: 0.0766  max mem: 4926
# Epoch: [5]  [  560/23117]  eta: 3:48:27  lr: 0.010000  loss: 1.4877 (2.3042)  loss_classifier: 0.0934 (0.1341)  loss_box_reg: 0.0324 (0.0317)  loss_objectness: 0.1080 (0.1583)  loss_rpn_box_reg: 1.2237 (1.9801)  time: 0.6139  data: 0.0843  max mem: 4926
# Epoch: [5]  [  570/23117]  eta: 3:48:21  lr: 0.010000  loss: 1.4977 (2.2900)  loss_classifier: 0.0887 (0.1333)  loss_box_reg: 0.0264 (0.0316)  loss_objectness: 0.1043 (0.1574)  loss_rpn_box_reg: 1.3376 (1.9676)  time: 0.6183  data: 0.0889  max mem: 4926
# Epoch: [5]  [  580/23117]  eta: 3:48:10  lr: 0.010000  loss: 1.6536 (2.2859)  loss_classifier: 0.0893 (0.1327)  loss_box_reg: 0.0256 (0.0316)  loss_objectness: 0.0933 (0.1571)  loss_rpn_box_reg: 1.3962 (1.9646)  time: 0.6017  data: 0.0720  max mem: 4926
# Epoch: [5]  [  590/23117]  eta: 3:48:04  lr: 0.010000  loss: 2.0591 (2.2797)  loss_classifier: 0.1074 (0.1324)  loss_box_reg: 0.0290 (0.0317)  loss_objectness: 0.1324 (0.1570)  loss_rpn_box_reg: 1.8103 (1.9586)  time: 0.6015  data: 0.0716  max mem: 4926
# Epoch: [5]  [  600/23117]  eta: 3:47:54  lr: 0.010000  loss: 1.7543 (2.2680)  loss_classifier: 0.1012 (0.1317)  loss_box_reg: 0.0290 (0.0315)  loss_objectness: 0.1208 (0.1572)  loss_rpn_box_reg: 1.4801 (1.9476)  time: 0.6030  data: 0.0736  max mem: 4926
# Epoch: [5]  [  610/23117]  eta: 3:47:47  lr: 0.010000  loss: 1.4518 (2.2622)  loss_classifier: 0.0865 (0.1312)  loss_box_reg: 0.0277 (0.0316)  loss_objectness: 0.1187 (0.1574)  loss_rpn_box_reg: 1.2234 (1.9420)  time: 0.6004  data: 0.0706  max mem: 4926
# Epoch: [5]  [  620/23117]  eta: 3:47:38  lr: 0.010000  loss: 1.4514 (2.2496)  loss_classifier: 0.0900 (0.1306)  loss_box_reg: 0.0253 (0.0316)  loss_objectness: 0.1187 (0.1565)  loss_rpn_box_reg: 1.1460 (1.9308)  time: 0.6018  data: 0.0719  max mem: 4926
# Epoch: [5]  [  630/23117]  eta: 3:47:31  lr: 0.010000  loss: 1.4206 (2.2376)  loss_classifier: 0.0935 (0.1300)  loss_box_reg: 0.0274 (0.0315)  loss_objectness: 0.1051 (0.1562)  loss_rpn_box_reg: 1.1573 (1.9199)  time: 0.6030  data: 0.0733  max mem: 4926
# Epoch: [5]  [  640/23117]  eta: 3:47:24  lr: 0.010000  loss: 1.5083 (2.2304)  loss_classifier: 0.0975 (0.1295)  loss_box_reg: 0.0274 (0.0315)  loss_objectness: 0.1100 (0.1562)  loss_rpn_box_reg: 1.2362 (1.9132)  time: 0.6045  data: 0.0750  max mem: 4926
# Epoch: [5]  [  650/23117]  eta: 3:47:17  lr: 0.010000  loss: 1.6194 (2.2235)  loss_classifier: 0.1085 (0.1294)  loss_box_reg: 0.0340 (0.0316)  loss_objectness: 0.1128 (0.1558)  loss_rpn_box_reg: 1.3347 (1.9066)  time: 0.6045  data: 0.0753  max mem: 4926
# Epoch: [5]  [  660/23117]  eta: 3:47:10  lr: 0.010000  loss: 1.6410 (2.2157)  loss_classifier: 0.1035 (0.1288)  loss_box_reg: 0.0350 (0.0316)  loss_objectness: 0.1128 (0.1563)  loss_rpn_box_reg: 1.3424 (1.8990)  time: 0.6042  data: 0.0749  max mem: 4926
# Epoch: [5]  [  670/23117]  eta: 3:47:04  lr: 0.010000  loss: 1.5291 (2.2075)  loss_classifier: 0.1111 (0.1287)  loss_box_reg: 0.0381 (0.0317)  loss_objectness: 0.1194 (0.1560)  loss_rpn_box_reg: 1.2803 (1.8911)  time: 0.6052  data: 0.0714  max mem: 4926
# Epoch: [5]  [  680/23117]  eta: 3:47:03  lr: 0.010000  loss: 1.5652 (2.1984)  loss_classifier: 0.1170 (0.1283)  loss_box_reg: 0.0321 (0.0317)  loss_objectness: 0.1057 (0.1553)  loss_rpn_box_reg: 1.3137 (1.8831)  time: 0.6143  data: 0.0758  max mem: 4926
# Epoch: [5]  [  690/23117]  eta: 3:46:56  lr: 0.010000  loss: 1.5762 (2.1934)  loss_classifier: 0.1013 (0.1278)  loss_box_reg: 0.0320 (0.0317)  loss_objectness: 0.1255 (0.1555)  loss_rpn_box_reg: 1.3392 (1.8784)  time: 0.6133  data: 0.0785  max mem: 4926
# Epoch: [5]  [  700/23117]  eta: 3:46:48  lr: 0.010000  loss: 1.7902 (2.1924)  loss_classifier: 0.1013 (0.1274)  loss_box_reg: 0.0320 (0.0316)  loss_objectness: 0.1343 (0.1554)  loss_rpn_box_reg: 1.5072 (1.8780)  time: 0.6027  data: 0.0719  max mem: 4926
# Epoch: [5]  [  710/23117]  eta: 3:46:40  lr: 0.010000  loss: 1.7541 (2.1882)  loss_classifier: 0.1058 (0.1271)  loss_box_reg: 0.0332 (0.0316)  loss_objectness: 0.1168 (0.1556)  loss_rpn_box_reg: 1.4389 (1.8739)  time: 0.6003  data: 0.0686  max mem: 4926
# Epoch: [5]  [  720/23117]  eta: 3:46:31  lr: 0.010000  loss: 1.6899 (2.1828)  loss_classifier: 0.1110 (0.1266)  loss_box_reg: 0.0332 (0.0316)  loss_objectness: 0.1118 (0.1557)  loss_rpn_box_reg: 1.3845 (1.8688)  time: 0.5997  data: 0.0675  max mem: 4926
# Epoch: [5]  [  730/23117]  eta: 3:46:26  lr: 0.010000  loss: 1.6899 (2.1743)  loss_classifier: 0.0924 (0.1262)  loss_box_reg: 0.0309 (0.0316)  loss_objectness: 0.0959 (0.1553)  loss_rpn_box_reg: 1.3622 (1.8612)  time: 0.6040  data: 0.0717  max mem: 4926
# Epoch: [5]  [  740/23117]  eta: 3:46:21  lr: 0.010000  loss: 1.7887 (2.1704)  loss_classifier: 0.1017 (0.1258)  loss_box_reg: 0.0353 (0.0316)  loss_objectness: 0.1240 (0.1554)  loss_rpn_box_reg: 1.4533 (1.8576)  time: 0.6095  data: 0.0769  max mem: 4926
# Epoch: [5]  [  750/23117]  eta: 3:46:15  lr: 0.010000  loss: 1.3996 (2.1605)  loss_classifier: 0.0996 (0.1255)  loss_box_reg: 0.0309 (0.0316)  loss_objectness: 0.0975 (0.1548)  loss_rpn_box_reg: 1.1607 (1.8485)  time: 0.6094  data: 0.0773  max mem: 4926
# Epoch: [5]  [  760/23117]  eta: 3:46:10  lr: 0.010000  loss: 1.1837 (2.1478)  loss_classifier: 0.1073 (0.1253)  loss_box_reg: 0.0309 (0.0317)  loss_objectness: 0.0811 (0.1538)  loss_rpn_box_reg: 0.9490 (1.8370)  time: 0.6094  data: 0.0786  max mem: 4926
# Epoch: [5]  [  770/23117]  eta: 3:46:01  lr: 0.010000  loss: 1.2619 (2.1374)  loss_classifier: 0.1058 (0.1250)  loss_box_reg: 0.0333 (0.0317)  loss_objectness: 0.0731 (0.1531)  loss_rpn_box_reg: 1.0351 (1.8277)  time: 0.6032  data: 0.0723  max mem: 4926
# Epoch: [5]  [  780/23117]  eta: 3:45:53  lr: 0.010000  loss: 1.4556 (2.1307)  loss_classifier: 0.0948 (0.1245)  loss_box_reg: 0.0297 (0.0316)  loss_objectness: 0.0895 (0.1530)  loss_rpn_box_reg: 1.1726 (1.8216)  time: 0.5985  data: 0.0671  max mem: 4926
# Epoch: [5]  [  790/23117]  eta: 3:45:44  lr: 0.010000  loss: 1.6269 (2.1236)  loss_classifier: 0.1009 (0.1244)  loss_box_reg: 0.0290 (0.0317)  loss_objectness: 0.0977 (0.1528)  loss_rpn_box_reg: 1.2007 (1.8147)  time: 0.5994  data: 0.0671  max mem: 4926
# Epoch: [5]  [  800/23117]  eta: 3:45:40  lr: 0.010000  loss: 1.3968 (2.1155)  loss_classifier: 0.0966 (0.1240)  loss_box_reg: 0.0266 (0.0316)  loss_objectness: 0.0973 (0.1524)  loss_rpn_box_reg: 1.1064 (1.8074)  time: 0.6046  data: 0.0703  max mem: 4926
# Epoch: [5]  [  810/23117]  eta: 3:45:33  lr: 0.010000  loss: 1.2763 (2.1065)  loss_classifier: 0.0862 (0.1236)  loss_box_reg: 0.0266 (0.0316)  loss_objectness: 0.0877 (0.1522)  loss_rpn_box_reg: 1.0103 (1.7992)  time: 0.6085  data: 0.0748  max mem: 4926
# Epoch: [5]  [  820/23117]  eta: 3:45:25  lr: 0.010000  loss: 1.7126 (2.1089)  loss_classifier: 0.0934 (0.1232)  loss_box_reg: 0.0296 (0.0315)  loss_objectness: 0.1049 (0.1520)  loss_rpn_box_reg: 1.4923 (1.8021)  time: 0.6019  data: 0.0697  max mem: 4926
# Epoch: [5]  [  830/23117]  eta: 3:45:17  lr: 0.010000  loss: 1.7126 (2.1013)  loss_classifier: 0.0934 (0.1231)  loss_box_reg: 0.0310 (0.0316)  loss_objectness: 0.1049 (0.1516)  loss_rpn_box_reg: 1.4923 (1.7950)  time: 0.5983  data: 0.0663  max mem: 4926
# Epoch: [5]  [  840/23117]  eta: 3:45:12  lr: 0.010000  loss: 1.2890 (2.0919)  loss_classifier: 0.1023 (0.1228)  loss_box_reg: 0.0345 (0.0316)  loss_objectness: 0.0794 (0.1512)  loss_rpn_box_reg: 1.0841 (1.7863)  time: 0.6054  data: 0.0726  max mem: 4926
# Epoch: [5]  [  850/23117]  eta: 3:45:05  lr: 0.010000  loss: 1.3752 (2.0876)  loss_classifier: 0.0996 (0.1224)  loss_box_reg: 0.0292 (0.0315)  loss_objectness: 0.0858 (0.1518)  loss_rpn_box_reg: 1.0787 (1.7819)  time: 0.6082  data: 0.0708  max mem: 4926
# Epoch: [5]  [  860/23117]  eta: 3:45:04  lr: 0.010000  loss: 1.3928 (2.0791)  loss_classifier: 0.0996 (0.1221)  loss_box_reg: 0.0292 (0.0315)  loss_objectness: 0.1111 (0.1515)  loss_rpn_box_reg: 1.0995 (1.7740)  time: 0.6148  data: 0.0744  max mem: 4926
# Epoch: [5]  [  870/23117]  eta: 3:45:00  lr: 0.010000  loss: 1.2730 (2.0695)  loss_classifier: 0.0955 (0.1218)  loss_box_reg: 0.0299 (0.0314)  loss_objectness: 0.0979 (0.1510)  loss_rpn_box_reg: 1.0299 (1.7652)  time: 0.6199  data: 0.0809  max mem: 4926
# Epoch: [5]  [  880/23117]  eta: 3:44:59  lr: 0.010000  loss: 1.2351 (2.0602)  loss_classifier: 0.0955 (0.1215)  loss_box_reg: 0.0274 (0.0314)  loss_objectness: 0.0999 (0.1510)  loss_rpn_box_reg: 0.9334 (1.7563)  time: 0.6203  data: 0.0809  max mem: 4926
# Epoch: [5]  [  890/23117]  eta: 3:44:53  lr: 0.010000  loss: 1.2496 (2.0522)  loss_classifier: 0.1090 (0.1214)  loss_box_reg: 0.0290 (0.0315)  loss_objectness: 0.1132 (0.1504)  loss_rpn_box_reg: 0.9628 (1.7489)  time: 0.6177  data: 0.0798  max mem: 4926
# Epoch: [5]  [  900/23117]  eta: 3:44:50  lr: 0.010000  loss: 1.2686 (2.0452)  loss_classifier: 0.1122 (0.1213)  loss_box_reg: 0.0386 (0.0315)  loss_objectness: 0.0852 (0.1499)  loss_rpn_box_reg: 1.0521 (1.7425)  time: 0.6147  data: 0.0769  max mem: 4926
# Epoch: [5]  [  910/23117]  eta: 3:44:48  lr: 0.010000  loss: 1.3195 (2.0398)  loss_classifier: 0.1043 (0.1210)  loss_box_reg: 0.0310 (0.0315)  loss_objectness: 0.0846 (0.1492)  loss_rpn_box_reg: 1.0961 (1.7381)  time: 0.6201  data: 0.0778  max mem: 4926
# Epoch: [5]  [  920/23117]  eta: 3:44:42  lr: 0.010000  loss: 1.3466 (2.0321)  loss_classifier: 0.0988 (0.1208)  loss_box_reg: 0.0324 (0.0316)  loss_objectness: 0.0789 (0.1489)  loss_rpn_box_reg: 1.0978 (1.7309)  time: 0.6153  data: 0.0699  max mem: 4926
# Epoch: [5]  [  930/23117]  eta: 3:44:36  lr: 0.010000  loss: 0.9705 (2.0226)  loss_classifier: 0.1015 (0.1207)  loss_box_reg: 0.0344 (0.0316)  loss_objectness: 0.0805 (0.1483)  loss_rpn_box_reg: 0.7590 (1.7220)  time: 0.6087  data: 0.0702  max mem: 4926
# Epoch: [5]  [  940/23117]  eta: 3:44:26  lr: 0.010000  loss: 1.1274 (2.0183)  loss_classifier: 0.1015 (0.1204)  loss_box_reg: 0.0317 (0.0316)  loss_objectness: 0.0829 (0.1478)  loss_rpn_box_reg: 0.8729 (1.7185)  time: 0.5999  data: 0.0672  max mem: 4926
# Epoch: [5]  [  950/23117]  eta: 3:44:17  lr: 0.010000  loss: 1.5124 (2.0161)  loss_classifier: 0.1007 (0.1202)  loss_box_reg: 0.0328 (0.0316)  loss_objectness: 0.0959 (0.1477)  loss_rpn_box_reg: 1.3375 (1.7166)  time: 0.5918  data: 0.0577  max mem: 4926
# Epoch: [5]  [  960/23117]  eta: 3:44:10  lr: 0.010000  loss: 1.3879 (2.0130)  loss_classifier: 0.1065 (0.1201)  loss_box_reg: 0.0328 (0.0316)  loss_objectness: 0.1006 (0.1476)  loss_rpn_box_reg: 1.1839 (1.7138)  time: 0.5977  data: 0.0635  max mem: 4926
# Epoch: [5]  [  970/23117]  eta: 3:44:05  lr: 0.010000  loss: 1.3617 (2.0072)  loss_classifier: 0.1065 (0.1198)  loss_box_reg: 0.0320 (0.0316)  loss_objectness: 0.0856 (0.1470)  loss_rpn_box_reg: 1.1269 (1.7089)  time: 0.6088  data: 0.0750  max mem: 4926
# Epoch: [5]  [  980/23117]  eta: 3:43:58  lr: 0.010000  loss: 1.2918 (1.9994)  loss_classifier: 0.0962 (0.1194)  loss_box_reg: 0.0269 (0.0315)  loss_objectness: 0.0856 (0.1472)  loss_rpn_box_reg: 1.0758 (1.7013)  time: 0.6071  data: 0.0735  max mem: 4926
# Epoch: [5]  [  990/23117]  eta: 3:43:49  lr: 0.010000  loss: 1.3054 (1.9973)  loss_classifier: 0.0923 (0.1193)  loss_box_reg: 0.0278 (0.0315)  loss_objectness: 0.0940 (0.1470)  loss_rpn_box_reg: 1.0758 (1.6995)  time: 0.5987  data: 0.0648  max mem: 4926
# Epoch: [5]  [ 1000/23117]  eta: 3:43:42  lr: 0.010000  loss: 1.1978 (1.9915)  loss_classifier: 0.1109 (0.1191)  loss_box_reg: 0.0320 (0.0315)  loss_objectness: 0.0886 (0.1469)  loss_rpn_box_reg: 0.9763 (1.6940)  time: 0.5998  data: 0.0664  max mem: 4926
# Epoch: [5]  [ 1010/23117]  eta: 3:43:35  lr: 0.010000  loss: 1.1437 (1.9851)  loss_classifier: 0.1076 (0.1191)  loss_box_reg: 0.0341 (0.0315)  loss_objectness: 0.0798 (0.1464)  loss_rpn_box_reg: 0.9021 (1.6882)  time: 0.6021  data: 0.0691  max mem: 4926
# Epoch: [5]  [ 1020/23117]  eta: 3:43:29  lr: 0.010000  loss: 1.2755 (1.9791)  loss_classifier: 0.1033 (0.1190)  loss_box_reg: 0.0330 (0.0316)  loss_objectness: 0.0798 (0.1459)  loss_rpn_box_reg: 1.1120 (1.6825)  time: 0.6035  data: 0.0710  max mem: 4926
# Epoch: [5]  [ 1030/23117]  eta: 3:43:18  lr: 0.010000  loss: 1.2705 (1.9725)  loss_classifier: 0.1033 (0.1188)  loss_box_reg: 0.0322 (0.0316)  loss_objectness: 0.0827 (0.1456)  loss_rpn_box_reg: 1.0384 (1.6765)  time: 0.5951  data: 0.0626  max mem: 4926
# Epoch: [5]  [ 1040/23117]  eta: 3:43:12  lr: 0.010000  loss: 1.2830 (1.9717)  loss_classifier: 0.0954 (0.1186)  loss_box_reg: 0.0247 (0.0316)  loss_objectness: 0.1047 (0.1456)  loss_rpn_box_reg: 1.0244 (1.6760)  time: 0.5964  data: 0.0646  max mem: 4926
# Epoch: [5]  [ 1050/23117]  eta: 3:43:05  lr: 0.010000  loss: 1.3632 (1.9659)  loss_classifier: 0.0933 (0.1183)  loss_box_reg: 0.0260 (0.0315)  loss_objectness: 0.1085 (0.1455)  loss_rpn_box_reg: 1.1468 (1.6706)  time: 0.6039  data: 0.0729  max mem: 4926
# Epoch: [5]  [ 1060/23117]  eta: 3:42:56  lr: 0.010000  loss: 1.3022 (1.9599)  loss_classifier: 0.0998 (0.1183)  loss_box_reg: 0.0324 (0.0316)  loss_objectness: 0.0957 (0.1454)  loss_rpn_box_reg: 1.0502 (1.6647)  time: 0.5968  data: 0.0650  max mem: 4926
# Epoch: [5]  [ 1070/23117]  eta: 3:42:46  lr: 0.010000  loss: 1.3262 (1.9573)  loss_classifier: 0.1080 (0.1181)  loss_box_reg: 0.0328 (0.0315)  loss_objectness: 0.1140 (0.1454)  loss_rpn_box_reg: 1.0502 (1.6623)  time: 0.5914  data: 0.0590  max mem: 4926
# Epoch: [5]  [ 1080/23117]  eta: 3:42:36  lr: 0.010000  loss: 1.3308 (1.9531)  loss_classifier: 0.0931 (0.1179)  loss_box_reg: 0.0310 (0.0316)  loss_objectness: 0.1113 (0.1450)  loss_rpn_box_reg: 1.1728 (1.6586)  time: 0.5875  data: 0.0554  max mem: 4926
# Epoch: [5]  [ 1090/23117]  eta: 3:42:28  lr: 0.010000  loss: 1.3308 (1.9487)  loss_classifier: 0.0931 (0.1177)  loss_box_reg: 0.0338 (0.0316)  loss_objectness: 0.0908 (0.1450)  loss_rpn_box_reg: 1.1218 (1.6544)  time: 0.5900  data: 0.0593  max mem: 4926
# Epoch: [5]  [ 1100/23117]  eta: 3:42:21  lr: 0.010000  loss: 1.3577 (1.9443)  loss_classifier: 0.0855 (0.1175)  loss_box_reg: 0.0255 (0.0316)  loss_objectness: 0.0908 (0.1446)  loss_rpn_box_reg: 1.1218 (1.6506)  time: 0.5992  data: 0.0691  max mem: 4926
# Epoch: [5]  [ 1110/23117]  eta: 3:42:12  lr: 0.010000  loss: 1.3475 (1.9408)  loss_classifier: 0.0843 (0.1173)  loss_box_reg: 0.0244 (0.0315)  loss_objectness: 0.0913 (0.1444)  loss_rpn_box_reg: 1.1858 (1.6476)  time: 0.5985  data: 0.0683  max mem: 4926
# Epoch: [5]  [ 1120/23117]  eta: 3:42:08  lr: 0.010000  loss: 1.2172 (1.9356)  loss_classifier: 0.0942 (0.1173)  loss_box_reg: 0.0281 (0.0316)  loss_objectness: 0.0960 (0.1441)  loss_rpn_box_reg: 0.9732 (1.6427)  time: 0.6030  data: 0.0730  max mem: 4926
# Epoch: [5]  [ 1130/23117]  eta: 3:42:01  lr: 0.010000  loss: 1.1944 (1.9316)  loss_classifier: 0.1163 (0.1172)  loss_box_reg: 0.0332 (0.0316)  loss_objectness: 0.1003 (0.1441)  loss_rpn_box_reg: 0.9222 (1.6387)  time: 0.6067  data: 0.0744  max mem: 4926
# Epoch: [5]  [ 1140/23117]  eta: 3:41:54  lr: 0.010000  loss: 1.3565 (1.9301)  loss_classifier: 0.0956 (0.1170)  loss_box_reg: 0.0260 (0.0315)  loss_objectness: 0.1019 (0.1444)  loss_rpn_box_reg: 1.0861 (1.6371)  time: 0.6005  data: 0.0675  max mem: 4926
# Epoch: [5]  [ 1150/23117]  eta: 3:41:46  lr: 0.010000  loss: 1.5029 (1.9259)  loss_classifier: 0.0861 (0.1168)  loss_box_reg: 0.0260 (0.0315)  loss_objectness: 0.1019 (0.1442)  loss_rpn_box_reg: 1.2660 (1.6333)  time: 0.5993  data: 0.0683  max mem: 4926
# Epoch: [5]  [ 1160/23117]  eta: 3:41:40  lr: 0.010000  loss: 1.0675 (1.9187)  loss_classifier: 0.0870 (0.1166)  loss_box_reg: 0.0275 (0.0315)  loss_objectness: 0.0812 (0.1436)  loss_rpn_box_reg: 0.8879 (1.6270)  time: 0.6018  data: 0.0718  max mem: 4926
# Epoch: [5]  [ 1170/23117]  eta: 3:41:34  lr: 0.010000  loss: 1.0571 (1.9133)  loss_classifier: 0.0870 (0.1163)  loss_box_reg: 0.0220 (0.0314)  loss_objectness: 0.0718 (0.1433)  loss_rpn_box_reg: 0.8782 (1.6223)  time: 0.6066  data: 0.0767  max mem: 4926
# Epoch: [5]  [ 1180/23117]  eta: 3:41:26  lr: 0.010000  loss: 1.1863 (1.9086)  loss_classifier: 0.0834 (0.1160)  loss_box_reg: 0.0266 (0.0314)  loss_objectness: 0.0728 (0.1428)  loss_rpn_box_reg: 1.0017 (1.6183)  time: 0.6014  data: 0.0712  max mem: 4926
# Epoch: [5]  [ 1190/23117]  eta: 3:41:16  lr: 0.010000  loss: 1.2449 (1.9047)  loss_classifier: 0.0908 (0.1160)  loss_box_reg: 0.0348 (0.0314)  loss_objectness: 0.0842 (0.1426)  loss_rpn_box_reg: 1.0529 (1.6147)  time: 0.5893  data: 0.0595  max mem: 4926
# Epoch: [5]  [ 1200/23117]  eta: 3:41:08  lr: 0.010000  loss: 1.1130 (1.8972)  loss_classifier: 0.1126 (0.1159)  loss_box_reg: 0.0348 (0.0314)  loss_objectness: 0.0794 (0.1422)  loss_rpn_box_reg: 0.7984 (1.6076)  time: 0.5872  data: 0.0577  max mem: 4926
# Epoch: [5]  [ 1210/23117]  eta: 3:41:02  lr: 0.010000  loss: 1.0090 (1.8910)  loss_classifier: 0.0954 (0.1157)  loss_box_reg: 0.0294 (0.0314)  loss_objectness: 0.0860 (0.1420)  loss_rpn_box_reg: 0.7817 (1.6019)  time: 0.6010  data: 0.0725  max mem: 4926
# Epoch: [5]  [ 1220/23117]  eta: 3:40:54  lr: 0.010000  loss: 1.1531 (1.8900)  loss_classifier: 0.1087 (0.1157)  loss_box_reg: 0.0327 (0.0314)  loss_objectness: 0.1002 (0.1422)  loss_rpn_box_reg: 0.9343 (1.6006)  time: 0.6016  data: 0.0732  max mem: 4926
# Epoch: [5]  [ 1230/23117]  eta: 3:40:49  lr: 0.010000  loss: 1.3798 (1.8877)  loss_classifier: 0.0952 (0.1154)  loss_box_reg: 0.0304 (0.0314)  loss_objectness: 0.1055 (0.1421)  loss_rpn_box_reg: 1.1732 (1.5988)  time: 0.6032  data: 0.0739  max mem: 4926
# Epoch: [5]  [ 1240/23117]  eta: 3:40:40  lr: 0.010000  loss: 1.2435 (1.8842)  loss_classifier: 0.0899 (0.1153)  loss_box_reg: 0.0289 (0.0314)  loss_objectness: 0.0984 (0.1417)  loss_rpn_box_reg: 1.0092 (1.5959)  time: 0.5995  data: 0.0695  max mem: 4926
# Epoch: [5]  [ 1250/23117]  eta: 3:40:30  lr: 0.010000  loss: 1.1731 (1.8821)  loss_classifier: 0.0922 (0.1151)  loss_box_reg: 0.0268 (0.0313)  loss_objectness: 0.0907 (0.1414)  loss_rpn_box_reg: 0.9806 (1.5943)  time: 0.5854  data: 0.0554  max mem: 4926
# Epoch: [5]  [ 1260/23117]  eta: 3:40:21  lr: 0.010000  loss: 1.1731 (1.8785)  loss_classifier: 0.0922 (0.1149)  loss_box_reg: 0.0269 (0.0313)  loss_objectness: 0.0821 (0.1412)  loss_rpn_box_reg: 0.9806 (1.5911)  time: 0.5863  data: 0.0563  max mem: 4926
# Epoch: [5]  [ 1270/23117]  eta: 3:40:15  lr: 0.010000  loss: 1.3838 (1.8770)  loss_classifier: 0.1048 (0.1148)  loss_box_reg: 0.0333 (0.0313)  loss_objectness: 0.0862 (0.1412)  loss_rpn_box_reg: 1.1506 (1.5897)  time: 0.5958  data: 0.0663  max mem: 4926
# Epoch: [5]  [ 1280/23117]  eta: 3:40:07  lr: 0.010000  loss: 1.5878 (1.8766)  loss_classifier: 0.1038 (0.1146)  loss_box_reg: 0.0328 (0.0313)  loss_objectness: 0.1178 (0.1414)  loss_rpn_box_reg: 1.3387 (1.5894)  time: 0.5997  data: 0.0707  max mem: 4926
# Epoch: [5]  [ 1290/23117]  eta: 3:39:59  lr: 0.010000  loss: 1.2468 (1.8708)  loss_classifier: 0.0949 (0.1145)  loss_box_reg: 0.0278 (0.0312)  loss_objectness: 0.0925 (0.1412)  loss_rpn_box_reg: 1.0492 (1.5839)  time: 0.5945  data: 0.0651  max mem: 4926
# Epoch: [5]  [ 1300/23117]  eta: 3:39:51  lr: 0.010000  loss: 1.2468 (1.8686)  loss_classifier: 0.0988 (0.1144)  loss_box_reg: 0.0289 (0.0312)  loss_objectness: 0.0923 (0.1410)  loss_rpn_box_reg: 1.0425 (1.5820)  time: 0.5934  data: 0.0632  max mem: 4926
# Epoch: [5]  [ 1310/23117]  eta: 3:39:44  lr: 0.010000  loss: 1.3653 (1.8640)  loss_classifier: 0.0998 (0.1142)  loss_box_reg: 0.0303 (0.0312)  loss_objectness: 0.0902 (0.1406)  loss_rpn_box_reg: 1.1304 (1.5781)  time: 0.5938  data: 0.0633  max mem: 4926
# Epoch: [5]  [ 1320/23117]  eta: 3:39:35  lr: 0.010000  loss: 1.1542 (1.8604)  loss_classifier: 0.0927 (0.1140)  loss_box_reg: 0.0288 (0.0311)  loss_objectness: 0.0908 (0.1409)  loss_rpn_box_reg: 0.9448 (1.5743)  time: 0.5917  data: 0.0617  max mem: 4926
# Epoch: [5]  [ 1330/23117]  eta: 3:39:28  lr: 0.010000  loss: 1.1413 (1.8562)  loss_classifier: 0.1030 (0.1139)  loss_box_reg: 0.0302 (0.0311)  loss_objectness: 0.1028 (0.1409)  loss_rpn_box_reg: 0.9262 (1.5702)  time: 0.5932  data: 0.0636  max mem: 4926
# Epoch: [5]  [ 1340/23117]  eta: 3:39:18  lr: 0.010000  loss: 1.2479 (1.8554)  loss_classifier: 0.0934 (0.1138)  loss_box_reg: 0.0315 (0.0311)  loss_objectness: 0.0855 (0.1409)  loss_rpn_box_reg: 1.0626 (1.5696)  time: 0.5897  data: 0.0599  max mem: 4926
# Epoch: [5]  [ 1350/23117]  eta: 3:39:09  lr: 0.010000  loss: 1.2488 (1.8511)  loss_classifier: 0.0850 (0.1135)  loss_box_reg: 0.0243 (0.0310)  loss_objectness: 0.0982 (0.1414)  loss_rpn_box_reg: 0.9627 (1.5652)  time: 0.5847  data: 0.0548  max mem: 4926
# Epoch: [5]  [ 1360/23117]  eta: 3:39:02  lr: 0.010000  loss: 1.2980 (1.8486)  loss_classifier: 0.0928 (0.1134)  loss_box_reg: 0.0246 (0.0310)  loss_objectness: 0.1242 (0.1416)  loss_rpn_box_reg: 0.9869 (1.5625)  time: 0.5923  data: 0.0624  max mem: 4926
# Epoch: [5]  [ 1370/23117]  eta: 3:38:57  lr: 0.010000  loss: 1.3453 (1.8467)  loss_classifier: 0.0964 (0.1133)  loss_box_reg: 0.0329 (0.0310)  loss_objectness: 0.1163 (0.1415)  loss_rpn_box_reg: 1.0598 (1.5609)  time: 0.6018  data: 0.0677  max mem: 4926
# Epoch: [5]  [ 1380/23117]  eta: 3:38:49  lr: 0.010000  loss: 1.4333 (1.8457)  loss_classifier: 0.0857 (0.1132)  loss_box_reg: 0.0263 (0.0310)  loss_objectness: 0.1089 (0.1418)  loss_rpn_box_reg: 1.1887 (1.5597)  time: 0.6007  data: 0.0668  max mem: 4926
# Epoch: [5]  [ 1390/23117]  eta: 3:38:40  lr: 0.010000  loss: 1.3586 (1.8413)  loss_classifier: 0.0981 (0.1131)  loss_box_reg: 0.0272 (0.0310)  loss_objectness: 0.1013 (0.1416)  loss_rpn_box_reg: 1.0551 (1.5556)  time: 0.5895  data: 0.0599  max mem: 4926
# Epoch: [5]  [ 1400/23117]  eta: 3:38:33  lr: 0.010000  loss: 1.1818 (1.8404)  loss_classifier: 0.0933 (0.1129)  loss_box_reg: 0.0223 (0.0309)  loss_objectness: 0.1024 (0.1417)  loss_rpn_box_reg: 0.8934 (1.5549)  time: 0.5894  data: 0.0595  max mem: 4926
# Epoch: [5]  [ 1410/23117]  eta: 3:38:24  lr: 0.010000  loss: 1.1818 (1.8358)  loss_classifier: 0.0933 (0.1128)  loss_box_reg: 0.0234 (0.0309)  loss_objectness: 0.1026 (0.1413)  loss_rpn_box_reg: 0.8934 (1.5507)  time: 0.5916  data: 0.0615  max mem: 4926
# Epoch: [5]  [ 1420/23117]  eta: 3:38:16  lr: 0.010000  loss: 1.0287 (1.8299)  loss_classifier: 0.1046 (0.1128)  loss_box_reg: 0.0335 (0.0309)  loss_objectness: 0.0789 (0.1411)  loss_rpn_box_reg: 0.7565 (1.5451)  time: 0.5893  data: 0.0596  max mem: 4926
# Epoch: [5]  [ 1430/23117]  eta: 3:38:10  lr: 0.010000  loss: 1.2371 (1.8306)  loss_classifier: 0.1038 (0.1127)  loss_box_reg: 0.0312 (0.0309)  loss_objectness: 0.0999 (0.1415)  loss_rpn_box_reg: 0.8687 (1.5455)  time: 0.5963  data: 0.0670  max mem: 4926
# Epoch: [5]  [ 1440/23117]  eta: 3:38:00  lr: 0.010000  loss: 1.3669 (1.8268)  loss_classifier: 0.1015 (0.1126)  loss_box_reg: 0.0307 (0.0309)  loss_objectness: 0.0882 (0.1412)  loss_rpn_box_reg: 1.1311 (1.5420)  time: 0.5889  data: 0.0598  max mem: 4926
# Epoch: [5]  [ 1450/23117]  eta: 3:37:51  lr: 0.010000  loss: 1.0144 (1.8215)  loss_classifier: 0.1060 (0.1126)  loss_box_reg: 0.0363 (0.0310)  loss_objectness: 0.0846 (0.1413)  loss_rpn_box_reg: 0.7805 (1.5367)  time: 0.5817  data: 0.0527  max mem: 4926
# Epoch: [5]  [ 1460/23117]  eta: 3:37:41  lr: 0.010000  loss: 1.1437 (1.8181)  loss_classifier: 0.1033 (0.1125)  loss_box_reg: 0.0335 (0.0310)  loss_objectness: 0.0867 (0.1411)  loss_rpn_box_reg: 0.8796 (1.5336)  time: 0.5818  data: 0.0521  max mem: 4926
# Epoch: [5]  [ 1470/23117]  eta: 3:37:32  lr: 0.010000  loss: 1.1458 (1.8146)  loss_classifier: 0.0980 (0.1124)  loss_box_reg: 0.0303 (0.0310)  loss_objectness: 0.0871 (0.1411)  loss_rpn_box_reg: 0.9222 (1.5301)  time: 0.5796  data: 0.0498  max mem: 4926
# Epoch: [5]  [ 1480/23117]  eta: 3:37:23  lr: 0.010000  loss: 1.3076 (1.8133)  loss_classifier: 0.0980 (0.1123)  loss_box_reg: 0.0263 (0.0310)  loss_objectness: 0.1008 (0.1410)  loss_rpn_box_reg: 1.0807 (1.5290)  time: 0.5841  data: 0.0542  max mem: 4926
# Epoch: [5]  [ 1490/23117]  eta: 3:37:17  lr: 0.010000  loss: 1.2156 (1.8095)  loss_classifier: 0.0868 (0.1122)  loss_box_reg: 0.0250 (0.0310)  loss_objectness: 0.0901 (0.1406)  loss_rpn_box_reg: 0.9436 (1.5258)  time: 0.5907  data: 0.0605  max mem: 4926
# Epoch: [5]  [ 1500/23117]  eta: 3:37:09  lr: 0.010000  loss: 1.0727 (1.8053)  loss_classifier: 0.1019 (0.1121)  loss_box_reg: 0.0347 (0.0310)  loss_objectness: 0.0770 (0.1404)  loss_rpn_box_reg: 0.8365 (1.5218)  time: 0.5929  data: 0.0633  max mem: 4926
# Epoch: [5]  [ 1510/23117]  eta: 3:37:00  lr: 0.010000  loss: 1.2312 (1.8030)  loss_classifier: 0.1019 (0.1120)  loss_box_reg: 0.0310 (0.0310)  loss_objectness: 0.0986 (0.1402)  loss_rpn_box_reg: 0.9628 (1.5198)  time: 0.5888  data: 0.0581  max mem: 4926
# Epoch: [5]  [ 1520/23117]  eta: 3:36:52  lr: 0.010000  loss: 1.2312 (1.7999)  loss_classifier: 0.0847 (0.1119)  loss_box_reg: 0.0252 (0.0310)  loss_objectness: 0.0986 (0.1401)  loss_rpn_box_reg: 0.9851 (1.5169)  time: 0.5858  data: 0.0554  max mem: 4926
# Epoch: [5]  [ 1530/23117]  eta: 3:36:45  lr: 0.010000  loss: 1.1256 (1.7964)  loss_classifier: 0.0814 (0.1118)  loss_box_reg: 0.0275 (0.0309)  loss_objectness: 0.1072 (0.1403)  loss_rpn_box_reg: 0.8995 (1.5134)  time: 0.5907  data: 0.0615  max mem: 4926
# Epoch: [5]  [ 1540/23117]  eta: 3:36:39  lr: 0.010000  loss: 1.2522 (1.7931)  loss_classifier: 0.1014 (0.1118)  loss_box_reg: 0.0317 (0.0310)  loss_objectness: 0.0894 (0.1400)  loss_rpn_box_reg: 0.9439 (1.5102)  time: 0.6000  data: 0.0700  max mem: 4926
# Epoch: [5]  [ 1550/23117]  eta: 3:36:32  lr: 0.010000  loss: 1.1334 (1.7901)  loss_classifier: 0.1044 (0.1117)  loss_box_reg: 0.0356 (0.0310)  loss_objectness: 0.0823 (0.1398)  loss_rpn_box_reg: 0.9303 (1.5076)  time: 0.5973  data: 0.0672  max mem: 4926
# Epoch: [5]  [ 1560/23117]  eta: 3:36:23  lr: 0.010000  loss: 1.1576 (1.7884)  loss_classifier: 0.0964 (0.1116)  loss_box_reg: 0.0266 (0.0309)  loss_objectness: 0.0847 (0.1396)  loss_rpn_box_reg: 0.9494 (1.5062)  time: 0.5889  data: 0.0593  max mem: 4926
# Epoch: [5]  [ 1570/23117]  eta: 3:36:16  lr: 0.010000  loss: 1.2640 (1.7866)  loss_classifier: 0.0936 (0.1114)  loss_box_reg: 0.0236 (0.0309)  loss_objectness: 0.0985 (0.1397)  loss_rpn_box_reg: 1.0749 (1.5046)  time: 0.5887  data: 0.0586  max mem: 4926
# Epoch: [5]  [ 1580/23117]  eta: 3:36:10  lr: 0.010000  loss: 1.2640 (1.7833)  loss_classifier: 0.0994 (0.1114)  loss_box_reg: 0.0285 (0.0309)  loss_objectness: 0.0887 (0.1395)  loss_rpn_box_reg: 1.0636 (1.5014)  time: 0.5970  data: 0.0663  max mem: 4926
# Epoch: [5]  [ 1590/23117]  eta: 3:36:00  lr: 0.010000  loss: 1.1803 (1.7809)  loss_classifier: 0.1119 (0.1114)  loss_box_reg: 0.0358 (0.0310)  loss_objectness: 0.0871 (0.1396)  loss_rpn_box_reg: 0.8435 (1.4989)  time: 0.5882  data: 0.0583  max mem: 4926
# Epoch: [5]  [ 1600/23117]  eta: 3:35:52  lr: 0.010000  loss: 1.1803 (1.7776)  loss_classifier: 0.0788 (0.1111)  loss_box_reg: 0.0208 (0.0309)  loss_objectness: 0.1050 (0.1399)  loss_rpn_box_reg: 0.8435 (1.4957)  time: 0.5799  data: 0.0500  max mem: 4926
# Epoch: [5]  [ 1610/23117]  eta: 3:35:44  lr: 0.010000  loss: 1.2818 (1.7771)  loss_classifier: 0.0788 (0.1110)  loss_box_reg: 0.0208 (0.0308)  loss_objectness: 0.1060 (0.1401)  loss_rpn_box_reg: 1.0133 (1.4952)  time: 0.5891  data: 0.0589  max mem: 4926
# Epoch: [5]  [ 1620/23117]  eta: 3:35:36  lr: 0.010000  loss: 1.1938 (1.7727)  loss_classifier: 0.0909 (0.1109)  loss_box_reg: 0.0265 (0.0308)  loss_objectness: 0.0906 (0.1397)  loss_rpn_box_reg: 0.9811 (1.4913)  time: 0.5903  data: 0.0603  max mem: 4926
# Epoch: [5]  [ 1630/23117]  eta: 3:35:28  lr: 0.010000  loss: 1.1194 (1.7701)  loss_classifier: 0.0909 (0.1108)  loss_box_reg: 0.0206 (0.0308)  loss_objectness: 0.0846 (0.1395)  loss_rpn_box_reg: 0.9621 (1.4890)  time: 0.5861  data: 0.0552  max mem: 4926
# Epoch: [5]  [ 1640/23117]  eta: 3:35:20  lr: 0.010000  loss: 1.2234 (1.7684)  loss_classifier: 0.0917 (0.1107)  loss_box_reg: 0.0233 (0.0307)  loss_objectness: 0.1122 (0.1397)  loss_rpn_box_reg: 0.9854 (1.4873)  time: 0.5845  data: 0.0536  max mem: 4926
# Epoch: [5]  [ 1650/23117]  eta: 3:35:11  lr: 0.010000  loss: 1.2055 (1.7648)  loss_classifier: 0.0929 (0.1105)  loss_box_reg: 0.0253 (0.0307)  loss_objectness: 0.1055 (0.1399)  loss_rpn_box_reg: 0.9787 (1.4838)  time: 0.5836  data: 0.0535  max mem: 4926
# Epoch: [5]  [ 1660/23117]  eta: 3:35:04  lr: 0.010000  loss: 1.2812 (1.7626)  loss_classifier: 0.0874 (0.1104)  loss_box_reg: 0.0239 (0.0307)  loss_objectness: 0.1212 (0.1401)  loss_rpn_box_reg: 0.9851 (1.4814)  time: 0.5858  data: 0.0557  max mem: 4926
# Epoch: [5]  [ 1670/23117]  eta: 3:34:58  lr: 0.010000  loss: 1.2592 (1.7593)  loss_classifier: 0.1064 (0.1103)  loss_box_reg: 0.0330 (0.0307)  loss_objectness: 0.1211 (0.1401)  loss_rpn_box_reg: 0.9819 (1.4782)  time: 0.5950  data: 0.0647  max mem: 4926
# Epoch: [5]  [ 1680/23117]  eta: 3:34:51  lr: 0.010000  loss: 1.1631 (1.7569)  loss_classifier: 0.0945 (0.1102)  loss_box_reg: 0.0248 (0.0306)  loss_objectness: 0.1060 (0.1400)  loss_rpn_box_reg: 0.8792 (1.4760)  time: 0.5971  data: 0.0669  max mem: 4926
# Epoch: [5]  [ 1690/23117]  eta: 3:34:42  lr: 0.010000  loss: 1.1838 (1.7532)  loss_classifier: 0.0926 (0.1101)  loss_box_reg: 0.0248 (0.0306)  loss_objectness: 0.0933 (0.1399)  loss_rpn_box_reg: 0.9335 (1.4726)  time: 0.5869  data: 0.0569  max mem: 4926
# Epoch: [5]  [ 1700/23117]  eta: 3:34:33  lr: 0.010000  loss: 0.9924 (1.7493)  loss_classifier: 0.0909 (0.1100)  loss_box_reg: 0.0260 (0.0306)  loss_objectness: 0.0849 (0.1396)  loss_rpn_box_reg: 0.8441 (1.4690)  time: 0.5792  data: 0.0494  max mem: 4926
# Epoch: [5]  [ 1710/23117]  eta: 3:34:26  lr: 0.010000  loss: 1.0672 (1.7486)  loss_classifier: 0.0903 (0.1099)  loss_box_reg: 0.0268 (0.0306)  loss_objectness: 0.1046 (0.1397)  loss_rpn_box_reg: 0.8477 (1.4685)  time: 0.5843  data: 0.0535  max mem: 4926
# Epoch: [5]  [ 1720/23117]  eta: 3:34:20  lr: 0.010000  loss: 1.4104 (1.7462)  loss_classifier: 0.1017 (0.1099)  loss_box_reg: 0.0332 (0.0306)  loss_objectness: 0.0931 (0.1395)  loss_rpn_box_reg: 1.1718 (1.4662)  time: 0.5951  data: 0.0638  max mem: 4926
# Epoch: [5]  [ 1730/23117]  eta: 3:34:12  lr: 0.010000  loss: 1.0354 (1.7419)  loss_classifier: 0.0962 (0.1098)  loss_box_reg: 0.0309 (0.0306)  loss_objectness: 0.0754 (0.1390)  loss_rpn_box_reg: 0.9058 (1.4625)  time: 0.5922  data: 0.0616  max mem: 4926
# Epoch: [5]  [ 1740/23117]  eta: 3:34:03  lr: 0.010000  loss: 0.9897 (1.7382)  loss_classifier: 0.0911 (0.1097)  loss_box_reg: 0.0259 (0.0306)  loss_objectness: 0.0669 (0.1387)  loss_rpn_box_reg: 0.7580 (1.4592)  time: 0.5839  data: 0.0539  max mem: 4926
# Epoch: [5]  [ 1750/23117]  eta: 3:33:55  lr: 0.010000  loss: 1.0105 (1.7350)  loss_classifier: 0.0828 (0.1095)  loss_box_reg: 0.0216 (0.0305)  loss_objectness: 0.0669 (0.1384)  loss_rpn_box_reg: 0.8271 (1.4565)  time: 0.5825  data: 0.0528  max mem: 4926
# Epoch: [5]  [ 1760/23117]  eta: 3:33:48  lr: 0.010000  loss: 1.1986 (1.7323)  loss_classifier: 0.0902 (0.1094)  loss_box_reg: 0.0260 (0.0305)  loss_objectness: 0.0971 (0.1385)  loss_rpn_box_reg: 0.8986 (1.4539)  time: 0.5869  data: 0.0570  max mem: 4926
# Epoch: [5]  [ 1770/23117]  eta: 3:33:40  lr: 0.010000  loss: 1.2166 (1.7330)  loss_classifier: 0.0902 (0.1093)  loss_box_reg: 0.0243 (0.0305)  loss_objectness: 0.1220 (0.1387)  loss_rpn_box_reg: 0.9504 (1.4546)  time: 0.5872  data: 0.0568  max mem: 4926
# Epoch: [5]  [ 1780/23117]  eta: 3:33:33  lr: 0.010000  loss: 1.0527 (1.7305)  loss_classifier: 0.0810 (0.1092)  loss_box_reg: 0.0243 (0.0304)  loss_objectness: 0.1003 (0.1386)  loss_rpn_box_reg: 0.8700 (1.4523)  time: 0.5905  data: 0.0600  max mem: 4926
# Epoch: [5]  [ 1790/23117]  eta: 3:33:26  lr: 0.010000  loss: 1.0309 (1.7278)  loss_classifier: 0.1007 (0.1091)  loss_box_reg: 0.0259 (0.0304)  loss_objectness: 0.0945 (0.1386)  loss_rpn_box_reg: 0.8454 (1.4497)  time: 0.5914  data: 0.0607  max mem: 4926
# Epoch: [5]  [ 1800/23117]  eta: 3:33:16  lr: 0.010000  loss: 1.0249 (1.7257)  loss_classifier: 0.1016 (0.1091)  loss_box_reg: 0.0273 (0.0304)  loss_objectness: 0.0900 (0.1384)  loss_rpn_box_reg: 0.8255 (1.4478)  time: 0.5785  data: 0.0485  max mem: 4926
# Epoch: [5]  [ 1810/23117]  eta: 3:33:10  lr: 0.010000  loss: 1.1822 (1.7224)  loss_classifier: 0.1012 (0.1090)  loss_box_reg: 0.0277 (0.0304)  loss_objectness: 0.0832 (0.1382)  loss_rpn_box_reg: 0.9618 (1.4447)  time: 0.5831  data: 0.0535  max mem: 4926
# Epoch: [5]  [ 1820/23117]  eta: 3:33:03  lr: 0.010000  loss: 1.0083 (1.7189)  loss_classifier: 0.0929 (0.1089)  loss_box_reg: 0.0277 (0.0304)  loss_objectness: 0.0807 (0.1381)  loss_rpn_box_reg: 0.7812 (1.4415)  time: 0.5933  data: 0.0598  max mem: 4926
# Epoch: [5]  [ 1830/23117]  eta: 3:32:55  lr: 0.010000  loss: 1.0157 (1.7166)  loss_classifier: 0.0919 (0.1088)  loss_box_reg: 0.0277 (0.0304)  loss_objectness: 0.0900 (0.1378)  loss_rpn_box_reg: 0.8089 (1.4396)  time: 0.5889  data: 0.0554  max mem: 4926
# Epoch: [5]  [ 1840/23117]  eta: 3:32:48  lr: 0.010000  loss: 1.0846 (1.7149)  loss_classifier: 0.0919 (0.1087)  loss_box_reg: 0.0268 (0.0304)  loss_objectness: 0.0722 (0.1377)  loss_rpn_box_reg: 0.8695 (1.4382)  time: 0.5898  data: 0.0600  max mem: 4926
# Epoch: [5]  [ 1850/23117]  eta: 3:32:42  lr: 0.010000  loss: 1.2451 (1.7144)  loss_classifier: 0.0920 (0.1086)  loss_box_reg: 0.0282 (0.0304)  loss_objectness: 0.0790 (0.1376)  loss_rpn_box_reg: 1.0309 (1.4377)  time: 0.5965  data: 0.0666  max mem: 4926
# Epoch: [5]  [ 1860/23117]  eta: 3:32:35  lr: 0.010000  loss: 1.3037 (1.7129)  loss_classifier: 0.0899 (0.1085)  loss_box_reg: 0.0290 (0.0304)  loss_objectness: 0.0980 (0.1375)  loss_rpn_box_reg: 1.0799 (1.4365)  time: 0.5929  data: 0.0628  max mem: 4926
# Epoch: [5]  [ 1870/23117]  eta: 3:32:27  lr: 0.010000  loss: 1.2816 (1.7111)  loss_classifier: 0.0896 (0.1085)  loss_box_reg: 0.0239 (0.0303)  loss_objectness: 0.1134 (0.1376)  loss_rpn_box_reg: 1.0087 (1.4347)  time: 0.5848  data: 0.0547  max mem: 4926
# ...
# Epoch: [5]  [22870/23117]  eta: 0:02:22  lr: 0.010000  loss: 0.6272 (1.0327)  loss_classifier: 0.0547 (0.0792)  loss_box_reg: 0.0077 (0.0208)  loss_objectness: 0.0629 (0.1078)  loss_rpn_box_reg: 0.4507 (0.8248)  time: 0.5607  data: 0.0301  max mem: 4926
# Epoch: [5]  [22880/23117]  eta: 0:02:16  lr: 0.010000  loss: 0.6585 (1.0327)  loss_classifier: 0.0547 (0.0792)  loss_box_reg: 0.0073 (0.0208)  loss_objectness: 0.0753 (0.1078)  loss_rpn_box_reg: 0.5012 (0.8248)  time: 0.5610  data: 0.0299  max mem: 4926
# Epoch: [5]  [22890/23117]  eta: 0:02:11  lr: 0.010000  loss: 0.6274 (1.0326)  loss_classifier: 0.0586 (0.0792)  loss_box_reg: 0.0151 (0.0208)  loss_objectness: 0.0640 (0.1078)  loss_rpn_box_reg: 0.4544 (0.8248)  time: 0.5621  data: 0.0307  max mem: 4926
# Epoch: [5]  [22900/23117]  eta: 0:02:05  lr: 0.010000  loss: 0.5940 (1.0325)  loss_classifier: 0.0651 (0.0792)  loss_box_reg: 0.0151 (0.0208)  loss_objectness: 0.0625 (0.1078)  loss_rpn_box_reg: 0.4391 (0.8247)  time: 0.5653  data: 0.0343  max mem: 4926
# Epoch: [5]  [22910/23117]  eta: 0:01:59  lr: 0.010000  loss: 0.6309 (1.0324)  loss_classifier: 0.0583 (0.0792)  loss_box_reg: 0.0132 (0.0208)  loss_objectness: 0.0625 (0.1078)  loss_rpn_box_reg: 0.4949 (0.8245)  time: 0.5620  data: 0.0315  max mem: 4926
# Epoch: [5]  [22920/23117]  eta: 0:01:53  lr: 0.010000  loss: 0.6296 (1.0322)  loss_classifier: 0.0569 (0.0792)  loss_box_reg: 0.0117 (0.0208)  loss_objectness: 0.0644 (0.1078)  loss_rpn_box_reg: 0.4949 (0.8244)  time: 0.5589  data: 0.0285  max mem: 4926
# Epoch: [5]  [22930/23117]  eta: 0:01:48  lr: 0.010000  loss: 0.6072 (1.0321)  loss_classifier: 0.0669 (0.0792)  loss_box_reg: 0.0136 (0.0208)  loss_objectness: 0.0685 (0.1078)  loss_rpn_box_reg: 0.4499 (0.8243)  time: 0.5644  data: 0.0337  max mem: 4926
# Epoch: [5]  [22940/23117]  eta: 0:01:42  lr: 0.010000  loss: 0.6072 (1.0320)  loss_classifier: 0.0666 (0.0792)  loss_box_reg: 0.0159 (0.0208)  loss_objectness: 0.0686 (0.1078)  loss_rpn_box_reg: 0.4499 (0.8242)  time: 0.5651  data: 0.0343  max mem: 4926
# Epoch: [5]  [22950/23117]  eta: 0:01:36  lr: 0.010000  loss: 0.8062 (1.0319)  loss_classifier: 0.0666 (0.0792)  loss_box_reg: 0.0119 (0.0208)  loss_objectness: 0.0712 (0.1078)  loss_rpn_box_reg: 0.6470 (0.8242)  time: 0.5618  data: 0.0311  max mem: 4926
# Epoch: [5]  [22960/23117]  eta: 0:01:30  lr: 0.010000  loss: 0.6413 (1.0320)  loss_classifier: 0.0684 (0.0792)  loss_box_reg: 0.0132 (0.0208)  loss_objectness: 0.0712 (0.1078)  loss_rpn_box_reg: 0.5124 (0.8242)  time: 0.5620  data: 0.0314  max mem: 4926
# Epoch: [5]  [22970/23117]  eta: 0:01:24  lr: 0.010000  loss: 0.6339 (1.0319)  loss_classifier: 0.0645 (0.0792)  loss_box_reg: 0.0143 (0.0208)  loss_objectness: 0.0818 (0.1078)  loss_rpn_box_reg: 0.4828 (0.8241)  time: 0.5622  data: 0.0311  max mem: 4926
# Epoch: [5]  [22980/23117]  eta: 0:01:19  lr: 0.010000  loss: 0.7774 (1.0318)  loss_classifier: 0.0632 (0.0792)  loss_box_reg: 0.0136 (0.0208)  loss_objectness: 0.0942 (0.1078)  loss_rpn_box_reg: 0.5780 (0.8240)  time: 0.5623  data: 0.0311  max mem: 4926
# Epoch: [5]  [22990/23117]  eta: 0:01:13  lr: 0.010000  loss: 0.6344 (1.0316)  loss_classifier: 0.0584 (0.0792)  loss_box_reg: 0.0153 (0.0208)  loss_objectness: 0.0745 (0.1078)  loss_rpn_box_reg: 0.4200 (0.8239)  time: 0.5677  data: 0.0370  max mem: 4926
# Epoch: [5]  [23000/23117]  eta: 0:01:07  lr: 0.010000  loss: 0.6708 (1.0317)  loss_classifier: 0.0556 (0.0792)  loss_box_reg: 0.0107 (0.0208)  loss_objectness: 0.0724 (0.1078)  loss_rpn_box_reg: 0.5306 (0.8240)  time: 0.5685  data: 0.0378  max mem: 4926
# Epoch: [5]  [23010/23117]  eta: 0:01:01  lr: 0.010000  loss: 0.8863 (1.0317)  loss_classifier: 0.0564 (0.0792)  loss_box_reg: 0.0114 (0.0208)  loss_objectness: 0.1021 (0.1078)  loss_rpn_box_reg: 0.6934 (0.8240)  time: 0.5647  data: 0.0336  max mem: 4926
# Epoch: [5]  [23020/23117]  eta: 0:00:56  lr: 0.010000  loss: 0.8963 (1.0318)  loss_classifier: 0.0663 (0.0792)  loss_box_reg: 0.0122 (0.0208)  loss_objectness: 0.1028 (0.1078)  loss_rpn_box_reg: 0.6801 (0.8241)  time: 0.5619  data: 0.0310  max mem: 4926
# Epoch: [5]  [23030/23117]  eta: 0:00:50  lr: 0.010000  loss: 0.7438 (1.0317)  loss_classifier: 0.0666 (0.0791)  loss_box_reg: 0.0114 (0.0208)  loss_objectness: 0.0825 (0.1078)  loss_rpn_box_reg: 0.5941 (0.8239)  time: 0.5657  data: 0.0347  max mem: 4926
# Epoch: [5]  [23040/23117]  eta: 0:00:44  lr: 0.010000  loss: 0.7429 (1.0316)  loss_classifier: 0.0744 (0.0791)  loss_box_reg: 0.0168 (0.0208)  loss_objectness: 0.0723 (0.1078)  loss_rpn_box_reg: 0.5692 (0.8239)  time: 0.5698  data: 0.0383  max mem: 4926
# Epoch: [5]  [23050/23117]  eta: 0:00:38  lr: 0.010000  loss: 0.7429 (1.0315)  loss_classifier: 0.0744 (0.0791)  loss_box_reg: 0.0187 (0.0208)  loss_objectness: 0.0679 (0.1078)  loss_rpn_box_reg: 0.6153 (0.8238)  time: 0.5661  data: 0.0347  max mem: 4926
# Epoch: [5]  [23060/23117]  eta: 0:00:32  lr: 0.010000  loss: 0.6789 (1.0314)  loss_classifier: 0.0699 (0.0791)  loss_box_reg: 0.0153 (0.0208)  loss_objectness: 0.0679 (0.1078)  loss_rpn_box_reg: 0.4748 (0.8237)  time: 0.5600  data: 0.0292  max mem: 4926
# Epoch: [5]  [23070/23117]  eta: 0:00:27  lr: 0.010000  loss: 0.5946 (1.0312)  loss_classifier: 0.0466 (0.0791)  loss_box_reg: 0.0122 (0.0207)  loss_objectness: 0.0709 (0.1078)  loss_rpn_box_reg: 0.4628 (0.8236)  time: 0.5650  data: 0.0337  max mem: 4926
# Epoch: [5]  [23080/23117]  eta: 0:00:21  lr: 0.010000  loss: 0.5914 (1.0312)  loss_classifier: 0.0466 (0.0791)  loss_box_reg: 0.0071 (0.0207)  loss_objectness: 0.0709 (0.1078)  loss_rpn_box_reg: 0.4363 (0.8236)  time: 0.5681  data: 0.0369  max mem: 4926
# Epoch: [5]  [23090/23117]  eta: 0:00:15  lr: 0.010000  loss: 0.7018 (1.0311)  loss_classifier: 0.0568 (0.0791)  loss_box_reg: 0.0131 (0.0207)  loss_objectness: 0.0908 (0.1078)  loss_rpn_box_reg: 0.4916 (0.8235)  time: 0.5627  data: 0.0321  max mem: 4926
# Epoch: [5]  [23100/23117]  eta: 0:00:09  lr: 0.010000  loss: 0.6551 (1.0309)  loss_classifier: 0.0597 (0.0791)  loss_box_reg: 0.0131 (0.0207)  loss_objectness: 0.0631 (0.1078)  loss_rpn_box_reg: 0.4667 (0.8233)  time: 0.5598  data: 0.0292  max mem: 4926
# Epoch: [5]  [23110/23117]  eta: 0:00:04  lr: 0.010000  loss: 0.5423 (1.0307)  loss_classifier: 0.0539 (0.0791)  loss_box_reg: 0.0095 (0.0207)  loss_objectness: 0.0583 (0.1078)  loss_rpn_box_reg: 0.3877 (0.8231)  time: 0.5612  data: 0.0305  max mem: 4926
# Epoch: [5]  [23116/23117]  eta: 0:00:00  lr: 0.010000  loss: 0.5671 (1.0308)  loss_classifier: 0.0564 (0.0791)  loss_box_reg: 0.0095 (0.0207)  loss_objectness: 0.0562 (0.1078)  loss_rpn_box_reg: 0.4412 (0.8232)  time: 0.5633  data: 0.0325  max mem: 4926
# Epoch: [5] Total time: 3:42:32 (0.5776 s / it)
# creating index...
# index created!
# Test:  [   0/5780]  eta: 0:21:19  model_time: 0.1885 (0.1885)  evaluator_time: 0.0030 (0.0030)  time: 0.2214  data: 0.0100  max mem: 4926
# Test:  [ 100/5780]  eta: 0:15:11  model_time: 0.1486 (0.1489)  evaluator_time: 0.0020 (0.0017)  time: 0.1598  data: 0.0080  max mem: 4926
# Test:  [ 200/5780]  eta: 0:14:56  model_time: 0.1496 (0.1494)  evaluator_time: 0.0020 (0.0017)  time: 0.1606  data: 0.0078  max mem: 4926
# Test:  [ 300/5780]  eta: 0:14:42  model_time: 0.1506 (0.1499)  evaluator_time: 0.0010 (0.0017)  time: 0.1619  data: 0.0080  max mem: 4926
# Test:  [ 400/5780]  eta: 0:14:35  model_time: 0.1586 (0.1515)  evaluator_time: 0.0020 (0.0017)  time: 0.1739  data: 0.0092  max mem: 4926
# Test:  [ 500/5780]  eta: 0:14:50  model_time: 0.1586 (0.1575)  evaluator_time: 0.0020 (0.0017)  time: 0.1704  data: 0.0085  max mem: 4926
# Test:  [ 600/5780]  eta: 0:14:35  model_time: 0.1576 (0.1577)  evaluator_time: 0.0020 (0.0017)  time: 0.1691  data: 0.0080  max mem: 4926
# Test:  [ 700/5780]  eta: 0:14:18  model_time: 0.1576 (0.1578)  evaluator_time: 0.0020 (0.0017)  time: 0.1696  data: 0.0083  max mem: 4926
# Test:  [ 800/5780]  eta: 0:14:02  model_time: 0.1586 (0.1579)  evaluator_time: 0.0020 (0.0017)  time: 0.1696  data: 0.0082  max mem: 4926
# Test:  [ 900/5780]  eta: 0:13:45  model_time: 0.1585 (0.1579)  evaluator_time: 0.0020 (0.0017)  time: 0.1697  data: 0.0081  max mem: 4926
# Test:  [1000/5780]  eta: 0:13:29  model_time: 0.1595 (0.1581)  evaluator_time: 0.0020 (0.0018)  time: 0.1706  data: 0.0078  max mem: 4926
# Test:  [1100/5780]  eta: 0:13:12  model_time: 0.1586 (0.1582)  evaluator_time: 0.0020 (0.0018)  time: 0.1700  data: 0.0080  max mem: 4926
# Test:  [1200/5780]  eta: 0:12:56  model_time: 0.1587 (0.1583)  evaluator_time: 0.0020 (0.0018)  time: 0.1705  data: 0.0080  max mem: 4926
# Test:  [1300/5780]  eta: 0:12:39  model_time: 0.1587 (0.1584)  evaluator_time: 0.0020 (0.0018)  time: 0.1704  data: 0.0081  max mem: 4926
# Test:  [1400/5780]  eta: 0:12:22  model_time: 0.1596 (0.1585)  evaluator_time: 0.0020 (0.0018)  time: 0.1705  data: 0.0079  max mem: 4926
# Test:  [1500/5780]  eta: 0:12:06  model_time: 0.1595 (0.1586)  evaluator_time: 0.0020 (0.0018)  time: 0.1708  data: 0.0078  max mem: 4926
# Test:  [1600/5780]  eta: 0:11:49  model_time: 0.1586 (0.1587)  evaluator_time: 0.0020 (0.0018)  time: 0.1708  data: 0.0083  max mem: 4926
# Test:  [1700/5780]  eta: 0:11:33  model_time: 0.1596 (0.1588)  evaluator_time: 0.0020 (0.0018)  time: 0.1703  data: 0.0079  max mem: 4926
# Test:  [1800/5780]  eta: 0:11:16  model_time: 0.1595 (0.1588)  evaluator_time: 0.0020 (0.0018)  time: 0.1708  data: 0.0083  max mem: 4926
# Test:  [1900/5780]  eta: 0:10:59  model_time: 0.1586 (0.1589)  evaluator_time: 0.0020 (0.0018)  time: 0.1698  data: 0.0078  max mem: 4926
# Test:  [2000/5780]  eta: 0:10:42  model_time: 0.1586 (0.1589)  evaluator_time: 0.0020 (0.0018)  time: 0.1709  data: 0.0081  max mem: 4926
# Test:  [2100/5780]  eta: 0:10:25  model_time: 0.1586 (0.1589)  evaluator_time: 0.0020 (0.0018)  time: 0.1697  data: 0.0078  max mem: 4926
# Test:  [2200/5780]  eta: 0:10:08  model_time: 0.1577 (0.1588)  evaluator_time: 0.0020 (0.0018)  time: 0.1699  data: 0.0085  max mem: 4926
# Test:  [2300/5780]  eta: 0:09:51  model_time: 0.1586 (0.1588)  evaluator_time: 0.0020 (0.0018)  time: 0.1693  data: 0.0076  max mem: 4926
# Test:  [2400/5780]  eta: 0:09:34  model_time: 0.1576 (0.1588)  evaluator_time: 0.0020 (0.0018)  time: 0.1687  data: 0.0078  max mem: 4926
# Test:  [2500/5780]  eta: 0:09:17  model_time: 0.1576 (0.1588)  evaluator_time: 0.0020 (0.0018)  time: 0.1690  data: 0.0079  max mem: 4926
# Test:  [2600/5780]  eta: 0:09:00  model_time: 0.1576 (0.1587)  evaluator_time: 0.0020 (0.0018)  time: 0.1689  data: 0.0077  max mem: 4926
# Test:  [2700/5780]  eta: 0:08:43  model_time: 0.1576 (0.1587)  evaluator_time: 0.0020 (0.0018)  time: 0.1687  data: 0.0079  max mem: 4926
# Test:  [2800/5780]  eta: 0:08:26  model_time: 0.1576 (0.1587)  evaluator_time: 0.0020 (0.0018)  time: 0.1696  data: 0.0085  max mem: 4926
# Test:  [2900/5780]  eta: 0:08:09  model_time: 0.1577 (0.1587)  evaluator_time: 0.0020 (0.0018)  time: 0.1688  data: 0.0078  max mem: 4926
# Test:  [3000/5780]  eta: 0:07:51  model_time: 0.1576 (0.1586)  evaluator_time: 0.0020 (0.0018)  time: 0.1691  data: 0.0081  max mem: 4926
# Test:  [3100/5780]  eta: 0:07:34  model_time: 0.1576 (0.1586)  evaluator_time: 0.0020 (0.0018)  time: 0.1690  data: 0.0082  max mem: 4926
# Test:  [3200/5780]  eta: 0:07:17  model_time: 0.1576 (0.1586)  evaluator_time: 0.0020 (0.0018)  time: 0.1690  data: 0.0082  max mem: 4926
# Test:  [3300/5780]  eta: 0:07:00  model_time: 0.1576 (0.1586)  evaluator_time: 0.0020 (0.0018)  time: 0.1691  data: 0.0082  max mem: 4926
# Test:  [3400/5780]  eta: 0:06:43  model_time: 0.1576 (0.1586)  evaluator_time: 0.0020 (0.0018)  time: 0.1692  data: 0.0082  max mem: 4926
# Test:  [3500/5780]  eta: 0:06:26  model_time: 0.1576 (0.1585)  evaluator_time: 0.0020 (0.0018)  time: 0.1687  data: 0.0082  max mem: 4926
# Test:  [3600/5780]  eta: 0:06:09  model_time: 0.1576 (0.1585)  evaluator_time: 0.0020 (0.0018)  time: 0.1691  data: 0.0081  max mem: 4926
# Test:  [3700/5780]  eta: 0:05:52  model_time: 0.1576 (0.1585)  evaluator_time: 0.0020 (0.0018)  time: 0.1688  data: 0.0079  max mem: 4926
# Test:  [3800/5780]  eta: 0:05:35  model_time: 0.1576 (0.1585)  evaluator_time: 0.0020 (0.0018)  time: 0.1688  data: 0.0078  max mem: 4926
# Test:  [3900/5780]  eta: 0:05:18  model_time: 0.1576 (0.1585)  evaluator_time: 0.0020 (0.0018)  time: 0.1741  data: 0.0089  max mem: 4926
# Test:  [4000/5780]  eta: 0:05:01  model_time: 0.1576 (0.1585)  evaluator_time: 0.0020 (0.0018)  time: 0.1692  data: 0.0082  max mem: 4926
# Test:  [4100/5780]  eta: 0:04:44  model_time: 0.1576 (0.1585)  evaluator_time: 0.0020 (0.0018)  time: 0.1689  data: 0.0086  max mem: 4926
# Test:  [4200/5780]  eta: 0:04:27  model_time: 0.1576 (0.1585)  evaluator_time: 0.0020 (0.0018)  time: 0.1688  data: 0.0083  max mem: 4926
# Test:  [4300/5780]  eta: 0:04:10  model_time: 0.1576 (0.1584)  evaluator_time: 0.0020 (0.0018)  time: 0.1687  data: 0.0078  max mem: 4926
# Test:  [4400/5780]  eta: 0:03:53  model_time: 0.1576 (0.1584)  evaluator_time: 0.0020 (0.0018)  time: 0.1685  data: 0.0079  max mem: 4926
# Test:  [4500/5780]  eta: 0:03:37  model_time: 0.1576 (0.1584)  evaluator_time: 0.0020 (0.0018)  time: 0.1690  data: 0.0083  max mem: 4926
# Test:  [4600/5780]  eta: 0:03:20  model_time: 0.1576 (0.1584)  evaluator_time: 0.0020 (0.0018)  time: 0.1691  data: 0.0081  max mem: 4926
# Test:  [4700/5780]  eta: 0:03:03  model_time: 0.1576 (0.1584)  evaluator_time: 0.0020 (0.0018)  time: 0.1689  data: 0.0082  max mem: 4926
# Test:  [4800/5780]  eta: 0:02:46  model_time: 0.1576 (0.1584)  evaluator_time: 0.0020 (0.0018)  time: 0.1691  data: 0.0085  max mem: 4926
# Test:  [4900/5780]  eta: 0:02:29  model_time: 0.1576 (0.1584)  evaluator_time: 0.0020 (0.0018)  time: 0.1688  data: 0.0080  max mem: 4926
# Test:  [5000/5780]  eta: 0:02:12  model_time: 0.1576 (0.1584)  evaluator_time: 0.0020 (0.0018)  time: 0.1682  data: 0.0075  max mem: 4926
# Test:  [5100/5780]  eta: 0:01:55  model_time: 0.1578 (0.1584)  evaluator_time: 0.0020 (0.0018)  time: 0.1695  data: 0.0081  max mem: 4926
# Test:  [5200/5780]  eta: 0:01:38  model_time: 0.1576 (0.1584)  evaluator_time: 0.0020 (0.0018)  time: 0.1687  data: 0.0078  max mem: 4926
# Test:  [5300/5780]  eta: 0:01:21  model_time: 0.1576 (0.1583)  evaluator_time: 0.0020 (0.0018)  time: 0.1690  data: 0.0081  max mem: 4926
# Test:  [5400/5780]  eta: 0:01:04  model_time: 0.1576 (0.1583)  evaluator_time: 0.0020 (0.0018)  time: 0.1695  data: 0.0080  max mem: 4926
# Test:  [5500/5780]  eta: 0:00:47  model_time: 0.1586 (0.1583)  evaluator_time: 0.0020 (0.0018)  time: 0.1698  data: 0.0082  max mem: 4926
# Test:  [5600/5780]  eta: 0:00:30  model_time: 0.1576 (0.1583)  evaluator_time: 0.0020 (0.0018)  time: 0.1693  data: 0.0087  max mem: 4926
# Test:  [5700/5780]  eta: 0:00:13  model_time: 0.1576 (0.1583)  evaluator_time: 0.0020 (0.0018)  time: 0.1683  data: 0.0075  max mem: 4926
# Test:  [5779/5780]  eta: 0:00:00  model_time: 0.1576 (0.1583)  evaluator_time: 0.0020 (0.0018)  time: 0.1689  data: 0.0078  max mem: 4926
# Test: Total time: 0:16:19 (0.1695 s / it)
# Averaged stats: model_time: 0.1576 (0.1583)  evaluator_time: 0.0020 (0.0018)
# Accumulating evaluation results...
# DONE (t=2.30s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000

# %% [markdown]
# **Save model**

# %%
MODEL_PATH = os.path.join(ROOT_DIR, "models", "food_detection", "wideres_backbone.pt")

torch.save(model.state_dict(), MODEL_PATH)

# %% [markdown]
# # Evaluate
