# %% [markdown]
# <a href="https://colab.research.google.com/github/BenRoche18/Im2Calories/blob/master/food_classification_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Set up environment

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torchsummary import summary

import os
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import copy
import shutil
from PIL import Image
from tqdm.autonotebook import tqdm
import sys

# %% [markdown]
# **Import utility functions from Pytorch**

# %%
ROOT_DIR = os.path.dirname(os.getcwd())

sys.path.append(os.path.join(ROOT_DIR, "utilities"))

from engine import train_one_epoch, evaluate
import utils

# %% [markdown]
# **Enable GPU**

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Running on", device)
# Out:
# Running on cuda:0

# %% [markdown]
# **Declare parameters**

# %%
IMAGE_SIZE = 512
BATCH_SIZE = 2

# %% [markdown]
# # Input data

# %% [markdown]
# **Fetch condensed classes from text file**

# %%
FOOD256_DIR = os.path.join(os.path.abspath(os.sep), "Datasets", "food256")
CONDENSED_CLASSES_PATH = os.path.join(FOOD256_DIR, "condensed-category.txt")

with open(CONDENSED_CLASSES_PATH, 'r') as file:
    file.readline()
    classes = {line.split('\t')[0]:line.split('\t')[1].strip() for line in file.readlines()}

# %% [markdown]
# **Extract condensed classes from dataset**
#
# Extract images and labels that correspond to condensed dataset and relabel classes so they are incremented by 1.

# %%
IMAGES_DIR = os.path.join(FOOD256_DIR, "condensed images")
LABELS_DIR = os.path.join(FOOD256_DIR, "condensed labels")

if not os.path.exists(IMAGES_DIR):
    os.makedirs(IMAGES_DIR)
    os.makedirs(LABELS_DIR)

    for class_id in classes.keys():
        class_path = os.path.join(FOOD256_DIR, class_id, "bb_info.txt")
        
        # normalise class_id to determine new label
        lbl = str(list(classes.keys()).index(class_id) + 1)
            
        with open(class_path, 'r') as file:
            # ignore headers
            file.readline()
            
            for line in file.readlines():
                line = line.strip().split()
                img_path = os.path.join(FOOD256_DIR, class_id, line[0]+".jpg")

                # copy img to images directory
                dest = os.path.join(IMAGES_DIR, line[0]+".jpg")
                shutil.copy(img_path, dest)

                 # copy bounding box annotation into txt file in labels directory
                with open(os.path.join(LABELS_DIR, line[0]+".txt"), 'w') as box_file:
                    box = lbl + " " + " ".join(line[1:])
                    box_file.write(box)

# %% [markdown]
# **Define FoodDataset class as subclass of Dataset**

# %%
class CondensedFoodDataset(torch.utils.data.Dataset):
    def __init__(self, root, transform=None):
        self.root = root
        self.transform = transform
        self.images = list(sorted(os.listdir(os.path.join(root, "condensed images"))))
        self.classes = []
        with open(os.path.join(root, "condensed-category.txt"), 'r') as file:
            file.readline()
            for line in file.readlines():
                self.classes.append(line.strip().split("\t")[1])
        
    def __getitem__(self, index):
        # image
        img_path = os.path.join(self.root, "condensed images", self.images[index])
        img = Image.open(img_path).convert("RGB")
        
        #label
        lbl_path = img_path.replace("images", "labels").replace(".jpg", ".txt")
        with open(lbl_path, 'r') as file:
            line = file.read().split()
            
        lbl = int(line[0]) - 1
            
        x1 = float(line[1])
        y1 = float(line[2])
        x2 = float(line[3])
        y2 = float(line[4])

        target = {
            "image_id": torch.as_tensor([index]),
            "labels": torch.as_tensor([lbl], dtype=torch.int64),
            "boxes": torch.as_tensor([[x1, y1, x2, y2]], dtype=torch.float32),
            "area": torch.as_tensor([(x2-x1)*(y2-y1)]),
            "iscrowd": torch.as_tensor([0], dtype=torch.int64)
        }
        
        if self.transform is not None:
            img, target = self.transform(img, target)
            
        return img, target
        
    
    def __len__(self):
        return len(self.images)

# %% [markdown]
# **Format images**

# %%
# custom transform for R-CNN input
class CustomTransform:
    def __init__(self, image_size):
        self.image_size = image_size
        
    def __call__(self, img, target):
        # resize to a max of IMAGE_SIZE
        w, h = img.size
        scale = min(IMAGE_SIZE/w, IMAGE_SIZE/h)
        img = transforms.functional.resize(img, (int(h*scale), int(w*scale)))
        
        # update bounding boxes
        target["boxes"] *= scale
        
        # add padding to a size of IMAGE_SIZE
        img = transforms.functional.pad(img, (0, 0, IMAGE_SIZE-int(w*scale), IMAGE_SIZE-int(h*scale)))
        
        # convert to tensor
        img = transforms.functional.to_tensor(img)

        # normalize
        img = img / 255
        return img, target

transform = CustomTransform(image_size=IMAGE_SIZE)

food_raw = CondensedFoodDataset(FOOD256_DIR, transform=transform)
food_size = len(food_raw)

class_names = food_raw.classes

# %% [markdown]
# **Split dataset into train and val sets**

# %%
indices = torch.randperm(food_size).tolist()

# define how to batch data (i.e not combine target dicitonaries)
def collate_fn(batch):
    return tuple(zip(*batch))

# take 80% as training
train_raw = torch.utils.data.Subset(food_raw, indices[:int(0.8*food_size)])
train_size = len(train_raw)
train_loader = torch.utils.data.DataLoader(train_raw, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fn)

# take 20% as validation
val_raw = torch.utils.data.Subset(food_raw, indices[int(0.8*food_size):])
val_size = len(val_raw)
val_loader = torch.utils.data.DataLoader(val_raw, batch_size=max(1, BATCH_SIZE//2), shuffle=True, collate_fn=collate_fn)

# %% [markdown]
# **Show example image with bounding boxes**

# %%
fig, axis= plt.subplots(1)

#randomly select image from dataset
i = np.random.randint(train_size)
img = train_raw[i][0].numpy()
img = np.transpose(img, (1,2,0))
img = img * 255
img = np.clip(img, 0, 1)
plt.imshow(img)

# draw bounding box
x1, y1, x2, y2 = train_raw[i][1]["boxes"][0]
box = patches.Rectangle((x1, y1), x2-x1, y2-y1, linewidth=2, edgecolor='r', facecolor='none')
axis.add_patch(box)

plt.title(class_names[train_raw[i][1]["labels"][0]])

fig

# %% [markdown]
# # Model

# %% [markdown]
# **Fetch pretrained mobilenet on food101 dataset as backbone**

# %%
BACKBONE_PATH = os.path.join(ROOT_DIR, "models", "food_classification", "fine_tuning_mobilenet.pt")

print("Fetching pretrained backbone... ", end="")
backbone = torchvision.models.mobilenet_v2(pretrained=False)

# replace classification head
num_features = backbone.classifier[1].in_features
backbone.classifier[1] = torch.nn.Linear(num_features, 101)

# load trained weights
backbone.load_state_dict(torch.load(BACKBONE_PATH))

# remove classification head
backbone = backbone.features
backbone.out_channels = 1280

print("done")
# Out:
# Fetching pretrained backbone... done

# %% [markdown]
# **Create Faster R-CNN from wide resnet backbone**

# %%
print("Creating R-CNN... ", end="")
anchor_generator = torchvision.models.detection.rpn.AnchorGenerator(sizes=((32, 64, 128, 256, 512),), aspect_ratios=((0.5, 1.0, 2.0),))

roi_pooler = torchvision.ops.MultiScaleRoIAlign(featmap_names=['0'], output_size=7, sampling_ratio=2)

model = torchvision.models.detection.FasterRCNN(backbone, num_classes=len(class_names), rpn_anchor_generator=anchor_generator, box_roi_pool=roi_pooler)

model = model.to(device)
print("done")
# Out:
# Creating R-CNN... done

# %% [markdown]
# # Train

# %% [markdown]
# **Declare optimizer**

# %%
learning_rate = 0.001

# fetch trainable parameters for transfer learning(where requires_grad = true)
params = [p for p in model.parameters() if p.requires_grad]

optimizer = torch.optim.SGD(params, lr=learning_rate)

# %% [markdown]
# **Train model**

# %%
num_epochs = 10

for epoch in range(num_epochs):
    train_one_epoch(model, optimizer, train_loader, device, epoch, print_freq=10)
    evaluate(model, val_loader, device)
# Out:
# Epoch: [0]  [   0/3673]  eta: 1:44:19  lr: 0.000020  loss: 5.0081 (5.0081)  loss_classifier: 4.1692 (4.1692)  loss_box_reg: 0.0443 (0.0443)  loss_objectness: 0.7068 (0.7068)  loss_rpn_box_reg: 0.0878 (0.0878)  time: 1.7043  data: 0.0798  max mem: 2410
# Epoch: [0]  [  10/3673]  eta: 0:27:18  lr: 0.000120  loss: 4.9470 (4.9170)  loss_classifier: 4.1286 (4.0962)  loss_box_reg: 0.0499 (0.0490)  loss_objectness: 0.7068 (0.7065)  loss_rpn_box_reg: 0.0604 (0.0653)  time: 0.4473  data: 0.0885  max mem: 2725
# Epoch: [0]  [  20/3673]  eta: 0:23:25  lr: 0.000220  loss: 4.7202 (4.6883)  loss_classifier: 3.9141 (3.8780)  loss_box_reg: 0.0436 (0.0445)  loss_objectness: 0.7010 (0.7042)  loss_rpn_box_reg: 0.0487 (0.0616)  time: 0.3188  data: 0.0871  max mem: 2725
# Epoch: [0]  [  30/3673]  eta: 0:22:04  lr: 0.000320  loss: 3.9498 (4.2716)  loss_classifier: 3.1418 (3.4649)  loss_box_reg: 0.0382 (0.0450)  loss_objectness: 0.6960 (0.6991)  loss_rpn_box_reg: 0.0459 (0.0626)  time: 0.3176  data: 0.0873  max mem: 2725
# Epoch: [0]  [  40/3673]  eta: 0:21:16  lr: 0.000420  loss: 2.6665 (3.7804)  loss_classifier: 1.8639 (2.9752)  loss_box_reg: 0.0507 (0.0467)  loss_objectness: 0.6746 (0.6918)  loss_rpn_box_reg: 0.0552 (0.0667)  time: 0.3162  data: 0.0855  max mem: 2725
# Epoch: [0]  [  50/3673]  eta: 0:20:42  lr: 0.000519  loss: 1.9158 (3.3895)  loss_classifier: 1.1286 (2.5934)  loss_box_reg: 0.0573 (0.0488)  loss_objectness: 0.6606 (0.6829)  loss_rpn_box_reg: 0.0483 (0.0644)  time: 0.3107  data: 0.0776  max mem: 2725
# Epoch: [0]  [  60/3673]  eta: 0:20:24  lr: 0.000619  loss: 1.6452 (3.0956)  loss_classifier: 0.8957 (2.3090)  loss_box_reg: 0.0580 (0.0502)  loss_objectness: 0.6334 (0.6733)  loss_rpn_box_reg: 0.0435 (0.0630)  time: 0.3132  data: 0.0799  max mem: 2725
# Epoch: [0]  [  70/3673]  eta: 0:20:10  lr: 0.000719  loss: 1.5731 (2.8772)  loss_classifier: 0.8553 (2.1044)  loss_box_reg: 0.0589 (0.0512)  loss_objectness: 0.6139 (0.6623)  loss_rpn_box_reg: 0.0367 (0.0593)  time: 0.3183  data: 0.0817  max mem: 2725
# Epoch: [0]  [  80/3673]  eta: 0:20:00  lr: 0.000819  loss: 1.4940 (2.7017)  loss_classifier: 0.7909 (1.9400)  loss_box_reg: 0.0564 (0.0512)  loss_objectness: 0.5768 (0.6499)  loss_rpn_box_reg: 0.0439 (0.0606)  time: 0.3198  data: 0.0823  max mem: 2725
# Epoch: [0]  [  90/3673]  eta: 0:19:53  lr: 0.000919  loss: 1.2972 (2.5369)  loss_classifier: 0.6234 (1.7867)  loss_box_reg: 0.0711 (0.0541)  loss_objectness: 0.5417 (0.6367)  loss_rpn_box_reg: 0.0588 (0.0594)  time: 0.3232  data: 0.0904  max mem: 2725
# Epoch: [0]  [ 100/3673]  eta: 0:19:44  lr: 0.001019  loss: 1.1473 (2.3940)  loss_classifier: 0.4993 (1.6553)  loss_box_reg: 0.0772 (0.0557)  loss_objectness: 0.5158 (0.6233)  loss_rpn_box_reg: 0.0482 (0.0597)  time: 0.3216  data: 0.0894  max mem: 2725
# Epoch: [0]  [ 110/3673]  eta: 0:19:35  lr: 0.001119  loss: 1.0010 (2.2648)  loss_classifier: 0.4115 (1.5408)  loss_box_reg: 0.0786 (0.0575)  loss_objectness: 0.4838 (0.6089)  loss_rpn_box_reg: 0.0367 (0.0577)  time: 0.3151  data: 0.0830  max mem: 2725
# Epoch: [0]  [ 120/3673]  eta: 0:19:29  lr: 0.001219  loss: 0.9264 (2.1532)  loss_classifier: 0.3720 (1.4437)  loss_box_reg: 0.0803 (0.0589)  loss_objectness: 0.4462 (0.5940)  loss_rpn_box_reg: 0.0332 (0.0566)  time: 0.3174  data: 0.0856  max mem: 2725
# Epoch: [0]  [ 130/3673]  eta: 0:19:26  lr: 0.001319  loss: 0.8918 (2.0520)  loss_classifier: 0.3546 (1.3580)  loss_box_reg: 0.0727 (0.0594)  loss_objectness: 0.4131 (0.5790)  loss_rpn_box_reg: 0.0350 (0.0556)  time: 0.3255  data: 0.0927  max mem: 2725
# Epoch: [0]  [ 140/3673]  eta: 0:19:22  lr: 0.001419  loss: 0.8117 (1.9622)  loss_classifier: 0.3333 (1.2833)  loss_box_reg: 0.0722 (0.0601)  loss_objectness: 0.3786 (0.5642)  loss_rpn_box_reg: 0.0342 (0.0545)  time: 0.3270  data: 0.0933  max mem: 2725
# Epoch: [0]  [ 150/3673]  eta: 0:19:19  lr: 0.001518  loss: 0.7855 (1.8807)  loss_classifier: 0.3263 (1.2172)  loss_box_reg: 0.0697 (0.0605)  loss_objectness: 0.3570 (0.5495)  loss_rpn_box_reg: 0.0280 (0.0535)  time: 0.3275  data: 0.0933  max mem: 2725
# Epoch: [0]  [ 160/3673]  eta: 0:19:14  lr: 0.001618  loss: 0.7767 (1.8112)  loss_classifier: 0.3336 (1.1606)  loss_box_reg: 0.0697 (0.0613)  loss_objectness: 0.3357 (0.5357)  loss_rpn_box_reg: 0.0392 (0.0536)  time: 0.3268  data: 0.0930  max mem: 2725
# Epoch: [0]  [ 170/3673]  eta: 0:19:07  lr: 0.001718  loss: 0.8022 (1.7502)  loss_classifier: 0.3379 (1.1114)  loss_box_reg: 0.0746 (0.0622)  loss_objectness: 0.3170 (0.5223)  loss_rpn_box_reg: 0.0483 (0.0542)  time: 0.3173  data: 0.0842  max mem: 2725
# Epoch: [0]  [ 180/3673]  eta: 0:19:03  lr: 0.001818  loss: 0.7050 (1.6884)  loss_classifier: 0.2841 (1.0640)  loss_box_reg: 0.0690 (0.0622)  loss_objectness: 0.2813 (0.5084)  loss_rpn_box_reg: 0.0457 (0.0538)  time: 0.3163  data: 0.0829  max mem: 2725
# Epoch: [0]  [ 190/3673]  eta: 0:18:58  lr: 0.001918  loss: 0.6488 (1.6341)  loss_classifier: 0.2756 (1.0235)  loss_box_reg: 0.0690 (0.0625)  loss_objectness: 0.2509 (0.4946)  loss_rpn_box_reg: 0.0420 (0.0534)  time: 0.3191  data: 0.0853  max mem: 2725
# Epoch: [0]  [ 200/3673]  eta: 0:18:54  lr: 0.002018  loss: 0.6506 (1.5862)  loss_classifier: 0.3152 (0.9886)  loss_box_reg: 0.0782 (0.0634)  loss_objectness: 0.2329 (0.4814)  loss_rpn_box_reg: 0.0363 (0.0528)  time: 0.3201  data: 0.0858  max mem: 2725
# Epoch: [0]  [ 210/3673]  eta: 0:18:49  lr: 0.002118  loss: 0.6403 (1.5379)  loss_classifier: 0.3094 (0.9541)  loss_box_reg: 0.0782 (0.0634)  loss_objectness: 0.2123 (0.4685)  loss_rpn_box_reg: 0.0333 (0.0518)  time: 0.3208  data: 0.0869  max mem: 2725
# Epoch: [0]  [ 220/3673]  eta: 0:18:47  lr: 0.002218  loss: 0.5822 (1.4940)  loss_classifier: 0.2645 (0.9227)  loss_box_reg: 0.0696 (0.0635)  loss_objectness: 0.2015 (0.4563)  loss_rpn_box_reg: 0.0296 (0.0515)  time: 0.3246  data: 0.0910  max mem: 2725
# Epoch: [0]  [ 230/3673]  eta: 0:18:41  lr: 0.002318  loss: 0.5428 (1.4543)  loss_classifier: 0.2426 (0.8933)  loss_box_reg: 0.0658 (0.0636)  loss_objectness: 0.1880 (0.4452)  loss_rpn_box_reg: 0.0379 (0.0521)  time: 0.3222  data: 0.0878  max mem: 2725
# Epoch: [0]  [ 240/3673]  eta: 0:18:39  lr: 0.002418  loss: 0.5765 (1.4174)  loss_classifier: 0.2605 (0.8674)  loss_box_reg: 0.0731 (0.0639)  loss_objectness: 0.1777 (0.4342)  loss_rpn_box_reg: 0.0361 (0.0519)  time: 0.3224  data: 0.0878  max mem: 2725
# Epoch: [0]  [ 250/3673]  eta: 0:18:34  lr: 0.002517  loss: 0.5965 (1.3847)  loss_classifier: 0.2972 (0.8445)  loss_box_reg: 0.0755 (0.0644)  loss_objectness: 0.1736 (0.4241)  loss_rpn_box_reg: 0.0355 (0.0518)  time: 0.3231  data: 0.0886  max mem: 2725
# Epoch: [0]  [ 260/3673]  eta: 0:18:31  lr: 0.002617  loss: 0.5658 (1.3522)  loss_classifier: 0.2919 (0.8224)  loss_box_reg: 0.0748 (0.0648)  loss_objectness: 0.1597 (0.4138)  loss_rpn_box_reg: 0.0317 (0.0512)  time: 0.3197  data: 0.0849  max mem: 2725
# Epoch: [0]  [ 270/3673]  eta: 0:18:28  lr: 0.002717  loss: 0.5044 (1.3216)  loss_classifier: 0.2587 (0.8002)  loss_box_reg: 0.0653 (0.0646)  loss_objectness: 0.1548 (0.4049)  loss_rpn_box_reg: 0.0346 (0.0519)  time: 0.3260  data: 0.0913  max mem: 2725
# Epoch: [0]  [ 280/3673]  eta: 0:18:24  lr: 0.002817  loss: 0.5355 (1.2949)  loss_classifier: 0.2754 (0.7823)  loss_box_reg: 0.0738 (0.0653)  loss_objectness: 0.1424 (0.3954)  loss_rpn_box_reg: 0.0478 (0.0519)  time: 0.3250  data: 0.0890  max mem: 2725
# Epoch: [0]  [ 290/3673]  eta: 0:18:21  lr: 0.002917  loss: 0.5148 (1.2663)  loss_classifier: 0.2626 (0.7629)  loss_box_reg: 0.0693 (0.0651)  loss_objectness: 0.1359 (0.3867)  loss_rpn_box_reg: 0.0380 (0.0516)  time: 0.3255  data: 0.0885  max mem: 2725
# Epoch: [0]  [ 300/3673]  eta: 0:18:17  lr: 0.003017  loss: 0.4647 (1.2403)  loss_classifier: 0.2225 (0.7460)  loss_box_reg: 0.0633 (0.0657)  loss_objectness: 0.1279 (0.3776)  loss_rpn_box_reg: 0.0239 (0.0511)  time: 0.3221  data: 0.0860  max mem: 2725
# Epoch: [0]  [ 310/3673]  eta: 0:18:14  lr: 0.003117  loss: 0.5026 (1.2156)  loss_classifier: 0.2713 (0.7298)  loss_box_reg: 0.0752 (0.0659)  loss_objectness: 0.1137 (0.3694)  loss_rpn_box_reg: 0.0301 (0.0505)  time: 0.3212  data: 0.0856  max mem: 2725
# Epoch: [0]  [ 320/3673]  eta: 0:18:11  lr: 0.003217  loss: 0.5026 (1.1925)  loss_classifier: 0.2604 (0.7141)  loss_box_reg: 0.0752 (0.0659)  loss_objectness: 0.1189 (0.3618)  loss_rpn_box_reg: 0.0339 (0.0507)  time: 0.3305  data: 0.0945  max mem: 2725
# Epoch: [0]  [ 330/3673]  eta: 0:18:07  lr: 0.003317  loss: 0.4760 (1.1714)  loss_classifier: 0.2552 (0.7005)  loss_box_reg: 0.0785 (0.0663)  loss_objectness: 0.1176 (0.3542)  loss_rpn_box_reg: 0.0341 (0.0504)  time: 0.3221  data: 0.0866  max mem: 2725
# Epoch: [0]  [ 340/3673]  eta: 0:18:04  lr: 0.003417  loss: 0.4760 (1.1508)  loss_classifier: 0.2388 (0.6865)  loss_box_reg: 0.0730 (0.0663)  loss_objectness: 0.1154 (0.3473)  loss_rpn_box_reg: 0.0381 (0.0507)  time: 0.3203  data: 0.0847  max mem: 2725
# Epoch: [0]  [ 350/3673]  eta: 0:18:00  lr: 0.003516  loss: 0.4698 (1.1314)  loss_classifier: 0.2388 (0.6735)  loss_box_reg: 0.0714 (0.0664)  loss_objectness: 0.1025 (0.3407)  loss_rpn_box_reg: 0.0406 (0.0508)  time: 0.3236  data: 0.0882  max mem: 2725
# Epoch: [0]  [ 360/3673]  eta: 0:17:57  lr: 0.003616  loss: 0.4378 (1.1123)  loss_classifier: 0.2258 (0.6612)  loss_box_reg: 0.0673 (0.0665)  loss_objectness: 0.1010 (0.3341)  loss_rpn_box_reg: 0.0332 (0.0505)  time: 0.3210  data: 0.0860  max mem: 2725
# Epoch: [0]  [ 370/3673]  eta: 0:17:52  lr: 0.003716  loss: 0.4378 (1.0940)  loss_classifier: 0.2304 (0.6496)  loss_box_reg: 0.0682 (0.0666)  loss_objectness: 0.0954 (0.3276)  loss_rpn_box_reg: 0.0322 (0.0501)  time: 0.3200  data: 0.0851  max mem: 2725
# Epoch: [0]  [ 380/3673]  eta: 0:17:48  lr: 0.003816  loss: 0.4463 (1.0763)  loss_classifier: 0.2304 (0.6380)  loss_box_reg: 0.0715 (0.0665)  loss_objectness: 0.0934 (0.3217)  loss_rpn_box_reg: 0.0324 (0.0501)  time: 0.3114  data: 0.0762  max mem: 2725
# Epoch: [0]  [ 390/3673]  eta: 0:17:44  lr: 0.003916  loss: 0.4463 (1.0597)  loss_classifier: 0.2225 (0.6276)  loss_box_reg: 0.0689 (0.0666)  loss_objectness: 0.0946 (0.3159)  loss_rpn_box_reg: 0.0302 (0.0496)  time: 0.3124  data: 0.0766  max mem: 2725
# Epoch: [0]  [ 400/3673]  eta: 0:17:40  lr: 0.004016  loss: 0.4061 (1.0433)  loss_classifier: 0.2326 (0.6172)  loss_box_reg: 0.0689 (0.0665)  loss_objectness: 0.0880 (0.3102)  loss_rpn_box_reg: 0.0339 (0.0494)  time: 0.3175  data: 0.0820  max mem: 2725
# Epoch: [0]  [ 410/3673]  eta: 0:17:37  lr: 0.004116  loss: 0.4428 (1.0288)  loss_classifier: 0.2459 (0.6081)  loss_box_reg: 0.0710 (0.0668)  loss_objectness: 0.0833 (0.3047)  loss_rpn_box_reg: 0.0330 (0.0490)  time: 0.3193  data: 0.0840  max mem: 2725
# Epoch: [0]  [ 420/3673]  eta: 0:17:34  lr: 0.004216  loss: 0.4219 (1.0130)  loss_classifier: 0.2494 (0.5984)  loss_box_reg: 0.0715 (0.0667)  loss_objectness: 0.0790 (0.2994)  loss_rpn_box_reg: 0.0271 (0.0485)  time: 0.3237  data: 0.0885  max mem: 2725
# Epoch: [0]  [ 430/3673]  eta: 0:17:30  lr: 0.004316  loss: 0.4227 (0.9998)  loss_classifier: 0.2136 (0.5897)  loss_box_reg: 0.0649 (0.0668)  loss_objectness: 0.0799 (0.2945)  loss_rpn_box_reg: 0.0312 (0.0487)  time: 0.3247  data: 0.0906  max mem: 2725
# Epoch: [0]  [ 440/3673]  eta: 0:17:27  lr: 0.004416  loss: 0.4544 (0.9874)  loss_classifier: 0.2513 (0.5820)  loss_box_reg: 0.0832 (0.0673)  loss_objectness: 0.0784 (0.2893)  loss_rpn_box_reg: 0.0429 (0.0487)  time: 0.3254  data: 0.0920  max mem: 2725
# Epoch: [0]  [ 450/3673]  eta: 0:17:23  lr: 0.004515  loss: 0.4348 (0.9739)  loss_classifier: 0.2499 (0.5737)  loss_box_reg: 0.0752 (0.0673)  loss_objectness: 0.0630 (0.2847)  loss_rpn_box_reg: 0.0298 (0.0483)  time: 0.3225  data: 0.0880  max mem: 2725
# Epoch: [0]  [ 460/3673]  eta: 0:17:20  lr: 0.004615  loss: 0.3954 (0.9611)  loss_classifier: 0.2061 (0.5657)  loss_box_reg: 0.0722 (0.0673)  loss_objectness: 0.0706 (0.2801)  loss_rpn_box_reg: 0.0298 (0.0481)  time: 0.3166  data: 0.0810  max mem: 2725
# Epoch: [0]  [ 470/3673]  eta: 0:17:16  lr: 0.004715  loss: 0.4186 (0.9496)  loss_classifier: 0.2210 (0.5586)  loss_box_reg: 0.0750 (0.0676)  loss_objectness: 0.0637 (0.2755)  loss_rpn_box_reg: 0.0354 (0.0480)  time: 0.3197  data: 0.0845  max mem: 2725
# Epoch: [0]  [ 480/3673]  eta: 0:17:13  lr: 0.004815  loss: 0.4136 (0.9378)  loss_classifier: 0.2240 (0.5513)  loss_box_reg: 0.0762 (0.0676)  loss_objectness: 0.0553 (0.2710)  loss_rpn_box_reg: 0.0351 (0.0479)  time: 0.3220  data: 0.0884  max mem: 2725
# Epoch: [0]  [ 490/3673]  eta: 0:17:09  lr: 0.004915  loss: 0.3894 (0.9266)  loss_classifier: 0.2107 (0.5445)  loss_box_reg: 0.0768 (0.0678)  loss_objectness: 0.0521 (0.2667)  loss_rpn_box_reg: 0.0273 (0.0476)  time: 0.3198  data: 0.0860  max mem: 2725
# Epoch: [0]  [ 500/3673]  eta: 0:17:05  lr: 0.005015  loss: 0.3915 (0.9161)  loss_classifier: 0.2098 (0.5381)  loss_box_reg: 0.0783 (0.0682)  loss_objectness: 0.0456 (0.2624)  loss_rpn_box_reg: 0.0333 (0.0475)  time: 0.3149  data: 0.0811  max mem: 2725
# Epoch: [0]  [ 510/3673]  eta: 0:17:01  lr: 0.005115  loss: 0.4182 (0.9062)  loss_classifier: 0.2288 (0.5321)  loss_box_reg: 0.0864 (0.0686)  loss_objectness: 0.0451 (0.2583)  loss_rpn_box_reg: 0.0365 (0.0473)  time: 0.3112  data: 0.0782  max mem: 2725
# Epoch: [0]  [ 520/3673]  eta: 0:16:58  lr: 0.005215  loss: 0.4328 (0.8966)  loss_classifier: 0.2479 (0.5265)  loss_box_reg: 0.0945 (0.0690)  loss_objectness: 0.0451 (0.2542)  loss_rpn_box_reg: 0.0312 (0.0469)  time: 0.3123  data: 0.0789  max mem: 2725
# Epoch: [0]  [ 530/3673]  eta: 0:16:55  lr: 0.005315  loss: 0.3798 (0.8866)  loss_classifier: 0.2199 (0.5205)  loss_box_reg: 0.0810 (0.0691)  loss_objectness: 0.0426 (0.2504)  loss_rpn_box_reg: 0.0207 (0.0466)  time: 0.3192  data: 0.0854  max mem: 2725
# Epoch: [0]  [ 540/3673]  eta: 0:16:51  lr: 0.005415  loss: 0.3589 (0.8774)  loss_classifier: 0.2010 (0.5146)  loss_box_reg: 0.0755 (0.0691)  loss_objectness: 0.0489 (0.2467)  loss_rpn_box_reg: 0.0260 (0.0470)  time: 0.3250  data: 0.0908  max mem: 2725
# Epoch: [0]  [ 550/3673]  eta: 0:16:49  lr: 0.005514  loss: 0.3916 (0.8688)  loss_classifier: 0.1927 (0.5089)  loss_box_reg: 0.0658 (0.0692)  loss_objectness: 0.0466 (0.2434)  loss_rpn_box_reg: 0.0519 (0.0473)  time: 0.3274  data: 0.0934  max mem: 2725
# Epoch: [0]  [ 560/3673]  eta: 0:16:45  lr: 0.005614  loss: 0.4012 (0.8611)  loss_classifier: 0.2150 (0.5038)  loss_box_reg: 0.0811 (0.0695)  loss_objectness: 0.0493 (0.2403)  loss_rpn_box_reg: 0.0522 (0.0476)  time: 0.3233  data: 0.0904  max mem: 2725
# Epoch: [0]  [ 570/3673]  eta: 0:16:41  lr: 0.005714  loss: 0.4012 (0.8533)  loss_classifier: 0.2227 (0.4993)  loss_box_reg: 0.0856 (0.0699)  loss_objectness: 0.0462 (0.2368)  loss_rpn_box_reg: 0.0351 (0.0473)  time: 0.3145  data: 0.0825  max mem: 2725
# Epoch: [0]  [ 580/3673]  eta: 0:16:38  lr: 0.005814  loss: 0.3907 (0.8451)  loss_classifier: 0.2324 (0.4944)  loss_box_reg: 0.0956 (0.0701)  loss_objectness: 0.0379 (0.2335)  loss_rpn_box_reg: 0.0276 (0.0471)  time: 0.3174  data: 0.0846  max mem: 2725
# Epoch: [0]  [ 590/3673]  eta: 0:16:35  lr: 0.005914  loss: 0.3664 (0.8371)  loss_classifier: 0.2146 (0.4893)  loss_box_reg: 0.0787 (0.0701)  loss_objectness: 0.0448 (0.2306)  loss_rpn_box_reg: 0.0317 (0.0471)  time: 0.3225  data: 0.0893  max mem: 2725
# Epoch: [0]  [ 600/3673]  eta: 0:16:31  lr: 0.006014  loss: 0.3664 (0.8291)  loss_classifier: 0.1998 (0.4844)  loss_box_reg: 0.0754 (0.0701)  loss_objectness: 0.0405 (0.2274)  loss_rpn_box_reg: 0.0433 (0.0471)  time: 0.3224  data: 0.0892  max mem: 2725
# Epoch: [0]  [ 610/3673]  eta: 0:16:28  lr: 0.006114  loss: 0.3748 (0.8222)  loss_classifier: 0.2134 (0.4800)  loss_box_reg: 0.0823 (0.0704)  loss_objectness: 0.0364 (0.2243)  loss_rpn_box_reg: 0.0471 (0.0476)  time: 0.3251  data: 0.0917  max mem: 2725
# Epoch: [0]  [ 620/3673]  eta: 0:16:25  lr: 0.006214  loss: 0.3917 (0.8151)  loss_classifier: 0.2183 (0.4754)  loss_box_reg: 0.0857 (0.0705)  loss_objectness: 0.0358 (0.2217)  loss_rpn_box_reg: 0.0381 (0.0474)  time: 0.3212  data: 0.0889  max mem: 2725
# Epoch: [0]  [ 630/3673]  eta: 0:16:22  lr: 0.006314  loss: 0.3917 (0.8084)  loss_classifier: 0.2183 (0.4713)  loss_box_reg: 0.0819 (0.0707)  loss_objectness: 0.0370 (0.2191)  loss_rpn_box_reg: 0.0305 (0.0473)  time: 0.3223  data: 0.0905  max mem: 2725
# Epoch: [0]  [ 640/3673]  eta: 0:16:19  lr: 0.006414  loss: 0.3820 (0.8017)  loss_classifier: 0.2101 (0.4672)  loss_box_reg: 0.0787 (0.0708)  loss_objectness: 0.0356 (0.2165)  loss_rpn_box_reg: 0.0305 (0.0472)  time: 0.3253  data: 0.0928  max mem: 2725
# Epoch: [0]  [ 650/3673]  eta: 0:16:15  lr: 0.006513  loss: 0.3601 (0.7947)  loss_classifier: 0.2004 (0.4628)  loss_box_reg: 0.0744 (0.0708)  loss_objectness: 0.0356 (0.2140)  loss_rpn_box_reg: 0.0307 (0.0471)  time: 0.3217  data: 0.0890  max mem: 2725
# Epoch: [0]  [ 660/3673]  eta: 0:16:12  lr: 0.006613  loss: 0.3622 (0.7888)  loss_classifier: 0.1883 (0.4591)  loss_box_reg: 0.0747 (0.0709)  loss_objectness: 0.0471 (0.2116)  loss_rpn_box_reg: 0.0381 (0.0472)  time: 0.3248  data: 0.0932  max mem: 2725
# Epoch: [0]  [ 670/3673]  eta: 0:16:09  lr: 0.006713  loss: 0.3676 (0.7824)  loss_classifier: 0.2113 (0.4552)  loss_box_reg: 0.0786 (0.0710)  loss_objectness: 0.0442 (0.2090)  loss_rpn_box_reg: 0.0452 (0.0472)  time: 0.3235  data: 0.0916  max mem: 2725
# Epoch: [0]  [ 680/3673]  eta: 0:16:06  lr: 0.006813  loss: 0.3632 (0.7766)  loss_classifier: 0.2113 (0.4517)  loss_box_reg: 0.0808 (0.0712)  loss_objectness: 0.0377 (0.2067)  loss_rpn_box_reg: 0.0389 (0.0471)  time: 0.3219  data: 0.0890  max mem: 2725
# Epoch: [0]  [ 690/3673]  eta: 0:16:02  lr: 0.006913  loss: 0.3706 (0.7709)  loss_classifier: 0.2118 (0.4483)  loss_box_reg: 0.0826 (0.0713)  loss_objectness: 0.0294 (0.2042)  loss_rpn_box_reg: 0.0381 (0.0471)  time: 0.3214  data: 0.0879  max mem: 2725
# Epoch: [0]  [ 700/3673]  eta: 0:15:59  lr: 0.007013  loss: 0.3747 (0.7654)  loss_classifier: 0.2062 (0.4448)  loss_box_reg: 0.0843 (0.0715)  loss_objectness: 0.0294 (0.2019)  loss_rpn_box_reg: 0.0381 (0.0473)  time: 0.3195  data: 0.0856  max mem: 2725
# Epoch: [0]  [ 710/3673]  eta: 0:15:55  lr: 0.007113  loss: 0.3689 (0.7598)  loss_classifier: 0.2009 (0.4414)  loss_box_reg: 0.0829 (0.0716)  loss_objectness: 0.0257 (0.1996)  loss_rpn_box_reg: 0.0400 (0.0472)  time: 0.3130  data: 0.0785  max mem: 2725
# Epoch: [0]  [ 720/3673]  eta: 0:15:52  lr: 0.007213  loss: 0.3642 (0.7542)  loss_classifier: 0.1957 (0.4380)  loss_box_reg: 0.0783 (0.0716)  loss_objectness: 0.0345 (0.1976)  loss_rpn_box_reg: 0.0360 (0.0470)  time: 0.3102  data: 0.0743  max mem: 2725
# Epoch: [0]  [ 730/3673]  eta: 0:15:48  lr: 0.007313  loss: 0.3508 (0.7485)  loss_classifier: 0.1790 (0.4345)  loss_box_reg: 0.0679 (0.0717)  loss_objectness: 0.0377 (0.1954)  loss_rpn_box_reg: 0.0291 (0.0469)  time: 0.3171  data: 0.0810  max mem: 2725
# Epoch: [0]  [ 740/3673]  eta: 0:15:45  lr: 0.007413  loss: 0.3508 (0.7435)  loss_classifier: 0.1874 (0.4313)  loss_box_reg: 0.0748 (0.0717)  loss_objectness: 0.0391 (0.1934)  loss_rpn_box_reg: 0.0270 (0.0470)  time: 0.3175  data: 0.0830  max mem: 2725
# Epoch: [0]  [ 750/3673]  eta: 0:15:41  lr: 0.007512  loss: 0.3569 (0.7382)  loss_classifier: 0.2031 (0.4282)  loss_box_reg: 0.0781 (0.0718)  loss_objectness: 0.0430 (0.1914)  loss_rpn_box_reg: 0.0296 (0.0469)  time: 0.3184  data: 0.0844  max mem: 2725
# Epoch: [0]  [ 760/3673]  eta: 0:15:37  lr: 0.007612  loss: 0.3527 (0.7330)  loss_classifier: 0.1866 (0.4249)  loss_box_reg: 0.0781 (0.0719)  loss_objectness: 0.0275 (0.1892)  loss_rpn_box_reg: 0.0368 (0.0471)  time: 0.3112  data: 0.0759  max mem: 2725
# Epoch: [0]  [ 770/3673]  eta: 0:15:35  lr: 0.007712  loss: 0.3122 (0.7276)  loss_classifier: 0.1684 (0.4217)  loss_box_reg: 0.0705 (0.0718)  loss_objectness: 0.0190 (0.1871)  loss_rpn_box_reg: 0.0368 (0.0469)  time: 0.3153  data: 0.0791  max mem: 2725
# Epoch: [0]  [ 780/3673]  eta: 0:15:31  lr: 0.007812  loss: 0.3099 (0.7225)  loss_classifier: 0.1684 (0.4186)  loss_box_reg: 0.0733 (0.0718)  loss_objectness: 0.0251 (0.1852)  loss_rpn_box_reg: 0.0290 (0.0469)  time: 0.3267  data: 0.0903  max mem: 2725
# Epoch: [0]  [ 790/3673]  eta: 0:15:28  lr: 0.007912  loss: 0.3518 (0.7179)  loss_classifier: 0.1917 (0.4157)  loss_box_reg: 0.0746 (0.0719)  loss_objectness: 0.0314 (0.1834)  loss_rpn_box_reg: 0.0327 (0.0469)  time: 0.3209  data: 0.0848  max mem: 2725
# Epoch: [0]  [ 800/3673]  eta: 0:15:25  lr: 0.008012  loss: 0.3447 (0.7130)  loss_classifier: 0.1917 (0.4128)  loss_box_reg: 0.0741 (0.0718)  loss_objectness: 0.0389 (0.1816)  loss_rpn_box_reg: 0.0327 (0.0467)  time: 0.3181  data: 0.0818  max mem: 2725
# Epoch: [0]  [ 810/3673]  eta: 0:15:22  lr: 0.008112  loss: 0.3447 (0.7085)  loss_classifier: 0.1955 (0.4100)  loss_box_reg: 0.0769 (0.0719)  loss_objectness: 0.0233 (0.1798)  loss_rpn_box_reg: 0.0362 (0.0468)  time: 0.3286  data: 0.0919  max mem: 2725
# Epoch: [0]  [ 820/3673]  eta: 0:15:19  lr: 0.008212  loss: 0.3365 (0.7039)  loss_classifier: 0.1955 (0.4072)  loss_box_reg: 0.0769 (0.0719)  loss_objectness: 0.0233 (0.1780)  loss_rpn_box_reg: 0.0453 (0.0468)  time: 0.3316  data: 0.0947  max mem: 2725
# Epoch: [0]  [ 830/3673]  eta: 0:15:15  lr: 0.008312  loss: 0.3319 (0.6997)  loss_classifier: 0.1824 (0.4045)  loss_box_reg: 0.0748 (0.0720)  loss_objectness: 0.0365 (0.1764)  loss_rpn_box_reg: 0.0316 (0.0467)  time: 0.3177  data: 0.0815  max mem: 2725
# Epoch: [0]  [ 840/3673]  eta: 0:15:12  lr: 0.008412  loss: 0.3214 (0.6949)  loss_classifier: 0.1699 (0.4016)  loss_box_reg: 0.0672 (0.0718)  loss_objectness: 0.0403 (0.1749)  loss_rpn_box_reg: 0.0298 (0.0466)  time: 0.3140  data: 0.0789  max mem: 2725
# Epoch: [0]  [ 850/3673]  eta: 0:15:09  lr: 0.008511  loss: 0.2956 (0.6904)  loss_classifier: 0.1585 (0.3989)  loss_box_reg: 0.0558 (0.0717)  loss_objectness: 0.0343 (0.1732)  loss_rpn_box_reg: 0.0250 (0.0465)  time: 0.3178  data: 0.0813  max mem: 2725
# Epoch: [0]  [ 860/3673]  eta: 0:15:05  lr: 0.008611  loss: 0.3138 (0.6859)  loss_classifier: 0.1643 (0.3962)  loss_box_reg: 0.0619 (0.0716)  loss_objectness: 0.0278 (0.1716)  loss_rpn_box_reg: 0.0408 (0.0465)  time: 0.3168  data: 0.0801  max mem: 2725
# Epoch: [0]  [ 870/3673]  eta: 0:15:02  lr: 0.008711  loss: 0.2827 (0.6817)  loss_classifier: 0.1467 (0.3933)  loss_box_reg: 0.0553 (0.0714)  loss_objectness: 0.0296 (0.1701)  loss_rpn_box_reg: 0.0466 (0.0470)  time: 0.3207  data: 0.0848  max mem: 2725
# Epoch: [0]  [ 880/3673]  eta: 0:14:59  lr: 0.008811  loss: 0.2818 (0.6772)  loss_classifier: 0.1467 (0.3905)  loss_box_reg: 0.0601 (0.0713)  loss_objectness: 0.0255 (0.1685)  loss_rpn_box_reg: 0.0315 (0.0469)  time: 0.3284  data: 0.0909  max mem: 2725
# Epoch: [0]  [ 890/3673]  eta: 0:14:56  lr: 0.008911  loss: 0.2976 (0.6734)  loss_classifier: 0.1696 (0.3881)  loss_box_reg: 0.0660 (0.0713)  loss_objectness: 0.0332 (0.1671)  loss_rpn_box_reg: 0.0343 (0.0470)  time: 0.3303  data: 0.0933  max mem: 2725
# Epoch: [0]  [ 900/3673]  eta: 0:14:53  lr: 0.009011  loss: 0.3416 (0.6697)  loss_classifier: 0.1705 (0.3857)  loss_box_reg: 0.0657 (0.0713)  loss_objectness: 0.0291 (0.1657)  loss_rpn_box_reg: 0.0343 (0.0471)  time: 0.3291  data: 0.0935  max mem: 2725
# Epoch: [0]  [ 910/3673]  eta: 0:14:50  lr: 0.009111  loss: 0.3181 (0.6658)  loss_classifier: 0.1829 (0.3835)  loss_box_reg: 0.0758 (0.0713)  loss_objectness: 0.0245 (0.1641)  loss_rpn_box_reg: 0.0233 (0.0469)  time: 0.3305  data: 0.0942  max mem: 2725
# Epoch: [0]  [ 920/3673]  eta: 0:14:47  lr: 0.009211  loss: 0.3181 (0.6621)  loss_classifier: 0.1744 (0.3811)  loss_box_reg: 0.0758 (0.0713)  loss_objectness: 0.0258 (0.1627)  loss_rpn_box_reg: 0.0297 (0.0469)  time: 0.3237  data: 0.0868  max mem: 2725
# Epoch: [0]  [ 930/3673]  eta: 0:14:43  lr: 0.009311  loss: 0.3165 (0.6581)  loss_classifier: 0.1682 (0.3787)  loss_box_reg: 0.0716 (0.0712)  loss_objectness: 0.0316 (0.1614)  loss_rpn_box_reg: 0.0413 (0.0468)  time: 0.3172  data: 0.0794  max mem: 2725
# Epoch: [0]  [ 940/3673]  eta: 0:14:40  lr: 0.009411  loss: 0.3112 (0.6548)  loss_classifier: 0.1682 (0.3765)  loss_box_reg: 0.0687 (0.0711)  loss_objectness: 0.0296 (0.1600)  loss_rpn_box_reg: 0.0334 (0.0472)  time: 0.3211  data: 0.0834  max mem: 2725
# Epoch: [0]  [ 950/3673]  eta: 0:14:37  lr: 0.009510  loss: 0.3478 (0.6515)  loss_classifier: 0.1667 (0.3742)  loss_box_reg: 0.0709 (0.0711)  loss_objectness: 0.0328 (0.1588)  loss_rpn_box_reg: 0.0363 (0.0475)  time: 0.3236  data: 0.0868  max mem: 2725
# Epoch: [0]  [ 960/3673]  eta: 0:14:34  lr: 0.009610  loss: 0.3209 (0.6482)  loss_classifier: 0.1466 (0.3716)  loss_box_reg: 0.0533 (0.0709)  loss_objectness: 0.0462 (0.1577)  loss_rpn_box_reg: 0.0434 (0.0479)  time: 0.3224  data: 0.0851  max mem: 2725
# Epoch: [0]  [ 970/3673]  eta: 0:14:30  lr: 0.009710  loss: 0.3209 (0.6447)  loss_classifier: 0.1477 (0.3696)  loss_box_reg: 0.0582 (0.0709)  loss_objectness: 0.0324 (0.1564)  loss_rpn_box_reg: 0.0441 (0.0479)  time: 0.3203  data: 0.0818  max mem: 2725
# Epoch: [0]  [ 980/3673]  eta: 0:14:27  lr: 0.009810  loss: 0.3084 (0.6411)  loss_classifier: 0.1610 (0.3673)  loss_box_reg: 0.0675 (0.0708)  loss_objectness: 0.0225 (0.1551)  loss_rpn_box_reg: 0.0448 (0.0478)  time: 0.3172  data: 0.0776  max mem: 2725
# Epoch: [0]  [ 990/3673]  eta: 0:14:24  lr: 0.009910  loss: 0.2953 (0.6377)  loss_classifier: 0.1569 (0.3652)  loss_box_reg: 0.0661 (0.0707)  loss_objectness: 0.0264 (0.1539)  loss_rpn_box_reg: 0.0346 (0.0478)  time: 0.3207  data: 0.0817  max mem: 2725
# Epoch: [0]  [1000/3673]  eta: 0:14:21  lr: 0.010000  loss: 0.2934 (0.6342)  loss_classifier: 0.1401 (0.3631)  loss_box_reg: 0.0613 (0.0706)  loss_objectness: 0.0271 (0.1528)  loss_rpn_box_reg: 0.0341 (0.0478)  time: 0.3225  data: 0.0840  max mem: 2725
# Epoch: [0]  [1010/3673]  eta: 0:14:17  lr: 0.010000  loss: 0.2864 (0.6310)  loss_classifier: 0.1517 (0.3612)  loss_box_reg: 0.0652 (0.0705)  loss_objectness: 0.0253 (0.1517)  loss_rpn_box_reg: 0.0333 (0.0476)  time: 0.3168  data: 0.0794  max mem: 2725
# Epoch: [0]  [1020/3673]  eta: 0:14:14  lr: 0.010000  loss: 0.2930 (0.6279)  loss_classifier: 0.1569 (0.3591)  loss_box_reg: 0.0680 (0.0704)  loss_objectness: 0.0268 (0.1506)  loss_rpn_box_reg: 0.0333 (0.0477)  time: 0.3162  data: 0.0794  max mem: 2725
# Epoch: [0]  [1030/3673]  eta: 0:14:11  lr: 0.010000  loss: 0.3305 (0.6250)  loss_classifier: 0.1693 (0.3573)  loss_box_reg: 0.0720 (0.0705)  loss_objectness: 0.0265 (0.1494)  loss_rpn_box_reg: 0.0420 (0.0478)  time: 0.3248  data: 0.0848  max mem: 2725
# Epoch: [0]  [1040/3673]  eta: 0:14:08  lr: 0.010000  loss: 0.3027 (0.6216)  loss_classifier: 0.1693 (0.3555)  loss_box_reg: 0.0720 (0.0705)  loss_objectness: 0.0206 (0.1482)  loss_rpn_box_reg: 0.0200 (0.0475)  time: 0.3248  data: 0.0835  max mem: 2725
# Epoch: [0]  [1050/3673]  eta: 0:14:05  lr: 0.010000  loss: 0.2934 (0.6186)  loss_classifier: 0.1557 (0.3536)  loss_box_reg: 0.0714 (0.0705)  loss_objectness: 0.0199 (0.1470)  loss_rpn_box_reg: 0.0186 (0.0475)  time: 0.3232  data: 0.0826  max mem: 2725
# Epoch: [0]  [1060/3673]  eta: 0:14:02  lr: 0.010000  loss: 0.3071 (0.6159)  loss_classifier: 0.1546 (0.3518)  loss_box_reg: 0.0717 (0.0705)  loss_objectness: 0.0199 (0.1459)  loss_rpn_box_reg: 0.0402 (0.0476)  time: 0.3331  data: 0.0929  max mem: 2725
# Epoch: [0]  [1070/3673]  eta: 0:13:59  lr: 0.010000  loss: 0.2982 (0.6128)  loss_classifier: 0.1546 (0.3500)  loss_box_reg: 0.0664 (0.0705)  loss_objectness: 0.0184 (0.1448)  loss_rpn_box_reg: 0.0329 (0.0474)  time: 0.3338  data: 0.0943  max mem: 2725
# Epoch: [0]  [1080/3673]  eta: 0:13:56  lr: 0.010000  loss: 0.2811 (0.6098)  loss_classifier: 0.1527 (0.3481)  loss_box_reg: 0.0609 (0.0704)  loss_objectness: 0.0325 (0.1439)  loss_rpn_box_reg: 0.0300 (0.0475)  time: 0.3323  data: 0.0934  max mem: 2725
# Epoch: [0]  [1090/3673]  eta: 0:13:52  lr: 0.010000  loss: 0.2909 (0.6070)  loss_classifier: 0.1482 (0.3463)  loss_box_reg: 0.0642 (0.0703)  loss_objectness: 0.0304 (0.1429)  loss_rpn_box_reg: 0.0372 (0.0475)  time: 0.3248  data: 0.0861  max mem: 2725
# Epoch: [0]  [1100/3673]  eta: 0:13:49  lr: 0.010000  loss: 0.2989 (0.6044)  loss_classifier: 0.1525 (0.3446)  loss_box_reg: 0.0684 (0.0703)  loss_objectness: 0.0214 (0.1419)  loss_rpn_box_reg: 0.0358 (0.0477)  time: 0.3247  data: 0.0848  max mem: 2725
# Epoch: [0]  [1110/3673]  eta: 0:13:46  lr: 0.010000  loss: 0.2938 (0.6018)  loss_classifier: 0.1553 (0.3431)  loss_box_reg: 0.0684 (0.0703)  loss_objectness: 0.0196 (0.1410)  loss_rpn_box_reg: 0.0244 (0.0475)  time: 0.3244  data: 0.0842  max mem: 2725
# Epoch: [0]  [1120/3673]  eta: 0:13:43  lr: 0.010000  loss: 0.2938 (0.5991)  loss_classifier: 0.1659 (0.3415)  loss_box_reg: 0.0699 (0.0703)  loss_objectness: 0.0307 (0.1400)  loss_rpn_box_reg: 0.0293 (0.0474)  time: 0.3212  data: 0.0823  max mem: 2725
# Epoch: [0]  [1130/3673]  eta: 0:13:39  lr: 0.010000  loss: 0.2829 (0.5964)  loss_classifier: 0.1575 (0.3399)  loss_box_reg: 0.0718 (0.0703)  loss_objectness: 0.0280 (0.1390)  loss_rpn_box_reg: 0.0192 (0.0472)  time: 0.3177  data: 0.0793  max mem: 2725
# Epoch: [0]  [1140/3673]  eta: 0:13:36  lr: 0.010000  loss: 0.2840 (0.5939)  loss_classifier: 0.1575 (0.3384)  loss_box_reg: 0.0719 (0.0703)  loss_objectness: 0.0186 (0.1381)  loss_rpn_box_reg: 0.0251 (0.0471)  time: 0.3238  data: 0.0852  max mem: 2725
# Epoch: [0]  [1150/3673]  eta: 0:13:33  lr: 0.010000  loss: 0.3076 (0.5917)  loss_classifier: 0.1772 (0.3370)  loss_box_reg: 0.0693 (0.0703)  loss_objectness: 0.0285 (0.1373)  loss_rpn_box_reg: 0.0296 (0.0470)  time: 0.3298  data: 0.0921  max mem: 2725
# Epoch: [0]  [1160/3673]  eta: 0:13:30  lr: 0.010000  loss: 0.3165 (0.5893)  loss_classifier: 0.1788 (0.3357)  loss_box_reg: 0.0707 (0.0703)  loss_objectness: 0.0283 (0.1363)  loss_rpn_box_reg: 0.0264 (0.0469)  time: 0.3249  data: 0.0870  max mem: 2725
# Epoch: [0]  [1170/3673]  eta: 0:13:27  lr: 0.010000  loss: 0.2937 (0.5868)  loss_classifier: 0.1703 (0.3342)  loss_box_reg: 0.0667 (0.0703)  loss_objectness: 0.0225 (0.1354)  loss_rpn_box_reg: 0.0302 (0.0469)  time: 0.3288  data: 0.0901  max mem: 2725
# Epoch: [0]  [1180/3673]  eta: 0:13:24  lr: 0.010000  loss: 0.2881 (0.5843)  loss_classifier: 0.1592 (0.3328)  loss_box_reg: 0.0635 (0.0703)  loss_objectness: 0.0228 (0.1346)  loss_rpn_box_reg: 0.0246 (0.0467)  time: 0.3267  data: 0.0873  max mem: 2725
# Epoch: [0]  [1190/3673]  eta: 0:13:21  lr: 0.010000  loss: 0.2954 (0.5820)  loss_classifier: 0.1709 (0.3314)  loss_box_reg: 0.0723 (0.0702)  loss_objectness: 0.0226 (0.1337)  loss_rpn_box_reg: 0.0219 (0.0466)  time: 0.3241  data: 0.0849  max mem: 2725
# Epoch: [0]  [1200/3673]  eta: 0:13:18  lr: 0.010000  loss: 0.3033 (0.5798)  loss_classifier: 0.1709 (0.3302)  loss_box_reg: 0.0737 (0.0702)  loss_objectness: 0.0221 (0.1330)  loss_rpn_box_reg: 0.0219 (0.0464)  time: 0.3289  data: 0.0897  max mem: 2725
# Epoch: [0]  [1210/3673]  eta: 0:13:15  lr: 0.010000  loss: 0.3250 (0.5783)  loss_classifier: 0.1844 (0.3290)  loss_box_reg: 0.0740 (0.0703)  loss_objectness: 0.0355 (0.1323)  loss_rpn_box_reg: 0.0289 (0.0467)  time: 0.3356  data: 0.0964  max mem: 2725
# Epoch: [0]  [1220/3673]  eta: 0:13:12  lr: 0.010000  loss: 0.3340 (0.5763)  loss_classifier: 0.1786 (0.3277)  loss_box_reg: 0.0788 (0.0703)  loss_objectness: 0.0193 (0.1313)  loss_rpn_box_reg: 0.0372 (0.0469)  time: 0.3389  data: 0.0994  max mem: 2725
# Epoch: [0]  [1230/3673]  eta: 0:13:08  lr: 0.010000  loss: 0.3108 (0.5742)  loss_classifier: 0.1721 (0.3266)  loss_box_reg: 0.0775 (0.0704)  loss_objectness: 0.0162 (0.1305)  loss_rpn_box_reg: 0.0341 (0.0468)  time: 0.3295  data: 0.0882  max mem: 2725
# Epoch: [0]  [1240/3673]  eta: 0:13:05  lr: 0.010000  loss: 0.3108 (0.5721)  loss_classifier: 0.1721 (0.3253)  loss_box_reg: 0.0732 (0.0704)  loss_objectness: 0.0216 (0.1297)  loss_rpn_box_reg: 0.0285 (0.0466)  time: 0.3220  data: 0.0803  max mem: 2725
# Epoch: [0]  [1250/3673]  eta: 0:13:02  lr: 0.010000  loss: 0.2955 (0.5698)  loss_classifier: 0.1683 (0.3239)  loss_box_reg: 0.0686 (0.0703)  loss_objectness: 0.0331 (0.1289)  loss_rpn_box_reg: 0.0315 (0.0467)  time: 0.3277  data: 0.0867  max mem: 2725
# Epoch: [0]  [1260/3673]  eta: 0:12:59  lr: 0.010000  loss: 0.3183 (0.5680)  loss_classifier: 0.1624 (0.3228)  loss_box_reg: 0.0743 (0.0703)  loss_objectness: 0.0258 (0.1282)  loss_rpn_box_reg: 0.0339 (0.0466)  time: 0.3363  data: 0.0953  max mem: 2725
# Epoch: [0]  [1270/3673]  eta: 0:12:56  lr: 0.010000  loss: 0.3233 (0.5661)  loss_classifier: 0.1574 (0.3216)  loss_box_reg: 0.0679 (0.0703)  loss_objectness: 0.0263 (0.1275)  loss_rpn_box_reg: 0.0315 (0.0467)  time: 0.3300  data: 0.0888  max mem: 2725
# Epoch: [0]  [1280/3673]  eta: 0:12:53  lr: 0.010000  loss: 0.2858 (0.5639)  loss_classifier: 0.1510 (0.3203)  loss_box_reg: 0.0625 (0.0703)  loss_objectness: 0.0199 (0.1266)  loss_rpn_box_reg: 0.0363 (0.0467)  time: 0.3233  data: 0.0824  max mem: 2725
# Epoch: [0]  [1290/3673]  eta: 0:12:50  lr: 0.010000  loss: 0.2856 (0.5619)  loss_classifier: 0.1612 (0.3192)  loss_box_reg: 0.0683 (0.0703)  loss_objectness: 0.0172 (0.1258)  loss_rpn_box_reg: 0.0332 (0.0466)  time: 0.3302  data: 0.0907  max mem: 2725
# Epoch: [0]  [1300/3673]  eta: 0:12:47  lr: 0.010000  loss: 0.2832 (0.5599)  loss_classifier: 0.1709 (0.3180)  loss_box_reg: 0.0708 (0.0703)  loss_objectness: 0.0172 (0.1250)  loss_rpn_box_reg: 0.0260 (0.0465)  time: 0.3311  data: 0.0908  max mem: 2725
# Epoch: [0]  [1310/3673]  eta: 0:12:43  lr: 0.010000  loss: 0.2898 (0.5579)  loss_classifier: 0.1690 (0.3169)  loss_box_reg: 0.0703 (0.0702)  loss_objectness: 0.0154 (0.1242)  loss_rpn_box_reg: 0.0260 (0.0465)  time: 0.3243  data: 0.0823  max mem: 2725
# Epoch: [0]  [1320/3673]  eta: 0:12:40  lr: 0.010000  loss: 0.2929 (0.5560)  loss_classifier: 0.1859 (0.3160)  loss_box_reg: 0.0717 (0.0703)  loss_objectness: 0.0112 (0.1235)  loss_rpn_box_reg: 0.0234 (0.0463)  time: 0.3234  data: 0.0834  max mem: 2725
# Epoch: [0]  [1330/3673]  eta: 0:12:37  lr: 0.010000  loss: 0.3064 (0.5541)  loss_classifier: 0.1868 (0.3149)  loss_box_reg: 0.0717 (0.0703)  loss_objectness: 0.0106 (0.1228)  loss_rpn_box_reg: 0.0230 (0.0462)  time: 0.3315  data: 0.0929  max mem: 2725
# Epoch: [0]  [1340/3673]  eta: 0:12:34  lr: 0.010000  loss: 0.3057 (0.5523)  loss_classifier: 0.1652 (0.3137)  loss_box_reg: 0.0656 (0.0702)  loss_objectness: 0.0158 (0.1221)  loss_rpn_box_reg: 0.0419 (0.0463)  time: 0.3242  data: 0.0844  max mem: 2725
# Epoch: [0]  [1350/3673]  eta: 0:12:31  lr: 0.010000  loss: 0.2987 (0.5503)  loss_classifier: 0.1555 (0.3125)  loss_box_reg: 0.0613 (0.0701)  loss_objectness: 0.0164 (0.1214)  loss_rpn_box_reg: 0.0430 (0.0462)  time: 0.3182  data: 0.0773  max mem: 2725
# Epoch: [0]  [1360/3673]  eta: 0:12:27  lr: 0.010000  loss: 0.2895 (0.5484)  loss_classifier: 0.1519 (0.3114)  loss_box_reg: 0.0642 (0.0701)  loss_objectness: 0.0200 (0.1207)  loss_rpn_box_reg: 0.0323 (0.0462)  time: 0.3250  data: 0.0844  max mem: 2725
# Epoch: [0]  [1370/3673]  eta: 0:12:24  lr: 0.010000  loss: 0.2948 (0.5467)  loss_classifier: 0.1654 (0.3105)  loss_box_reg: 0.0701 (0.0702)  loss_objectness: 0.0189 (0.1200)  loss_rpn_box_reg: 0.0244 (0.0460)  time: 0.3256  data: 0.0855  max mem: 2725
# Epoch: [0]  [1380/3673]  eta: 0:12:21  lr: 0.010000  loss: 0.3323 (0.5450)  loss_classifier: 0.1887 (0.3096)  loss_box_reg: 0.0847 (0.0702)  loss_objectness: 0.0137 (0.1192)  loss_rpn_box_reg: 0.0271 (0.0460)  time: 0.3180  data: 0.0781  max mem: 2725
# Epoch: [0]  [1390/3673]  eta: 0:12:18  lr: 0.010000  loss: 0.3176 (0.5433)  loss_classifier: 0.1710 (0.3085)  loss_box_reg: 0.0713 (0.0702)  loss_objectness: 0.0128 (0.1186)  loss_rpn_box_reg: 0.0352 (0.0460)  time: 0.3227  data: 0.0825  max mem: 2725
# Epoch: [0]  [1400/3673]  eta: 0:12:14  lr: 0.010000  loss: 0.3070 (0.5416)  loss_classifier: 0.1649 (0.3075)  loss_box_reg: 0.0675 (0.0702)  loss_objectness: 0.0124 (0.1179)  loss_rpn_box_reg: 0.0352 (0.0460)  time: 0.3278  data: 0.0874  max mem: 2725
# Epoch: [0]  [1410/3673]  eta: 0:12:11  lr: 0.010000  loss: 0.3141 (0.5400)  loss_classifier: 0.1779 (0.3066)  loss_box_reg: 0.0700 (0.0702)  loss_objectness: 0.0131 (0.1173)  loss_rpn_box_reg: 0.0388 (0.0460)  time: 0.3254  data: 0.0855  max mem: 2725
# Epoch: [0]  [1420/3673]  eta: 0:12:08  lr: 0.010000  loss: 0.3182 (0.5388)  loss_classifier: 0.1780 (0.3059)  loss_box_reg: 0.0785 (0.0703)  loss_objectness: 0.0162 (0.1167)  loss_rpn_box_reg: 0.0246 (0.0459)  time: 0.3239  data: 0.0840  max mem: 2725
# Epoch: [0]  [1430/3673]  eta: 0:12:05  lr: 0.010000  loss: 0.3013 (0.5371)  loss_classifier: 0.1885 (0.3049)  loss_box_reg: 0.0755 (0.0702)  loss_objectness: 0.0201 (0.1162)  loss_rpn_box_reg: 0.0239 (0.0458)  time: 0.3246  data: 0.0844  max mem: 2725
# Epoch: [0]  [1440/3673]  eta: 0:12:02  lr: 0.010000  loss: 0.3221 (0.5358)  loss_classifier: 0.1987 (0.3041)  loss_box_reg: 0.0768 (0.0703)  loss_objectness: 0.0181 (0.1156)  loss_rpn_box_reg: 0.0294 (0.0458)  time: 0.3250  data: 0.0848  max mem: 2725
# Epoch: [0]  [1450/3673]  eta: 0:11:58  lr: 0.010000  loss: 0.3072 (0.5341)  loss_classifier: 0.1680 (0.3030)  loss_box_reg: 0.0662 (0.0702)  loss_objectness: 0.0242 (0.1151)  loss_rpn_box_reg: 0.0333 (0.0458)  time: 0.3225  data: 0.0832  max mem: 2725
# Epoch: [0]  [1460/3673]  eta: 0:11:55  lr: 0.010000  loss: 0.2877 (0.5324)  loss_classifier: 0.1604 (0.3021)  loss_box_reg: 0.0635 (0.0702)  loss_objectness: 0.0206 (0.1144)  loss_rpn_box_reg: 0.0332 (0.0458)  time: 0.3277  data: 0.0887  max mem: 2725
# Epoch: [0]  [1470/3673]  eta: 0:11:52  lr: 0.010000  loss: 0.2908 (0.5309)  loss_classifier: 0.1604 (0.3011)  loss_box_reg: 0.0635 (0.0701)  loss_objectness: 0.0188 (0.1138)  loss_rpn_box_reg: 0.0370 (0.0458)  time: 0.3324  data: 0.0933  max mem: 2725
# Epoch: [0]  [1480/3673]  eta: 0:11:49  lr: 0.010000  loss: 0.2972 (0.5292)  loss_classifier: 0.1549 (0.3002)  loss_box_reg: 0.0627 (0.0701)  loss_objectness: 0.0149 (0.1132)  loss_rpn_box_reg: 0.0286 (0.0458)  time: 0.3331  data: 0.0935  max mem: 2725
# Epoch: [0]  [1490/3673]  eta: 0:11:46  lr: 0.010000  loss: 0.2831 (0.5275)  loss_classifier: 0.1451 (0.2992)  loss_box_reg: 0.0665 (0.0700)  loss_objectness: 0.0122 (0.1126)  loss_rpn_box_reg: 0.0286 (0.0458)  time: 0.3276  data: 0.0872  max mem: 2725
# Epoch: [0]  [1500/3673]  eta: 0:11:43  lr: 0.010000  loss: 0.3017 (0.5260)  loss_classifier: 0.1633 (0.2983)  loss_box_reg: 0.0598 (0.0700)  loss_objectness: 0.0152 (0.1120)  loss_rpn_box_reg: 0.0338 (0.0457)  time: 0.3239  data: 0.0830  max mem: 2725
# Epoch: [0]  [1510/3673]  eta: 0:11:39  lr: 0.010000  loss: 0.3064 (0.5247)  loss_classifier: 0.1768 (0.2975)  loss_box_reg: 0.0648 (0.0700)  loss_objectness: 0.0408 (0.1116)  loss_rpn_box_reg: 0.0289 (0.0456)  time: 0.3242  data: 0.0837  max mem: 2725
# Epoch: [0]  [1520/3673]  eta: 0:11:36  lr: 0.010000  loss: 0.2851 (0.5230)  loss_classifier: 0.1605 (0.2965)  loss_box_reg: 0.0521 (0.0699)  loss_objectness: 0.0280 (0.1111)  loss_rpn_box_reg: 0.0212 (0.0456)  time: 0.3232  data: 0.0829  max mem: 2725
# Epoch: [0]  [1530/3673]  eta: 0:11:33  lr: 0.010000  loss: 0.2788 (0.5214)  loss_classifier: 0.1560 (0.2956)  loss_box_reg: 0.0627 (0.0699)  loss_objectness: 0.0239 (0.1105)  loss_rpn_box_reg: 0.0230 (0.0455)  time: 0.3206  data: 0.0793  max mem: 2725
# Epoch: [0]  [1540/3673]  eta: 0:11:29  lr: 0.010000  loss: 0.2867 (0.5199)  loss_classifier: 0.1627 (0.2947)  loss_box_reg: 0.0741 (0.0699)  loss_objectness: 0.0178 (0.1099)  loss_rpn_box_reg: 0.0230 (0.0454)  time: 0.3150  data: 0.0749  max mem: 2725
# Epoch: [0]  [1550/3673]  eta: 0:11:26  lr: 0.010000  loss: 0.3142 (0.5186)  loss_classifier: 0.1736 (0.2940)  loss_box_reg: 0.0748 (0.0699)  loss_objectness: 0.0125 (0.1094)  loss_rpn_box_reg: 0.0278 (0.0454)  time: 0.3129  data: 0.0736  max mem: 2725
# Epoch: [0]  [1560/3673]  eta: 0:11:23  lr: 0.010000  loss: 0.3242 (0.5174)  loss_classifier: 0.1804 (0.2933)  loss_box_reg: 0.0765 (0.0699)  loss_objectness: 0.0171 (0.1088)  loss_rpn_box_reg: 0.0388 (0.0454)  time: 0.3232  data: 0.0826  max mem: 2725
# Epoch: [0]  [1570/3673]  eta: 0:11:20  lr: 0.010000  loss: 0.3287 (0.5161)  loss_classifier: 0.1804 (0.2925)  loss_box_reg: 0.0759 (0.0699)  loss_objectness: 0.0188 (0.1084)  loss_rpn_box_reg: 0.0270 (0.0453)  time: 0.3341  data: 0.0934  max mem: 2725
# Epoch: [0]  [1580/3673]  eta: 0:11:17  lr: 0.010000  loss: 0.3061 (0.5147)  loss_classifier: 0.1750 (0.2918)  loss_box_reg: 0.0655 (0.0699)  loss_objectness: 0.0186 (0.1078)  loss_rpn_box_reg: 0.0296 (0.0452)  time: 0.3329  data: 0.0928  max mem: 2725
# Epoch: [0]  [1590/3673]  eta: 0:11:14  lr: 0.010000  loss: 0.3122 (0.5134)  loss_classifier: 0.1870 (0.2911)  loss_box_reg: 0.0706 (0.0699)  loss_objectness: 0.0197 (0.1073)  loss_rpn_box_reg: 0.0229 (0.0450)  time: 0.3330  data: 0.0933  max mem: 2725
# Epoch: [0]  [1600/3673]  eta: 0:11:10  lr: 0.010000  loss: 0.3077 (0.5120)  loss_classifier: 0.1865 (0.2903)  loss_box_reg: 0.0710 (0.0699)  loss_objectness: 0.0228 (0.1069)  loss_rpn_box_reg: 0.0196 (0.0449)  time: 0.3292  data: 0.0896  max mem: 2725
# Epoch: [0]  [1610/3673]  eta: 0:11:07  lr: 0.010000  loss: 0.2965 (0.5107)  loss_classifier: 0.1671 (0.2896)  loss_box_reg: 0.0649 (0.0698)  loss_objectness: 0.0228 (0.1064)  loss_rpn_box_reg: 0.0209 (0.0450)  time: 0.3275  data: 0.0879  max mem: 2725
# Epoch: [0]  [1620/3673]  eta: 0:11:04  lr: 0.010000  loss: 0.3012 (0.5096)  loss_classifier: 0.1671 (0.2888)  loss_box_reg: 0.0702 (0.0698)  loss_objectness: 0.0195 (0.1059)  loss_rpn_box_reg: 0.0373 (0.0450)  time: 0.3325  data: 0.0927  max mem: 2725
# Epoch: [0]  [1630/3673]  eta: 0:11:01  lr: 0.010000  loss: 0.3086 (0.5082)  loss_classifier: 0.1782 (0.2881)  loss_box_reg: 0.0708 (0.0698)  loss_objectness: 0.0160 (0.1054)  loss_rpn_box_reg: 0.0300 (0.0449)  time: 0.3338  data: 0.0933  max mem: 2725
# Epoch: [0]  [1640/3673]  eta: 0:10:58  lr: 0.010000  loss: 0.2681 (0.5068)  loss_classifier: 0.1662 (0.2873)  loss_box_reg: 0.0661 (0.0698)  loss_objectness: 0.0120 (0.1049)  loss_rpn_box_reg: 0.0198 (0.0449)  time: 0.3254  data: 0.0850  max mem: 2725
# Epoch: [0]  [1650/3673]  eta: 0:10:55  lr: 0.010000  loss: 0.2689 (0.5056)  loss_classifier: 0.1645 (0.2866)  loss_box_reg: 0.0683 (0.0698)  loss_objectness: 0.0120 (0.1044)  loss_rpn_box_reg: 0.0278 (0.0449)  time: 0.3218  data: 0.0819  max mem: 2725
# Epoch: [0]  [1660/3673]  eta: 0:10:51  lr: 0.010000  loss: 0.3087 (0.5044)  loss_classifier: 0.1792 (0.2860)  loss_box_reg: 0.0719 (0.0698)  loss_objectness: 0.0142 (0.1039)  loss_rpn_box_reg: 0.0265 (0.0448)  time: 0.3259  data: 0.0865  max mem: 2725
# Epoch: [0]  [1670/3673]  eta: 0:10:48  lr: 0.010000  loss: 0.2793 (0.5029)  loss_classifier: 0.1785 (0.2852)  loss_box_reg: 0.0678 (0.0697)  loss_objectness: 0.0129 (0.1034)  loss_rpn_box_reg: 0.0214 (0.0446)  time: 0.3222  data: 0.0834  max mem: 2725
# Epoch: [0]  [1680/3673]  eta: 0:10:45  lr: 0.010000  loss: 0.2794 (0.5019)  loss_classifier: 0.1720 (0.2845)  loss_box_reg: 0.0638 (0.0697)  loss_objectness: 0.0129 (0.1031)  loss_rpn_box_reg: 0.0200 (0.0446)  time: 0.3229  data: 0.0845  max mem: 2725
# Epoch: [0]  [1690/3673]  eta: 0:10:42  lr: 0.010000  loss: 0.2827 (0.5004)  loss_classifier: 0.1722 (0.2837)  loss_box_reg: 0.0561 (0.0696)  loss_objectness: 0.0115 (0.1026)  loss_rpn_box_reg: 0.0321 (0.0445)  time: 0.3223  data: 0.0833  max mem: 2725
# Epoch: [0]  [1700/3673]  eta: 0:10:38  lr: 0.010000  loss: 0.2245 (0.4988)  loss_classifier: 0.1437 (0.2829)  loss_box_reg: 0.0493 (0.0695)  loss_objectness: 0.0199 (0.1022)  loss_rpn_box_reg: 0.0193 (0.0443)  time: 0.3268  data: 0.0873  max mem: 2725
# Epoch: [0]  [1710/3673]  eta: 0:10:35  lr: 0.010000  loss: 0.2523 (0.4975)  loss_classifier: 0.1477 (0.2821)  loss_box_reg: 0.0545 (0.0694)  loss_objectness: 0.0161 (0.1016)  loss_rpn_box_reg: 0.0233 (0.0443)  time: 0.3321  data: 0.0930  max mem: 2725
# Epoch: [0]  [1720/3673]  eta: 0:10:32  lr: 0.010000  loss: 0.2724 (0.4962)  loss_classifier: 0.1642 (0.2814)  loss_box_reg: 0.0643 (0.0694)  loss_objectness: 0.0139 (0.1012)  loss_rpn_box_reg: 0.0316 (0.0442)  time: 0.3329  data: 0.0940  max mem: 2725
# Epoch: [0]  [1730/3673]  eta: 0:10:29  lr: 0.010000  loss: 0.2807 (0.4951)  loss_classifier: 0.1665 (0.2807)  loss_box_reg: 0.0618 (0.0694)  loss_objectness: 0.0150 (0.1008)  loss_rpn_box_reg: 0.0277 (0.0442)  time: 0.3355  data: 0.0954  max mem: 2725
# Epoch: [0]  [1740/3673]  eta: 0:10:26  lr: 0.010000  loss: 0.2665 (0.4937)  loss_classifier: 0.1539 (0.2800)  loss_box_reg: 0.0603 (0.0693)  loss_objectness: 0.0091 (0.1003)  loss_rpn_box_reg: 0.0261 (0.0442)  time: 0.3259  data: 0.0855  max mem: 2725
# Epoch: [0]  [1750/3673]  eta: 0:10:23  lr: 0.010000  loss: 0.2665 (0.4925)  loss_classifier: 0.1533 (0.2793)  loss_box_reg: 0.0574 (0.0693)  loss_objectness: 0.0091 (0.0998)  loss_rpn_box_reg: 0.0186 (0.0441)  time: 0.3255  data: 0.0854  max mem: 2725
# Epoch: [0]  [1760/3673]  eta: 0:10:19  lr: 0.010000  loss: 0.2830 (0.4913)  loss_classifier: 0.1652 (0.2786)  loss_box_reg: 0.0614 (0.0692)  loss_objectness: 0.0216 (0.0994)  loss_rpn_box_reg: 0.0281 (0.0441)  time: 0.3320  data: 0.0923  max mem: 2725
# Epoch: [0]  [1770/3673]  eta: 0:10:16  lr: 0.010000  loss: 0.2854 (0.4901)  loss_classifier: 0.1649 (0.2780)  loss_box_reg: 0.0629 (0.0692)  loss_objectness: 0.0216 (0.0990)  loss_rpn_box_reg: 0.0281 (0.0440)  time: 0.3259  data: 0.0864  max mem: 2725
# Epoch: [0]  [1780/3673]  eta: 0:10:13  lr: 0.010000  loss: 0.2875 (0.4891)  loss_classifier: 0.1649 (0.2774)  loss_box_reg: 0.0642 (0.0692)  loss_objectness: 0.0163 (0.0987)  loss_rpn_box_reg: 0.0222 (0.0439)  time: 0.3243  data: 0.0848  max mem: 2725
# Epoch: [0]  [1790/3673]  eta: 0:10:10  lr: 0.010000  loss: 0.3055 (0.4881)  loss_classifier: 0.1760 (0.2769)  loss_box_reg: 0.0679 (0.0692)  loss_objectness: 0.0158 (0.0982)  loss_rpn_box_reg: 0.0200 (0.0438)  time: 0.3248  data: 0.0851  max mem: 2725
# Epoch: [0]  [1800/3673]  eta: 0:10:06  lr: 0.010000  loss: 0.3094 (0.4872)  loss_classifier: 0.1795 (0.2764)  loss_box_reg: 0.0681 (0.0692)  loss_objectness: 0.0208 (0.0980)  loss_rpn_box_reg: 0.0186 (0.0437)  time: 0.3275  data: 0.0873  max mem: 2725
# Epoch: [0]  [1810/3673]  eta: 0:10:03  lr: 0.010000  loss: 0.2975 (0.4860)  loss_classifier: 0.1711 (0.2758)  loss_box_reg: 0.0615 (0.0691)  loss_objectness: 0.0165 (0.0975)  loss_rpn_box_reg: 0.0190 (0.0435)  time: 0.3283  data: 0.0878  max mem: 2725
# Epoch: [0]  [1820/3673]  eta: 0:10:00  lr: 0.010000  loss: 0.2709 (0.4849)  loss_classifier: 0.1587 (0.2751)  loss_box_reg: 0.0601 (0.0691)  loss_objectness: 0.0110 (0.0971)  loss_rpn_box_reg: 0.0203 (0.0436)  time: 0.3216  data: 0.0815  max mem: 2725
# Epoch: [0]  [1830/3673]  eta: 0:09:57  lr: 0.010000  loss: 0.2736 (0.4838)  loss_classifier: 0.1547 (0.2745)  loss_box_reg: 0.0623 (0.0690)  loss_objectness: 0.0114 (0.0967)  loss_rpn_box_reg: 0.0240 (0.0436)  time: 0.3228  data: 0.0827  max mem: 2725
# Epoch: [0]  [1840/3673]  eta: 0:09:54  lr: 0.010000  loss: 0.2928 (0.4829)  loss_classifier: 0.1744 (0.2740)  loss_box_reg: 0.0670 (0.0690)  loss_objectness: 0.0124 (0.0963)  loss_rpn_box_reg: 0.0349 (0.0435)  time: 0.3293  data: 0.0884  max mem: 2725
# Epoch: [0]  [1850/3673]  eta: 0:09:50  lr: 0.010000  loss: 0.2678 (0.4816)  loss_classifier: 0.1607 (0.2733)  loss_box_reg: 0.0607 (0.0689)  loss_objectness: 0.0226 (0.0960)  loss_rpn_box_reg: 0.0180 (0.0434)  time: 0.3326  data: 0.0932  max mem: 2725
# Epoch: [0]  [1860/3673]  eta: 0:09:47  lr: 0.010000  loss: 0.2611 (0.4805)  loss_classifier: 0.1524 (0.2727)  loss_box_reg: 0.0553 (0.0689)  loss_objectness: 0.0226 (0.0956)  loss_rpn_box_reg: 0.0178 (0.0433)  time: 0.3321  data: 0.0944  max mem: 2725
# Epoch: [0]  [1870/3673]  eta: 0:09:44  lr: 0.010000  loss: 0.2594 (0.4795)  loss_classifier: 0.1562 (0.2721)  loss_box_reg: 0.0613 (0.0689)  loss_objectness: 0.0123 (0.0952)  loss_rpn_box_reg: 0.0265 (0.0433)  time: 0.3258  data: 0.0874  max mem: 2725
# Epoch: [0]  [1880/3673]  eta: 0:09:41  lr: 0.010000  loss: 0.2749 (0.4785)  loss_classifier: 0.1520 (0.2715)  loss_box_reg: 0.0556 (0.0688)  loss_objectness: 0.0122 (0.0948)  loss_rpn_box_reg: 0.0279 (0.0433)  time: 0.3273  data: 0.0881  max mem: 2725
# Epoch: [0]  [1890/3673]  eta: 0:09:38  lr: 0.010000  loss: 0.2691 (0.4774)  loss_classifier: 0.1467 (0.2708)  loss_box_reg: 0.0540 (0.0688)  loss_objectness: 0.0193 (0.0944)  loss_rpn_box_reg: 0.0378 (0.0434)  time: 0.3299  data: 0.0910  max mem: 2725
# ...
# Epoch: [4]  [3220/3673]  eta: 0:01:53  lr: 0.010000  loss: 0.1575 (0.1729)  loss_classifier: 0.1126 (0.1141)  loss_box_reg: 0.0241 (0.0244)  loss_objectness: 0.0052 (0.0114)  loss_rpn_box_reg: 0.0148 (0.0230)  time: 0.2503  data: 0.0125  max mem: 2725
# Epoch: [4]  [3230/3673]  eta: 0:01:51  lr: 0.010000  loss: 0.1689 (0.1729)  loss_classifier: 0.1150 (0.1141)  loss_box_reg: 0.0252 (0.0244)  loss_objectness: 0.0080 (0.0114)  loss_rpn_box_reg: 0.0148 (0.0230)  time: 0.2506  data: 0.0121  max mem: 2725
# Epoch: [4]  [3240/3673]  eta: 0:01:48  lr: 0.010000  loss: 0.1633 (0.1729)  loss_classifier: 0.1106 (0.1141)  loss_box_reg: 0.0252 (0.0244)  loss_objectness: 0.0062 (0.0114)  loss_rpn_box_reg: 0.0147 (0.0230)  time: 0.2511  data: 0.0123  max mem: 2725
# Epoch: [4]  [3250/3673]  eta: 0:01:46  lr: 0.010000  loss: 0.1633 (0.1730)  loss_classifier: 0.1106 (0.1141)  loss_box_reg: 0.0220 (0.0244)  loss_objectness: 0.0059 (0.0114)  loss_rpn_box_reg: 0.0218 (0.0230)  time: 0.2517  data: 0.0125  max mem: 2725
# Epoch: [4]  [3260/3673]  eta: 0:01:43  lr: 0.010000  loss: 0.1623 (0.1729)  loss_classifier: 0.1057 (0.1140)  loss_box_reg: 0.0238 (0.0244)  loss_objectness: 0.0059 (0.0114)  loss_rpn_box_reg: 0.0235 (0.0230)  time: 0.2514  data: 0.0124  max mem: 2725
# Epoch: [4]  [3270/3673]  eta: 0:01:41  lr: 0.010000  loss: 0.1768 (0.1730)  loss_classifier: 0.1080 (0.1141)  loss_box_reg: 0.0243 (0.0244)  loss_objectness: 0.0074 (0.0115)  loss_rpn_box_reg: 0.0234 (0.0230)  time: 0.2508  data: 0.0119  max mem: 2725
# Epoch: [4]  [3280/3673]  eta: 0:01:38  lr: 0.010000  loss: 0.1784 (0.1730)  loss_classifier: 0.1084 (0.1141)  loss_box_reg: 0.0243 (0.0244)  loss_objectness: 0.0041 (0.0115)  loss_rpn_box_reg: 0.0199 (0.0230)  time: 0.2503  data: 0.0118  max mem: 2725
# Epoch: [4]  [3290/3673]  eta: 0:01:36  lr: 0.010000  loss: 0.1569 (0.1730)  loss_classifier: 0.1048 (0.1141)  loss_box_reg: 0.0258 (0.0244)  loss_objectness: 0.0040 (0.0115)  loss_rpn_box_reg: 0.0180 (0.0230)  time: 0.2503  data: 0.0121  max mem: 2725
# Epoch: [4]  [3300/3673]  eta: 0:01:33  lr: 0.010000  loss: 0.1597 (0.1730)  loss_classifier: 0.1064 (0.1141)  loss_box_reg: 0.0201 (0.0245)  loss_objectness: 0.0061 (0.0115)  loss_rpn_box_reg: 0.0182 (0.0230)  time: 0.2507  data: 0.0124  max mem: 2725
# Epoch: [4]  [3310/3673]  eta: 0:01:31  lr: 0.010000  loss: 0.1771 (0.1730)  loss_classifier: 0.1092 (0.1141)  loss_box_reg: 0.0239 (0.0245)  loss_objectness: 0.0094 (0.0115)  loss_rpn_box_reg: 0.0172 (0.0230)  time: 0.2512  data: 0.0127  max mem: 2725
# Epoch: [4]  [3320/3673]  eta: 0:01:28  lr: 0.010000  loss: 0.1741 (0.1730)  loss_classifier: 0.1092 (0.1140)  loss_box_reg: 0.0257 (0.0245)  loss_objectness: 0.0060 (0.0115)  loss_rpn_box_reg: 0.0155 (0.0230)  time: 0.2509  data: 0.0123  max mem: 2725
# Epoch: [4]  [3330/3673]  eta: 0:01:26  lr: 0.010000  loss: 0.1576 (0.1730)  loss_classifier: 0.1022 (0.1140)  loss_box_reg: 0.0220 (0.0245)  loss_objectness: 0.0039 (0.0115)  loss_rpn_box_reg: 0.0190 (0.0230)  time: 0.2508  data: 0.0120  max mem: 2725
# Epoch: [4]  [3340/3673]  eta: 0:01:23  lr: 0.010000  loss: 0.1579 (0.1730)  loss_classifier: 0.1077 (0.1140)  loss_box_reg: 0.0207 (0.0245)  loss_objectness: 0.0045 (0.0115)  loss_rpn_box_reg: 0.0190 (0.0230)  time: 0.2501  data: 0.0117  max mem: 2725
# Epoch: [4]  [3350/3673]  eta: 0:01:21  lr: 0.010000  loss: 0.1782 (0.1731)  loss_classifier: 0.1091 (0.1140)  loss_box_reg: 0.0217 (0.0245)  loss_objectness: 0.0074 (0.0115)  loss_rpn_box_reg: 0.0160 (0.0230)  time: 0.2500  data: 0.0120  max mem: 2725
# Epoch: [4]  [3360/3673]  eta: 0:01:18  lr: 0.010000  loss: 0.1718 (0.1730)  loss_classifier: 0.1109 (0.1140)  loss_box_reg: 0.0249 (0.0245)  loss_objectness: 0.0047 (0.0115)  loss_rpn_box_reg: 0.0133 (0.0230)  time: 0.2513  data: 0.0130  max mem: 2725
# Epoch: [4]  [3370/3673]  eta: 0:01:16  lr: 0.010000  loss: 0.1653 (0.1730)  loss_classifier: 0.1115 (0.1140)  loss_box_reg: 0.0187 (0.0245)  loss_objectness: 0.0038 (0.0115)  loss_rpn_box_reg: 0.0133 (0.0230)  time: 0.2514  data: 0.0126  max mem: 2725
# Epoch: [4]  [3380/3673]  eta: 0:01:13  lr: 0.010000  loss: 0.1743 (0.1730)  loss_classifier: 0.1115 (0.1141)  loss_box_reg: 0.0181 (0.0245)  loss_objectness: 0.0032 (0.0115)  loss_rpn_box_reg: 0.0131 (0.0230)  time: 0.2511  data: 0.0120  max mem: 2725
# Epoch: [4]  [3390/3673]  eta: 0:01:11  lr: 0.010000  loss: 0.1610 (0.1730)  loss_classifier: 0.1100 (0.1141)  loss_box_reg: 0.0207 (0.0245)  loss_objectness: 0.0046 (0.0115)  loss_rpn_box_reg: 0.0160 (0.0230)  time: 0.2510  data: 0.0122  max mem: 2725
# Epoch: [4]  [3400/3673]  eta: 0:01:08  lr: 0.010000  loss: 0.1664 (0.1731)  loss_classifier: 0.1164 (0.1141)  loss_box_reg: 0.0289 (0.0245)  loss_objectness: 0.0046 (0.0115)  loss_rpn_box_reg: 0.0160 (0.0230)  time: 0.2500  data: 0.0119  max mem: 2725
# Epoch: [4]  [3410/3673]  eta: 0:01:06  lr: 0.010000  loss: 0.1664 (0.1731)  loss_classifier: 0.1164 (0.1141)  loss_box_reg: 0.0320 (0.0245)  loss_objectness: 0.0043 (0.0115)  loss_rpn_box_reg: 0.0142 (0.0229)  time: 0.2500  data: 0.0119  max mem: 2725
# Epoch: [4]  [3420/3673]  eta: 0:01:03  lr: 0.010000  loss: 0.1567 (0.1731)  loss_classifier: 0.1027 (0.1141)  loss_box_reg: 0.0250 (0.0245)  loss_objectness: 0.0079 (0.0115)  loss_rpn_box_reg: 0.0142 (0.0229)  time: 0.2500  data: 0.0114  max mem: 2725
# Epoch: [4]  [3430/3673]  eta: 0:01:01  lr: 0.010000  loss: 0.1386 (0.1730)  loss_classifier: 0.1070 (0.1140)  loss_box_reg: 0.0162 (0.0245)  loss_objectness: 0.0039 (0.0115)  loss_rpn_box_reg: 0.0163 (0.0229)  time: 0.2504  data: 0.0116  max mem: 2725
# Epoch: [4]  [3440/3673]  eta: 0:00:58  lr: 0.010000  loss: 0.1719 (0.1730)  loss_classifier: 0.1080 (0.1140)  loss_box_reg: 0.0185 (0.0245)  loss_objectness: 0.0037 (0.0115)  loss_rpn_box_reg: 0.0196 (0.0230)  time: 0.2509  data: 0.0121  max mem: 2725
# Epoch: [4]  [3450/3673]  eta: 0:00:56  lr: 0.010000  loss: 0.1701 (0.1730)  loss_classifier: 0.1016 (0.1140)  loss_box_reg: 0.0194 (0.0245)  loss_objectness: 0.0055 (0.0115)  loss_rpn_box_reg: 0.0220 (0.0230)  time: 0.2511  data: 0.0124  max mem: 2725
# Epoch: [4]  [3460/3673]  eta: 0:00:53  lr: 0.010000  loss: 0.1626 (0.1730)  loss_classifier: 0.1016 (0.1140)  loss_box_reg: 0.0194 (0.0245)  loss_objectness: 0.0055 (0.0115)  loss_rpn_box_reg: 0.0141 (0.0230)  time: 0.2519  data: 0.0131  max mem: 2725
# Epoch: [4]  [3470/3673]  eta: 0:00:51  lr: 0.010000  loss: 0.1481 (0.1730)  loss_classifier: 0.0984 (0.1140)  loss_box_reg: 0.0195 (0.0245)  loss_objectness: 0.0044 (0.0115)  loss_rpn_box_reg: 0.0157 (0.0230)  time: 0.2517  data: 0.0128  max mem: 2725
# Epoch: [4]  [3480/3673]  eta: 0:00:48  lr: 0.010000  loss: 0.1562 (0.1730)  loss_classifier: 0.1016 (0.1140)  loss_box_reg: 0.0245 (0.0245)  loss_objectness: 0.0044 (0.0115)  loss_rpn_box_reg: 0.0231 (0.0230)  time: 0.2505  data: 0.0118  max mem: 2725
# Epoch: [4]  [3490/3673]  eta: 0:00:46  lr: 0.010000  loss: 0.1702 (0.1730)  loss_classifier: 0.1063 (0.1140)  loss_box_reg: 0.0232 (0.0245)  loss_objectness: 0.0034 (0.0115)  loss_rpn_box_reg: 0.0177 (0.0230)  time: 0.2497  data: 0.0114  max mem: 2725
# Epoch: [4]  [3500/3673]  eta: 0:00:43  lr: 0.010000  loss: 0.1495 (0.1730)  loss_classifier: 0.0992 (0.1139)  loss_box_reg: 0.0195 (0.0245)  loss_objectness: 0.0035 (0.0115)  loss_rpn_box_reg: 0.0148 (0.0230)  time: 0.2498  data: 0.0116  max mem: 2725
# Epoch: [4]  [3510/3673]  eta: 0:00:40  lr: 0.010000  loss: 0.1491 (0.1730)  loss_classifier: 0.0992 (0.1139)  loss_box_reg: 0.0195 (0.0245)  loss_objectness: 0.0043 (0.0115)  loss_rpn_box_reg: 0.0182 (0.0230)  time: 0.2502  data: 0.0121  max mem: 2725
# Epoch: [4]  [3520/3673]  eta: 0:00:38  lr: 0.010000  loss: 0.1509 (0.1729)  loss_classifier: 0.0912 (0.1139)  loss_box_reg: 0.0186 (0.0245)  loss_objectness: 0.0042 (0.0115)  loss_rpn_box_reg: 0.0210 (0.0231)  time: 0.2504  data: 0.0121  max mem: 2725
# Epoch: [4]  [3530/3673]  eta: 0:00:35  lr: 0.010000  loss: 0.1624 (0.1729)  loss_classifier: 0.0861 (0.1139)  loss_box_reg: 0.0186 (0.0245)  loss_objectness: 0.0042 (0.0115)  loss_rpn_box_reg: 0.0185 (0.0231)  time: 0.2509  data: 0.0118  max mem: 2725
# Epoch: [4]  [3540/3673]  eta: 0:00:33  lr: 0.010000  loss: 0.1649 (0.1729)  loss_classifier: 0.1122 (0.1139)  loss_box_reg: 0.0185 (0.0245)  loss_objectness: 0.0028 (0.0115)  loss_rpn_box_reg: 0.0176 (0.0230)  time: 0.2508  data: 0.0118  max mem: 2725
# Epoch: [4]  [3550/3673]  eta: 0:00:30  lr: 0.010000  loss: 0.1353 (0.1728)  loss_classifier: 0.0924 (0.1138)  loss_box_reg: 0.0150 (0.0245)  loss_objectness: 0.0024 (0.0115)  loss_rpn_box_reg: 0.0205 (0.0231)  time: 0.2512  data: 0.0122  max mem: 2725
# Epoch: [4]  [3560/3673]  eta: 0:00:28  lr: 0.010000  loss: 0.1540 (0.1728)  loss_classifier: 0.0900 (0.1138)  loss_box_reg: 0.0149 (0.0245)  loss_objectness: 0.0026 (0.0115)  loss_rpn_box_reg: 0.0219 (0.0231)  time: 0.2511  data: 0.0122  max mem: 2725
# Epoch: [4]  [3570/3673]  eta: 0:00:25  lr: 0.010000  loss: 0.1832 (0.1728)  loss_classifier: 0.0983 (0.1138)  loss_box_reg: 0.0364 (0.0245)  loss_objectness: 0.0090 (0.0115)  loss_rpn_box_reg: 0.0167 (0.0231)  time: 0.2496  data: 0.0116  max mem: 2725
# Epoch: [4]  [3580/3673]  eta: 0:00:23  lr: 0.010000  loss: 0.1714 (0.1728)  loss_classifier: 0.1092 (0.1138)  loss_box_reg: 0.0326 (0.0245)  loss_objectness: 0.0059 (0.0115)  loss_rpn_box_reg: 0.0168 (0.0231)  time: 0.2497  data: 0.0115  max mem: 2725
# Epoch: [4]  [3590/3673]  eta: 0:00:20  lr: 0.010000  loss: 0.1714 (0.1729)  loss_classifier: 0.1097 (0.1138)  loss_box_reg: 0.0196 (0.0245)  loss_objectness: 0.0082 (0.0115)  loss_rpn_box_reg: 0.0179 (0.0231)  time: 0.2510  data: 0.0122  max mem: 2725
# Epoch: [4]  [3600/3673]  eta: 0:00:18  lr: 0.010000  loss: 0.1648 (0.1728)  loss_classifier: 0.1026 (0.1138)  loss_box_reg: 0.0206 (0.0245)  loss_objectness: 0.0083 (0.0115)  loss_rpn_box_reg: 0.0179 (0.0231)  time: 0.2508  data: 0.0125  max mem: 2725
# Epoch: [4]  [3610/3673]  eta: 0:00:15  lr: 0.010000  loss: 0.1554 (0.1728)  loss_classifier: 0.1038 (0.1138)  loss_box_reg: 0.0224 (0.0245)  loss_objectness: 0.0034 (0.0114)  loss_rpn_box_reg: 0.0176 (0.0231)  time: 0.2502  data: 0.0118  max mem: 2725
# Epoch: [4]  [3620/3673]  eta: 0:00:13  lr: 0.010000  loss: 0.1589 (0.1728)  loss_classifier: 0.1174 (0.1138)  loss_box_reg: 0.0279 (0.0245)  loss_objectness: 0.0048 (0.0115)  loss_rpn_box_reg: 0.0142 (0.0230)  time: 0.2498  data: 0.0118  max mem: 2725
# Epoch: [4]  [3630/3673]  eta: 0:00:10  lr: 0.010000  loss: 0.1431 (0.1727)  loss_classifier: 0.0947 (0.1137)  loss_box_reg: 0.0240 (0.0245)  loss_objectness: 0.0066 (0.0115)  loss_rpn_box_reg: 0.0143 (0.0230)  time: 0.2497  data: 0.0122  max mem: 2725
# Epoch: [4]  [3640/3673]  eta: 0:00:08  lr: 0.010000  loss: 0.1332 (0.1727)  loss_classifier: 0.0893 (0.1137)  loss_box_reg: 0.0206 (0.0245)  loss_objectness: 0.0028 (0.0114)  loss_rpn_box_reg: 0.0137 (0.0230)  time: 0.2507  data: 0.0123  max mem: 2725
# Epoch: [4]  [3650/3673]  eta: 0:00:05  lr: 0.010000  loss: 0.1355 (0.1726)  loss_classifier: 0.0984 (0.1136)  loss_box_reg: 0.0218 (0.0245)  loss_objectness: 0.0025 (0.0114)  loss_rpn_box_reg: 0.0123 (0.0230)  time: 0.2506  data: 0.0125  max mem: 2725
# Epoch: [4]  [3660/3673]  eta: 0:00:03  lr: 0.010000  loss: 0.1476 (0.1726)  loss_classifier: 0.1041 (0.1137)  loss_box_reg: 0.0152 (0.0245)  loss_objectness: 0.0030 (0.0114)  loss_rpn_box_reg: 0.0135 (0.0230)  time: 0.2509  data: 0.0129  max mem: 2725
# Epoch: [4]  [3670/3673]  eta: 0:00:00  lr: 0.010000  loss: 0.1523 (0.1726)  loss_classifier: 0.1099 (0.1136)  loss_box_reg: 0.0127 (0.0245)  loss_objectness: 0.0030 (0.0114)  loss_rpn_box_reg: 0.0167 (0.0230)  time: 0.2512  data: 0.0129  max mem: 2725
# Epoch: [4]  [3672/3673]  eta: 0:00:00  lr: 0.010000  loss: 0.1523 (0.1726)  loss_classifier: 0.1187 (0.1136)  loss_box_reg: 0.0134 (0.0245)  loss_objectness: 0.0031 (0.0114)  loss_rpn_box_reg: 0.0141 (0.0230)  time: 0.2508  data: 0.0127  max mem: 2725
# Epoch: [4] Total time: 0:15:23 (0.2515 s / it)
# creating index...
# index created!
# Test:  [   0/1837]  eta: 0:02:35  model_time: 0.0549 (0.0549)  evaluator_time: 0.0030 (0.0030)  time: 0.0848  data: 0.0090  max mem: 2725
# Test:  [ 100/1837]  eta: 0:01:19  model_time: 0.0339 (0.0338)  evaluator_time: 0.0030 (0.0030)  time: 0.0460  data: 0.0079  max mem: 2725
# Test:  [ 200/1837]  eta: 0:01:14  model_time: 0.0319 (0.0335)  evaluator_time: 0.0030 (0.0030)  time: 0.0452  data: 0.0077  max mem: 2725
# Test:  [ 300/1837]  eta: 0:01:10  model_time: 0.0329 (0.0334)  evaluator_time: 0.0030 (0.0030)  time: 0.0456  data: 0.0081  max mem: 2725
# Test:  [ 400/1837]  eta: 0:01:05  model_time: 0.0319 (0.0334)  evaluator_time: 0.0030 (0.0030)  time: 0.0455  data: 0.0076  max mem: 2725
# Test:  [ 500/1837]  eta: 0:01:00  model_time: 0.0309 (0.0333)  evaluator_time: 0.0030 (0.0030)  time: 0.0446  data: 0.0083  max mem: 2725
# Test:  [ 600/1837]  eta: 0:00:56  model_time: 0.0319 (0.0332)  evaluator_time: 0.0030 (0.0030)  time: 0.0448  data: 0.0081  max mem: 2725
# Test:  [ 700/1837]  eta: 0:00:51  model_time: 0.0329 (0.0332)  evaluator_time: 0.0030 (0.0030)  time: 0.0459  data: 0.0082  max mem: 2725
# Test:  [ 800/1837]  eta: 0:00:47  model_time: 0.0319 (0.0331)  evaluator_time: 0.0030 (0.0030)  time: 0.0441  data: 0.0080  max mem: 2725
# Test:  [ 900/1837]  eta: 0:00:42  model_time: 0.0329 (0.0331)  evaluator_time: 0.0030 (0.0030)  time: 0.0456  data: 0.0078  max mem: 2725
# Test:  [1000/1837]  eta: 0:00:38  model_time: 0.0329 (0.0331)  evaluator_time: 0.0030 (0.0030)  time: 0.0457  data: 0.0081  max mem: 2725
# Test:  [1100/1837]  eta: 0:00:33  model_time: 0.0319 (0.0331)  evaluator_time: 0.0030 (0.0030)  time: 0.0456  data: 0.0086  max mem: 2725
# Test:  [1200/1837]  eta: 0:00:28  model_time: 0.0329 (0.0331)  evaluator_time: 0.0030 (0.0030)  time: 0.0456  data: 0.0079  max mem: 2725
# Test:  [1300/1837]  eta: 0:00:24  model_time: 0.0319 (0.0331)  evaluator_time: 0.0030 (0.0030)  time: 0.0449  data: 0.0084  max mem: 2725
# Test:  [1400/1837]  eta: 0:00:19  model_time: 0.0319 (0.0331)  evaluator_time: 0.0030 (0.0030)  time: 0.0459  data: 0.0082  max mem: 2725
# Test:  [1500/1837]  eta: 0:00:15  model_time: 0.0319 (0.0331)  evaluator_time: 0.0030 (0.0031)  time: 0.0453  data: 0.0077  max mem: 2725
# Test:  [1600/1837]  eta: 0:00:10  model_time: 0.0329 (0.0332)  evaluator_time: 0.0030 (0.0031)  time: 0.0456  data: 0.0077  max mem: 2725
# Test:  [1700/1837]  eta: 0:00:06  model_time: 0.0329 (0.0332)  evaluator_time: 0.0030 (0.0031)  time: 0.0456  data: 0.0075  max mem: 2725
# Test:  [1800/1837]  eta: 0:00:01  model_time: 0.0329 (0.0333)  evaluator_time: 0.0030 (0.0031)  time: 0.0458  data: 0.0077  max mem: 2725
# Test:  [1836/1837]  eta: 0:00:00  model_time: 0.0339 (0.0333)  evaluator_time: 0.0030 (0.0031)  time: 0.0463  data: 0.0086  max mem: 2725
# Test: Total time: 0:01:23 (0.0456 s / it)
# Averaged stats: model_time: 0.0339 (0.0333)  evaluator_time: 0.0030 (0.0031)
# Accumulating evaluation results...
# DONE (t=0.78s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.061
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.108
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.060
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.061
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.183
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.183
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.183
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.183

# %% [markdown]
# **Save model**

# %%
MODEL_PATH = os.path.join(ROOT_DIR, "models", "condensed_food_detection", "mobilenet_backbone.pt")

torch.save(model.state_dict(), MODEL_PATH)

# %% [markdown]
# # Evaluate
